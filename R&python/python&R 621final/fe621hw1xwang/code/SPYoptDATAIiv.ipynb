# %%
import math
import numpy as np   #manipulate mutidimensional arrays
import pandas as pd   #provide data structures
import scipy.stats as scs
import statsmodels.api as sm
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['font.family'] = 'serif' 
from scipy.integrate import quad
import mpl_toolkits.mplot3d.axes3d as p3
# Out:
# C:\Users\apple\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
from scipy.stats import norm

# %%
file1='SPYcalloptDATA1.csv'

# %%
data_email=pd.read_csv(file1)

# %%
df = pd.DataFrame(data_email)

# %%
from pandas import Series,DataFrame

# %%
series1=df['bid_price']
series2=df['ask_price']

# %%
average=(series1+series2)/2

# %%
df['average']=average

# %%
avrg=np.array(df['average'])
avrgli=avrg.tolist()

# %%
stp=np.array(df['strike_price'])
stpli=stp.tolist()

# %%
avrg=df['average']

# %%
sp=df['strike_price']

# %%
import math

r=0.0146 
T=float(30)/365



S0=274.96
 # initial volatility



def C(sigma):
    d1=(np.log(S0/K)+(r+sigma**2/2)*T)/(sigma*np.sqrt(T))
    d2=d1-sigma*np.sqrt(T)
    C=S0*norm.cdf(d1)-K*norm.cdf(d2)
    return C

def C2(sigma):
    C2=C(sigma)-mktprice
    return C2
def bisect(a,b):
    while b - a >= 0.000001:
        mid= (a + b) / 2.
        if C2(a)*C(mid) >= 0.0000001:
            b = mid
        else:
            a = mid

    return (mid)

# %%
filename='SPYcalloptDATA1iv.csv'
f=open(filename,'w')

headers='iv\n'
f.write(headers)

for i,j in zip(avrgli,stpli):
    
    mktprice=i
    K=j
    iv=bisect(0.000001,1)


    f.write(str(iv)+'\n')

f.close()

# %%
file2='SPYcalloptDATA1iv.csv'
data_1=pd.read_csv(file2)

# %%
df2 = pd.DataFrame(data_1)

# %%
df['iv']=df2
df['avrg_iv']=0.555638938

# %%
file3='SPYputoptDATA1.csv'
data_2=pd.read_csv(file3)

df3=data_2
series3=df3['bid_price']
series4=df3['ask_price']

# %%
average3=(series3+series4)/2

# %%
df3['average']=average3

# %%
avrg3=np.array(df3['average'])
avrgli3=avrg3.tolist()

# %%
stp3=np.array(df3['strike_price'])
stpli3=stp3.tolist()

# %%
r=0.0146 
T=float(30)/365



S0=274.96
 # initial volatility



def P(sigma):
    d1=(np.log(S0/K)+(r+sigma**2/2)*T)/(sigma*np.sqrt(T))
    d2=d1-sigma*np.sqrt(T)
    P=K*norm.cdf(-d2)-S0*norm.cdf(-d1)
    return P

def P2(sigma):
    P2=P(sigma)-mktprice
    return P2
def bisect2(a,b):
    while b - a >= 0.000001:
        mid= (a + b) / 2.
        if C2(a)*C(mid) >= 0.0000001:
            b = mid
        else:
            a = mid

    return (mid)

# %%
filename='SPYputoptDATA1iv.csv'
f=open(filename,'w')

headers='iv\n'
f.write(headers)

for i,j in zip(avrgli3,stpli3):
    
    mktprice=i
    K=j
    iv=bisect2(0.000001,1)


    f.write(str(iv)+'\n')

f.close()

# %%
file4='SPYputoptDATA1iv.csv'
data_4=pd.read_csv(file4)

# %%
df3['avrg_iv']=0.3786539

df3['iv']=data_4

# %%
df
# Out:
#           contract_name         last_trade_date  strike_price  last_price  \
# 0    SPY180518C00140000  2018-01-26 11:46PM EST         140.0      143.71
# 1    SPY180518C00145000  2018-01-26 11:46PM EST         145.0      138.70
# 2    SPY180518C00155000  2018-01-26 11:46PM EST         155.0      129.05
# 3    SPY180518C00170000  2018-01-26 11:46PM EST         170.0      113.89
# 4    SPY180518C00190000   2018-01-29 1:00PM EST         190.0       96.60
# 5    SPY180518C00200000  2018-02-02 10:15AM EST         200.0       79.80
# 6    SPY180518C00210000  2018-01-26 11:46PM EST         210.0       74.12
# 7    SPY180518C00220000   2018-01-29 3:48PM EST         220.0       65.79
# 8    SPY180518C00235000  2018-01-26 11:46PM EST         235.0       49.87
# 9    SPY180518C00240000   2018-02-01 1:55PM EST         240.0       43.65
# 10   SPY180518C00245000  2018-02-01 10:55AM EST         245.0       38.65
# 11   SPY180518C00250000  2018-01-31 10:18AM EST         250.0       35.22
# ...

# %%
df3
# Out:
#           contract_name         last_trade_date  strike_price  last_price  \
# 0    SPY180518P00140000  2018-01-31 12:30PM EST         140.0        0.04
# 1    SPY180518P00145000   2018-01-31 9:33AM EST         145.0        0.05
# 2    SPY180518P00150000   2018-02-02 8:05PM EST         150.0        0.06
# 3    SPY180518P00165000  2018-01-26 11:50PM EST         165.0        0.08
# 4    SPY180518P00170000   2018-02-02 2:41PM EST         170.0        0.14
# 5    SPY180518P00175000  2018-01-26 11:50PM EST         175.0        0.10
# 6    SPY180518P00185000   2018-02-02 2:18PM EST         185.0        0.18
# 7    SPY180518P00190000   2018-01-31 2:50PM EST         190.0        0.19
# 8    SPY180518P00195000  2018-02-01 10:37AM EST         195.0        0.20
# 9    SPY180518P00200000   2018-02-01 3:42PM EST         200.0        0.23
# 10   SPY180518P00205000  2018-01-26 11:50PM EST         205.0        0.26
# 11   SPY180518P00210000   2018-02-02 2:26PM EST         210.0        0.48
# ...
