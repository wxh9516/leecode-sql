# %%
from bs4 import BeautifulSoup as soup

# %%
from urllib.request import urlopen as uReq

# %%
my_url = 'https://finance.yahoo.com/quote/AMZN/options?p=AMZN&date=1529020800'

# %%
uClient = uReq(my_url)

# %%
page_html = uClient.read()

# %%
uClient.close()

# %%
page_soup = soup(page_html,'lxml')

# %%
page_soup.body.span
# Out:
# <span data-reactid="7">Summary</span>

# %%
containers=page_soup.findAll('tbody')

# %%
calls=containers[0]

# %%
puts=containers[1]

# %%
len(containers)
# Out:
# 2

# %%
filename='AMZNcalloptk-iv6-15.csv'
f=open(filename,'w')

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price,implied_volatility\n'

# %%
f.write(headers)
# Out:
# 93

# %%
for container in containers:
    for call in calls:
        
        title_container=call.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=call.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=call.findAll('a',{'href':'/quote/AMZN/options?strike=false&straddle=false'})
        strike_price=strike_price2[0].text
    
        lp=call.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=call.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=call.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
        
        iv=call.findAll('td',{'class':'data-col10 Ta(end) Pstart(7px) Pend(6px)'})
        iv2=iv[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
        print('implied volatility:'+iv2)
    
        f.write(contract_name+','+last_trade_date.replace(',','')+','+strike_price.replace(',','')+','+last_price.replace(',','')+','+bid_price.replace(',','')+','+ask_price.replace(',','')+','+iv2+'\n')

f.close()
# Out:
# contract name:AMZN180615C00420000
# last_trade_date:2018-01-11 1:18PM EST
# strike price:420.00
# last price:851.35
# bid price:887.20
# ask price:891.30
# implied volatility:0.00%
# contract name:AMZN180615C00430000
# last_trade_date:2018-01-11 1:18PM EST
# strike price:430.00
# last price:841.45
# bid price:877.25
# ask price:881.40
# implied volatility:0.00%
# contract name:AMZN180615C00440000
# last_trade_date:2018-02-05 10:10AM EST
# strike price:440.00
# last price:1,003.90
# bid price:953.30
# ask price:958.30
# implied volatility:103.85%
# contract name:AMZN180615C00450000
# last_trade_date:2018-02-02 9:54AM EST
# strike price:450.00
# last price:1,007.60
# bid price:983.85
# ask price:988.85
# implied volatility:166.46%
# contract name:AMZN180615C00460000
# last_trade_date:2018-01-10 10:35AM EST
# strike price:460.00
# last price:787.85
# bid price:847.55
# ask price:851.70
# implied volatility:0.00%
# contract name:AMZN180615C00470000
# last_trade_date:2018-02-02 9:42AM EST
# strike price:470.00
# last price:1,010.85
# bid price:964.00
# ask price:969.00
# implied volatility:160.79%
# contract name:AMZN180615C00480000
# last_trade_date:2018-02-05 10:12AM EST
# strike price:480.00
# last price:965.90
# bid price:913.75
# ask price:918.75
# implied volatility:97.80%
# contract name:AMZN180615C00490000
# last_trade_date:2017-12-01 11:45PM EST
# strike price:490.00
# last price:686.45
# bid price:676.00
# ask price:681.00
# implied volatility:0.00%
# contract name:AMZN180615C00500000
# last_trade_date:2018-01-17 12:07PM EST
# strike price:500.00
# last price:798.85
# bid price:797.50
# ask price:802.00
# implied volatility:0.00%
# contract name:AMZN180615C00520000
# last_trade_date:2018-02-02 1:04PM EST
# strike price:520.00
# last price:944.45
# bid price:914.50
# ask price:919.50
# implied volatility:147.89%
# contract name:AMZN180615C00540000
# last_trade_date:2018-02-02 9:46AM EST
# strike price:540.00
# last price:932.25
# bid price:894.70
# ask price:899.70
# implied volatility:143.12%
# contract name:AMZN180615C00560000
# last_trade_date:2017-12-04 4:26PM EST
# strike price:560.00
# last price:585.10
# bid price:579.55
# ask price:584.40
# implied volatility:0.00%
# contract name:AMZN180615C00580000
# last_trade_date:2017-12-04 9:34AM EST
# strike price:580.00
# last price:592.45
# bid price:560.00
# ask price:563.90
# implied volatility:0.00%
# contract name:AMZN180615C00600000
# last_trade_date:2018-02-02 3:58PM EST
# strike price:600.00
# last price:838.05
# bid price:835.65
# ask price:840.65
# implied volatility:130.22%
# contract name:AMZN180615C00620000
# last_trade_date:2018-01-18 3:37PM EST
# strike price:620.00
# last price:679.37
# bid price:678.50
# ask price:683.30
# implied volatility:0.00%
# contract name:AMZN180615C00640000
# last_trade_date:2017-12-04 10:57AM EST
# strike price:640.00
# last price:499.95
# bid price:501.70
# ask price:506.60
# implied volatility:0.00%
# contract name:AMZN180615C00650000
# last_trade_date:2017-10-27 10:39AM EST
# strike price:650.00
# last price:449.25
# bid price:458.65
# ask price:463.35
# implied volatility:0.00%
# contract name:AMZN180615C00660000
# last_trade_date:2018-02-02 1:04PM EST
# strike price:660.00
# last price:805.90
# bid price:776.00
# ask price:781.00
# implied volatility:118.13%
# contract name:AMZN180615C00670000
# last_trade_date:2018-01-08 9:32AM EST
# strike price:670.00
# last price:573.00
# bid price:639.95
# ask price:644.05
# implied volatility:0.00%
# contract name:AMZN180615C00685000
# last_trade_date:2017-12-04 4:26PM EST
# strike price:685.00
# last price:458.45
# bid price:457.90
# ask price:462.05
# implied volatility:0.00%
# contract name:AMZN180615C00690000
# last_trade_date:2017-12-26 10:03AM EST
# strike price:690.00
# last price:481.90
# bid price:485.50
# ask price:490.00
# implied volatility:0.00%
# contract name:AMZN180615C00700000
# last_trade_date:2018-01-23 3:26PM EST
# strike price:700.00
# last price:667.95
# bid price:706.00
# ask price:711.00
# implied volatility:83.40%
# contract name:AMZN180615C00710000
# last_trade_date:2017-12-12 2:40PM EST
# strike price:710.00
# last price:467.68
# bid price:476.00
# ask price:480.25
# implied volatility:0.00%
# contract name:AMZN180615C00720000
# last_trade_date:2018-01-02 10:32AM EST
# strike price:720.00
# last price:472.26
# bid price:514.90
# ask price:518.30
# implied volatility:0.00%
# contract name:AMZN180615C00730000
# last_trade_date:2018-01-26 10:57AM EST
# strike price:730.00
# last price:674.71
# bid price:676.50
# ask price:681.50
# implied volatility:79.63%
# contract name:AMZN180615C00740000
# last_trade_date:2018-02-02 3:10PM EST
# strike price:740.00
# last price:693.30
# bid price:697.45
# ask price:702.45
# implied volatility:104.41%
# contract name:AMZN180615C00750000
# last_trade_date:2018-01-03 2:53PM EST
# strike price:750.00
# last price:462.90
# bid price:485.65
# ask price:488.85
# implied volatility:0.00%
# contract name:AMZN180615C00760000
# last_trade_date:2017-08-31 11:56AM EST
# strike price:760.00
# last price:441.98
# bid price:417.00
# ask price:422.00
# implied volatility:0.00%
# contract name:AMZN180615C00770000
# last_trade_date:2017-10-30 12:19PM EST
# strike price:770.00
# last price:354.78
# bid price:352.65
# ask price:357.00
# implied volatility:0.00%
# contract name:AMZN180615C00780000
# last_trade_date:2017-09-28 2:58PM EST
# strike price:780.00
# last price:207.15
# bid price:225.30
# ask price:229.50
# implied volatility:0.00%
# contract name:AMZN180615C00790000
# last_trade_date:2018-01-31 2:09PM EST
# strike price:790.00
# last price:690.55
# bid price:648.25
# ask price:653.25
# implied volatility:96.47%
# contract name:AMZN180615C00800000
# last_trade_date:2018-02-01 12:04PM EST
# strike price:800.00
# last price:640.00
# bid price:637.75
# ask price:642.75
# implied volatility:94.50%
# contract name:AMZN180615C00810000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:810.00
# last price:633.62
# bid price:588.90
# ask price:593.90
# implied volatility:60.71%
# contract name:AMZN180615C00820000
# last_trade_date:2018-01-10 10:49AM EST
# strike price:820.00
# last price:433.95
# bid price:492.25
# ask price:496.20
# implied volatility:0.00%
# contract name:AMZN180615C00830000
# last_trade_date:2018-01-17 3:31PM EST
# strike price:830.00
# last price:477.25
# bid price:472.50
# ask price:477.00
# implied volatility:0.00%
# contract name:AMZN180615C00840000
# last_trade_date:2018-01-02 10:32AM EST
# strike price:840.00
# last price:356.27
# bid price:398.00
# ask price:401.35
# implied volatility:0.00%
# contract name:AMZN180615C00850000
# last_trade_date:2018-01-29 1:03PM EST
# strike price:850.00
# last price:590.00
# bid price:589.30
# ask price:594.30
# implied volatility:87.57%
# contract name:AMZN180615C00855000
# last_trade_date:2018-01-23 1:51PM EST
# strike price:855.00
# last price:509.83
# bid price:554.00
# ask price:559.00
# implied volatility:65.41%
# contract name:AMZN180615C00860000
# last_trade_date:2018-02-01 3:42PM EST
# strike price:860.00
# last price:547.50
# bid price:578.75
# ask price:583.75
# implied volatility:85.70%
# contract name:AMZN180615C00870000
# last_trade_date:2018-01-16 12:25PM EST
# strike price:870.00
# last price:462.27
# bid price:433.50
# ask price:438.30
# implied volatility:0.00%
# contract name:AMZN180615C00880000
# last_trade_date:2018-01-22 12:59PM EST
# strike price:880.00
# last price:447.69
# bid price:530.00
# ask price:534.50
# implied volatility:62.93%
# contract name:AMZN180615C00900000
# last_trade_date:2018-02-05 3:54PM EST
# strike price:900.00
# last price:502.00
# bid price:502.10
# ask price:507.10
# implied volatility:53.93%
# contract name:AMZN180615C00920000
# last_trade_date:2018-02-05 9:30AM EST
# strike price:920.00
# last price:490.25
# bid price:483.10
# ask price:488.10
# implied volatility:52.64%
# contract name:AMZN180615C00940000
# last_trade_date:2018-02-02 12:17PM EST
# strike price:940.00
# last price:537.00
# bid price:500.95
# ask price:505.95
# implied volatility:75.20%
# contract name:AMZN180615C00960000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:960.00
# last price:463.95
# bid price:445.50
# ask price:450.50
# implied volatility:50.25%
# contract name:AMZN180615C00980000
# last_trade_date:2018-02-02 9:30AM EST
# strike price:980.00
# last price:501.17
# bid price:462.60
# ask price:467.60
# implied volatility:70.45%
# contract name:AMZN180615C01000000
# last_trade_date:2018-02-05 3:52PM EST
# strike price:1,000.00
# last price:409.20
# bid price:408.55
# ask price:413.55
# implied volatility:49.82%
# contract name:AMZN180615C01020000
# last_trade_date:2018-02-02 3:49PM EST
# strike price:1,020.00
# last price:432.00
# bid price:424.60
# ask price:429.60
# implied volatility:65.96%
# contract name:AMZN180615C01040000
# last_trade_date:2018-02-02 3:57PM EST
# strike price:1,040.00
# last price:407.50
# bid price:372.50
# ask price:377.50
# implied volatility:47.79%
# contract name:AMZN180615C01060000
# last_trade_date:2018-02-05 10:42AM EST
# strike price:1,060.00
# last price:408.60
# bid price:354.85
# ask price:359.85
# implied volatility:46.87%
# contract name:AMZN180615C01080000
# last_trade_date:2018-02-02 11:14AM EST
# strike price:1,080.00
# last price:410.95
# bid price:368.85
# ask price:373.85
# implied volatility:59.87%
# contract name:AMZN180615C01100000
# last_trade_date:2018-02-05 3:38PM EST
# strike price:1,100.00
# last price:331.00
# bid price:320.55
# ask price:325.55
# implied volatility:45.28%
# contract name:AMZN180615C01120000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:1,120.00
# last price:319.35
# bid price:303.35
# ask price:308.35
# implied volatility:44.32%
# contract name:AMZN180615C01140000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,140.00
# last price:310.00
# bid price:287.85
# ask price:292.85
# implied volatility:44.03%
# contract name:AMZN180615C01160000
# last_trade_date:2018-02-05 11:17AM EST
# strike price:1,160.00
# last price:318.82
# bid price:272.25
# ask price:277.25
# implied volatility:43.54%
# contract name:AMZN180615C01180000
# last_trade_date:2018-02-05 3:56PM EST
# strike price:1,180.00
# last price:259.26
# bid price:256.25
# ask price:261.25
# implied volatility:42.75%
# contract name:AMZN180615C01200000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:1,200.00
# last price:252.90
# bid price:241.30
# ask price:246.30
# implied volatility:42.27%
# contract name:AMZN180615C01220000
# last_trade_date:2018-02-05 10:59AM EST
# strike price:1,220.00
# last price:271.45
# bid price:226.80
# ask price:231.80
# implied volatility:41.81%
# contract name:AMZN180615C01240000
# last_trade_date:2018-02-05 3:52PM EST
# strike price:1,240.00
# last price:215.27
# bid price:212.70
# ask price:217.70
# implied volatility:41.37%
# contract name:AMZN180615C01260000
# last_trade_date:2018-02-05 3:55PM EST
# strike price:1,260.00
# last price:203.00
# bid price:199.15
# ask price:204.15
# implied volatility:40.97%
# contract name:AMZN180615C01280000
# last_trade_date:2018-02-05 3:47PM EST
# strike price:1,280.00
# last price:192.00
# bid price:185.90
# ask price:190.90
# implied volatility:40.53%
# contract name:AMZN180615C01300000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,300.00
# last price:184.02
# bid price:172.70
# ask price:177.70
# implied volatility:39.97%
# contract name:AMZN180615C01320000
# last_trade_date:2018-02-05 1:26PM EST
# strike price:1,320.00
# last price:187.20
# bid price:161.85
# ask price:166.35
# implied volatility:39.87%
# contract name:AMZN180615C01340000
# last_trade_date:2018-02-05 3:41PM EST
# strike price:1,340.00
# last price:157.65
# bid price:151.05
# ask price:156.05
# implied volatility:39.94%
# contract name:AMZN180615C01350000
# last_trade_date:2018-02-05 12:44PM EST
# strike price:1,350.00
# last price:174.95
# bid price:143.95
# ask price:148.95
# implied volatility:39.31%
# contract name:AMZN180615C01360000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:1,360.00
# last price:145.00
# bid price:138.55
# ask price:143.55
# implied volatility:39.18%
# contract name:AMZN180615C01370000
# last_trade_date:2018-02-05 12:57PM EST
# strike price:1,370.00
# last price:163.25
# bid price:133.45
# ask price:138.45
# implied volatility:39.10%
# contract name:AMZN180615C01380000
# last_trade_date:2018-02-05 3:55PM EST
# strike price:1,380.00
# last price:133.62
# bid price:129.00
# ask price:134.00
# implied volatility:39.18%
# contract name:AMZN180615C01390000
# last_trade_date:2018-02-05 10:02PM EST
# strike price:1,390.00
# last price:131.76
# bid price:125.00
# ask price:130.00
# implied volatility:39.37%
# contract name:AMZN180615C01400000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,400.00
# last price:123.00
# bid price:120.05
# ask price:125.05
# implied volatility:39.22%
# contract name:AMZN180615C01410000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:1,410.00
# last price:125.33
# bid price:115.65
# ask price:119.95
# implied volatility:38.99%
# contract name:AMZN180615C01420000
# last_trade_date:2018-02-05 3:49PM EST
# strike price:1,420.00
# last price:113.40
# bid price:109.65
# ask price:114.65
# implied volatility:38.67%
# contract name:AMZN180615C01430000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,430.00
# last price:109.00
# bid price:104.90
# ask price:109.90
# implied volatility:38.48%
# contract name:AMZN180615C01440000
# last_trade_date:2018-02-05 3:50PM EST
# strike price:1,440.00
# last price:105.21
# bid price:101.05
# ask price:106.05
# implied volatility:38.53%
# contract name:AMZN180615C01450000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:1,450.00
# last price:105.14
# bid price:97.20
# ask price:101.85
# implied volatility:38.43%
# contract name:AMZN180615C01460000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:1,460.00
# last price:101.00
# bid price:95.00
# ask price:99.50
# implied volatility:38.86%
# contract name:AMZN180615C01470000
# last_trade_date:2018-02-05 3:47PM EST
# strike price:1,470.00
# last price:92.10
# bid price:88.75
# ask price:93.75
# implied volatility:38.23%
# contract name:AMZN180615C01480000
# last_trade_date:2018-02-05 3:47PM EST
# strike price:1,480.00
# last price:89.10
# bid price:85.20
# ask price:90.20
# implied volatility:38.22%
# contract name:AMZN180615C01490000
# last_trade_date:2018-02-05 11:05AM EST
# strike price:1,490.00
# last price:101.89
# bid price:81.80
# ask price:86.80
# implied volatility:38.23%
# contract name:AMZN180615C01500000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:1,500.00
# last price:83.00
# bid price:79.05
# ask price:84.00
# implied volatility:38.39%
# contract name:AMZN180615C01510000
# last_trade_date:2018-02-05 2:16PM EST
# strike price:1,510.00
# last price:91.50
# bid price:74.15
# ask price:79.15
# implied volatility:37.89%
# contract name:AMZN180615C01520000
# last_trade_date:2018-02-05 1:41PM EST
# strike price:1,520.00
# last price:86.50
# bid price:71.95
# ask price:76.45
# implied volatility:38.02%
# contract name:AMZN180615C01530000
# last_trade_date:2018-02-05 2:19PM EST
# strike price:1,530.00
# last price:83.10
# bid price:68.55
# ask price:73.05
# implied volatility:37.89%
# contract name:AMZN180615C01540000
# last_trade_date:2018-02-05 2:33PM EST
# strike price:1,540.00
# last price:80.05
# bid price:65.05
# ask price:70.05
# implied volatility:37.86%
# contract name:AMZN180615C01550000
# last_trade_date:2018-02-05 2:59PM EST
# strike price:1,550.00
# last price:72.14
# bid price:62.10
# ask price:67.10
# implied volatility:37.82%
# contract name:AMZN180615C01560000
# last_trade_date:2018-02-05 12:20PM EST
# strike price:1,560.00
# last price:70.00
# bid price:59.55
# ask price:64.35
# implied volatility:37.80%
# contract name:AMZN180615C01580000
# last_trade_date:2018-02-05 2:45PM EST
# strike price:1,580.00
# last price:67.69
# bid price:53.90
# ask price:58.90
# implied volatility:37.70%
# contract name:AMZN180615C01600000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,600.00
# last price:52.50
# bid price:49.80
# ask price:54.80
# implied volatility:37.93%
# contract name:AMZN180615C01620000
# last_trade_date:2018-02-05 9:52AM EST
# strike price:1,620.00
# last price:43.95
# bid price:44.75
# ask price:49.60
# implied volatility:37.67%
# contract name:AMZN180615C01640000
# last_trade_date:2018-02-05 3:40PM EST
# strike price:1,640.00
# last price:43.70
# bid price:40.45
# ask price:45.25
# implied volatility:37.59%
# contract name:AMZN180615C01650000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:1,650.00
# last price:47.00
# bid price:38.30
# ask price:43.30
# implied volatility:37.58%
# contract name:AMZN180615C01660000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:1,660.00
# last price:44.85
# bid price:36.85
# ask price:41.85
# implied volatility:37.74%
# contract name:AMZN180615C01680000
# last_trade_date:2018-02-05 1:40PM EST
# strike price:1,680.00
# last price:41.75
# bid price:33.30
# ask price:38.30
# implied volatility:37.74%
# contract name:AMZN180615C01700000
# last_trade_date:2018-02-05 3:50PM EST
# strike price:1,700.00
# last price:32.50
# bid price:30.00
# ask price:35.00
# implied volatility:37.72%
# contract name:AMZN180615C01720000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:1,720.00
# last price:33.09
# bid price:27.20
# ask price:32.20
# implied volatility:37.82%
# contract name:AMZN180615C01740000
# last_trade_date:2018-02-05 3:40PM EST
# strike price:1,740.00
# last price:27.05
# bid price:24.40
# ask price:29.40
# implied volatility:37.81%
# contract name:AMZN180615C01760000
# last_trade_date:2018-02-05 2:02PM EST
# strike price:1,760.00
# last price:28.74
# bid price:22.20
# ask price:27.20
# implied volatility:37.99%
# contract name:AMZN180615C01780000
# last_trade_date:2018-02-05 12:45PM EST
# strike price:1,780.00
# last price:26.35
# bid price:19.40
# ask price:24.40
# implied volatility:37.78%
# contract name:AMZN180615C01800000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:1,800.00
# last price:19.50
# bid price:17.60
# ask price:22.60
# implied volatility:37.97%
# contract name:AMZN180615C01820000
# last_trade_date:2018-02-05 12:57PM EST
# strike price:1,820.00
# last price:21.85
# bid price:15.80
# ask price:20.80
# implied volatility:38.09%
# contract name:AMZN180615C01840000
# last_trade_date:2018-02-05 12:57PM EST
# strike price:1,840.00
# last price:19.85
# bid price:14.55
# ask price:19.50
# implied volatility:38.40%
# contract name:AMZN180615C01850000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,850.00
# last price:17.45
# bid price:13.85
# ask price:18.85
# implied volatility:38.54%
# contract name:AMZN180615C01860000
# last_trade_date:2018-02-05 9:54AM EST
# strike price:1,860.00
# last price:13.20
# bid price:13.10
# ask price:18.05
# implied volatility:38.57%
# contract name:AMZN180615C01880000
# last_trade_date:2018-02-05 1:50PM EST
# strike price:1,880.00
# last price:15.55
# bid price:11.20
# ask price:16.05
# implied volatility:38.32%
# contract name:AMZN180615C01900000
# last_trade_date:2018-02-05 1:45PM EST
# strike price:1,900.00
# last price:14.30
# bid price:10.60
# ask price:15.60
# implied volatility:38.97%
# contract name:AMZN180615C01920000
# last_trade_date:2018-02-05 1:49PM EST
# strike price:1,920.00
# last price:12.95
# bid price:9.25
# ask price:14.05
# implied volatility:38.86%
# contract name:AMZN180615C01940000
# last_trade_date:2018-02-05 11:24AM EST
# strike price:1,940.00
# last price:11.35
# bid price:8.55
# ask price:13.55
# implied volatility:39.40%
# contract name:AMZN180615C01950000
# last_trade_date:2018-02-05 1:44PM EST
# strike price:1,950.00
# last price:11.30
# bid price:8.15
# ask price:13.15
# implied volatility:39.55%
# contract name:AMZN180615C01960000
# last_trade_date:2018-02-05 1:44PM EST
# strike price:1,960.00
# last price:10.85
# bid price:7.70
# ask price:12.55
# implied volatility:39.55%
# contract name:AMZN180615C01980000
# last_trade_date:2018-02-05 11:51AM EST
# strike price:1,980.00
# last price:9.25
# bid price:6.85
# ask price:11.80
# implied volatility:39.82%
# contract name:AMZN180615C02000000
# last_trade_date:2018-02-05 3:56PM EST
# strike price:2,000.00
# last price:8.00
# bid price:6.00
# ask price:10.95
# implied volatility:39.97%
# contract name:AMZN180615C02050000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:2,050.00
# last price:7.45
# bid price:4.75
# ask price:9.70
# implied volatility:40.89%
# contract name:AMZN180615C02100000
# last_trade_date:2018-02-05 3:41PM EST
# strike price:2,100.00
# last price:6.15
# bid price:5.10
# ask price:8.40
# implied volatility:41.54%
# contract name:AMZN180615C00420000
# last_trade_date:2018-01-11 1:18PM EST
# strike price:420.00
# last price:851.35
# bid price:887.20
# ask price:891.30
# implied volatility:0.00%
# contract name:AMZN180615C00430000
# last_trade_date:2018-01-11 1:18PM EST
# strike price:430.00
# last price:841.45
# bid price:877.25
# ask price:881.40
# implied volatility:0.00%
# contract name:AMZN180615C00440000
# last_trade_date:2018-02-05 10:10AM EST
# strike price:440.00
# last price:1,003.90
# bid price:953.30
# ask price:958.30
# implied volatility:103.85%
# contract name:AMZN180615C00450000
# last_trade_date:2018-02-02 9:54AM EST
# strike price:450.00
# last price:1,007.60
# bid price:983.85
# ask price:988.85
# implied volatility:166.46%
# contract name:AMZN180615C00460000
# last_trade_date:2018-01-10 10:35AM EST
# strike price:460.00
# last price:787.85
# bid price:847.55
# ask price:851.70
# implied volatility:0.00%
# contract name:AMZN180615C00470000
# last_trade_date:2018-02-02 9:42AM EST
# strike price:470.00
# last price:1,010.85
# bid price:964.00
# ask price:969.00
# implied volatility:160.79%
# contract name:AMZN180615C00480000
# last_trade_date:2018-02-05 10:12AM EST
# strike price:480.00
# last price:965.90
# bid price:913.75
# ask price:918.75
# implied volatility:97.80%
# contract name:AMZN180615C00490000
# last_trade_date:2017-12-01 11:45PM EST
# strike price:490.00
# last price:686.45
# bid price:676.00
# ask price:681.00
# implied volatility:0.00%
# contract name:AMZN180615C00500000
# last_trade_date:2018-01-17 12:07PM EST
# strike price:500.00
# last price:798.85
# bid price:797.50
# ask price:802.00
# implied volatility:0.00%
# contract name:AMZN180615C00520000
# last_trade_date:2018-02-02 1:04PM EST
# strike price:520.00
# last price:944.45
# bid price:914.50
# ask price:919.50
# implied volatility:147.89%
# contract name:AMZN180615C00540000
# last_trade_date:2018-02-02 9:46AM EST
# strike price:540.00
# last price:932.25
# bid price:894.70
# ask price:899.70
# implied volatility:143.12%
# contract name:AMZN180615C00560000
# last_trade_date:2017-12-04 4:26PM EST
# strike price:560.00
# last price:585.10
# bid price:579.55
# ask price:584.40
# implied volatility:0.00%
# contract name:AMZN180615C00580000
# last_trade_date:2017-12-04 9:34AM EST
# strike price:580.00
# last price:592.45
# bid price:560.00
# ask price:563.90
# implied volatility:0.00%
# contract name:AMZN180615C00600000
# last_trade_date:2018-02-02 3:58PM EST
# strike price:600.00
# last price:838.05
# bid price:835.65
# ask price:840.65
# implied volatility:130.22%
# contract name:AMZN180615C00620000
# last_trade_date:2018-01-18 3:37PM EST
# strike price:620.00
# last price:679.37
# bid price:678.50
# ask price:683.30
# implied volatility:0.00%
# contract name:AMZN180615C00640000
# last_trade_date:2017-12-04 10:57AM EST
# strike price:640.00
# last price:499.95
# bid price:501.70
# ask price:506.60
# implied volatility:0.00%
# contract name:AMZN180615C00650000
# last_trade_date:2017-10-27 10:39AM EST
# strike price:650.00
# last price:449.25
# bid price:458.65
# ask price:463.35
# implied volatility:0.00%
# contract name:AMZN180615C00660000
# last_trade_date:2018-02-02 1:04PM EST
# strike price:660.00
# last price:805.90
# bid price:776.00
# ask price:781.00
# implied volatility:118.13%
# contract name:AMZN180615C00670000
# last_trade_date:2018-01-08 9:32AM EST
# strike price:670.00
# last price:573.00
# bid price:639.95
# ask price:644.05
# implied volatility:0.00%
# contract name:AMZN180615C00685000
# last_trade_date:2017-12-04 4:26PM EST
# strike price:685.00
# last price:458.45
# bid price:457.90
# ask price:462.05
# implied volatility:0.00%
# contract name:AMZN180615C00690000
# last_trade_date:2017-12-26 10:03AM EST
# strike price:690.00
# last price:481.90
# bid price:485.50
# ask price:490.00
# implied volatility:0.00%
# contract name:AMZN180615C00700000
# last_trade_date:2018-01-23 3:26PM EST
# strike price:700.00
# last price:667.95
# bid price:706.00
# ask price:711.00
# implied volatility:83.40%
# contract name:AMZN180615C00710000
# last_trade_date:2017-12-12 2:40PM EST
# strike price:710.00
# last price:467.68
# bid price:476.00
# ask price:480.25
# implied volatility:0.00%
# contract name:AMZN180615C00720000
# last_trade_date:2018-01-02 10:32AM EST
# strike price:720.00
# last price:472.26
# bid price:514.90
# ask price:518.30
# implied volatility:0.00%
# contract name:AMZN180615C00730000
# last_trade_date:2018-01-26 10:57AM EST
# strike price:730.00
# last price:674.71
# bid price:676.50
# ask price:681.50
# implied volatility:79.63%
# contract name:AMZN180615C00740000
# last_trade_date:2018-02-02 3:10PM EST
# strike price:740.00
# last price:693.30
# bid price:697.45
# ask price:702.45
# implied volatility:104.41%
# contract name:AMZN180615C00750000
# last_trade_date:2018-01-03 2:53PM EST
# strike price:750.00
# last price:462.90
# bid price:485.65
# ask price:488.85
# implied volatility:0.00%
# contract name:AMZN180615C00760000
# last_trade_date:2017-08-31 11:56AM EST
# strike price:760.00
# last price:441.98
# bid price:417.00
# ask price:422.00
# implied volatility:0.00%
# contract name:AMZN180615C00770000
# last_trade_date:2017-10-30 12:19PM EST
# strike price:770.00
# last price:354.78
# bid price:352.65
# ask price:357.00
# implied volatility:0.00%
# contract name:AMZN180615C00780000
# last_trade_date:2017-09-28 2:58PM EST
# strike price:780.00
# last price:207.15
# bid price:225.30
# ask price:229.50
# implied volatility:0.00%
# contract name:AMZN180615C00790000
# last_trade_date:2018-01-31 2:09PM EST
# strike price:790.00
# last price:690.55
# bid price:648.25
# ask price:653.25
# implied volatility:96.47%
# contract name:AMZN180615C00800000
# last_trade_date:2018-02-01 12:04PM EST
# strike price:800.00
# last price:640.00
# bid price:637.75
# ask price:642.75
# implied volatility:94.50%
# contract name:AMZN180615C00810000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:810.00
# last price:633.62
# bid price:588.90
# ask price:593.90
# implied volatility:60.71%
# contract name:AMZN180615C00820000
# last_trade_date:2018-01-10 10:49AM EST
# strike price:820.00
# last price:433.95
# bid price:492.25
# ask price:496.20
# implied volatility:0.00%
# contract name:AMZN180615C00830000
# last_trade_date:2018-01-17 3:31PM EST
# strike price:830.00
# last price:477.25
# bid price:472.50
# ask price:477.00
# implied volatility:0.00%
# contract name:AMZN180615C00840000
# last_trade_date:2018-01-02 10:32AM EST
# strike price:840.00
# last price:356.27
# bid price:398.00
# ask price:401.35
# implied volatility:0.00%
# contract name:AMZN180615C00850000
# last_trade_date:2018-01-29 1:03PM EST
# strike price:850.00
# last price:590.00
# bid price:589.30
# ask price:594.30
# implied volatility:87.57%
# contract name:AMZN180615C00855000
# last_trade_date:2018-01-23 1:51PM EST
# strike price:855.00
# last price:509.83
# bid price:554.00
# ask price:559.00
# implied volatility:65.41%
# contract name:AMZN180615C00860000
# last_trade_date:2018-02-01 3:42PM EST
# strike price:860.00
# last price:547.50
# bid price:578.75
# ask price:583.75
# implied volatility:85.70%
# contract name:AMZN180615C00870000
# last_trade_date:2018-01-16 12:25PM EST
# strike price:870.00
# last price:462.27
# bid price:433.50
# ask price:438.30
# implied volatility:0.00%
# contract name:AMZN180615C00880000
# last_trade_date:2018-01-22 12:59PM EST
# strike price:880.00
# last price:447.69
# bid price:530.00
# ask price:534.50
# implied volatility:62.93%
# contract name:AMZN180615C00900000
# last_trade_date:2018-02-05 3:54PM EST
# strike price:900.00
# last price:502.00
# bid price:502.10
# ask price:507.10
# implied volatility:53.93%
# contract name:AMZN180615C00920000
# last_trade_date:2018-02-05 9:30AM EST
# strike price:920.00
# last price:490.25
# bid price:483.10
# ask price:488.10
# implied volatility:52.64%
# contract name:AMZN180615C00940000
# last_trade_date:2018-02-02 12:17PM EST
# strike price:940.00
# last price:537.00
# bid price:500.95
# ask price:505.95
# implied volatility:75.20%
# contract name:AMZN180615C00960000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:960.00
# last price:463.95
# bid price:445.50
# ask price:450.50
# implied volatility:50.25%
# contract name:AMZN180615C00980000
# last_trade_date:2018-02-02 9:30AM EST
# strike price:980.00
# last price:501.17
# bid price:462.60
# ask price:467.60
# implied volatility:70.45%
# contract name:AMZN180615C01000000
# last_trade_date:2018-02-05 3:52PM EST
# strike price:1,000.00
# last price:409.20
# bid price:408.55
# ask price:413.55
# implied volatility:49.82%
# contract name:AMZN180615C01020000
# last_trade_date:2018-02-02 3:49PM EST
# strike price:1,020.00
# last price:432.00
# bid price:424.60
# ask price:429.60
# implied volatility:65.96%
# contract name:AMZN180615C01040000
# last_trade_date:2018-02-02 3:57PM EST
# strike price:1,040.00
# last price:407.50
# bid price:372.50
# ask price:377.50
# implied volatility:47.79%
# contract name:AMZN180615C01060000
# last_trade_date:2018-02-05 10:42AM EST
# strike price:1,060.00
# last price:408.60
# bid price:354.85
# ask price:359.85
# implied volatility:46.87%
# contract name:AMZN180615C01080000
# last_trade_date:2018-02-02 11:14AM EST
# strike price:1,080.00
# last price:410.95
# bid price:368.85
# ask price:373.85
# implied volatility:59.87%
# contract name:AMZN180615C01100000
# last_trade_date:2018-02-05 3:38PM EST
# strike price:1,100.00
# last price:331.00
# bid price:320.55
# ask price:325.55
# implied volatility:45.28%
# contract name:AMZN180615C01120000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:1,120.00
# last price:319.35
# bid price:303.35
# ask price:308.35
# implied volatility:44.32%
# contract name:AMZN180615C01140000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,140.00
# last price:310.00
# bid price:287.85
# ask price:292.85
# implied volatility:44.03%
# contract name:AMZN180615C01160000
# last_trade_date:2018-02-05 11:17AM EST
# strike price:1,160.00
# last price:318.82
# bid price:272.25
# ask price:277.25
# implied volatility:43.54%
# contract name:AMZN180615C01180000
# last_trade_date:2018-02-05 3:56PM EST
# strike price:1,180.00
# last price:259.26
# bid price:256.25
# ask price:261.25
# implied volatility:42.75%
# contract name:AMZN180615C01200000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:1,200.00
# last price:252.90
# bid price:241.30
# ask price:246.30
# implied volatility:42.27%
# contract name:AMZN180615C01220000
# last_trade_date:2018-02-05 10:59AM EST
# strike price:1,220.00
# last price:271.45
# bid price:226.80
# ask price:231.80
# implied volatility:41.81%
# contract name:AMZN180615C01240000
# last_trade_date:2018-02-05 3:52PM EST
# strike price:1,240.00
# last price:215.27
# bid price:212.70
# ask price:217.70
# implied volatility:41.37%
# contract name:AMZN180615C01260000
# last_trade_date:2018-02-05 3:55PM EST
# strike price:1,260.00
# last price:203.00
# bid price:199.15
# ask price:204.15
# implied volatility:40.97%
# contract name:AMZN180615C01280000
# last_trade_date:2018-02-05 3:47PM EST
# strike price:1,280.00
# last price:192.00
# bid price:185.90
# ask price:190.90
# implied volatility:40.53%
# contract name:AMZN180615C01300000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,300.00
# last price:184.02
# bid price:172.70
# ask price:177.70
# implied volatility:39.97%
# contract name:AMZN180615C01320000
# last_trade_date:2018-02-05 1:26PM EST
# strike price:1,320.00
# last price:187.20
# bid price:161.85
# ask price:166.35
# implied volatility:39.87%
# contract name:AMZN180615C01340000
# last_trade_date:2018-02-05 3:41PM EST
# strike price:1,340.00
# last price:157.65
# bid price:151.05
# ask price:156.05
# implied volatility:39.94%
# contract name:AMZN180615C01350000
# last_trade_date:2018-02-05 12:44PM EST
# strike price:1,350.00
# last price:174.95
# bid price:143.95
# ask price:148.95
# implied volatility:39.31%
# contract name:AMZN180615C01360000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:1,360.00
# last price:145.00
# bid price:138.55
# ask price:143.55
# implied volatility:39.18%
# contract name:AMZN180615C01370000
# last_trade_date:2018-02-05 12:57PM EST
# strike price:1,370.00
# last price:163.25
# bid price:133.45
# ask price:138.45
# implied volatility:39.10%
# contract name:AMZN180615C01380000
# last_trade_date:2018-02-05 3:55PM EST
# strike price:1,380.00
# last price:133.62
# bid price:129.00
# ask price:134.00
# implied volatility:39.18%
# contract name:AMZN180615C01390000
# last_trade_date:2018-02-05 10:02PM EST
# strike price:1,390.00
# last price:131.76
# bid price:125.00
# ask price:130.00
# implied volatility:39.37%
# contract name:AMZN180615C01400000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,400.00
# last price:123.00
# bid price:120.05
# ask price:125.05
# implied volatility:39.22%
# contract name:AMZN180615C01410000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:1,410.00
# last price:125.33
# bid price:115.65
# ask price:119.95
# implied volatility:38.99%
# contract name:AMZN180615C01420000
# last_trade_date:2018-02-05 3:49PM EST
# strike price:1,420.00
# last price:113.40
# bid price:109.65
# ask price:114.65
# implied volatility:38.67%
# contract name:AMZN180615C01430000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,430.00
# last price:109.00
# bid price:104.90
# ask price:109.90
# implied volatility:38.48%
# contract name:AMZN180615C01440000
# last_trade_date:2018-02-05 3:50PM EST
# strike price:1,440.00
# last price:105.21
# bid price:101.05
# ask price:106.05
# implied volatility:38.53%
# contract name:AMZN180615C01450000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:1,450.00
# last price:105.14
# bid price:97.20
# ask price:101.85
# implied volatility:38.43%
# contract name:AMZN180615C01460000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:1,460.00
# last price:101.00
# bid price:95.00
# ask price:99.50
# implied volatility:38.86%
# contract name:AMZN180615C01470000
# last_trade_date:2018-02-05 3:47PM EST
# strike price:1,470.00
# last price:92.10
# bid price:88.75
# ask price:93.75
# implied volatility:38.23%
# contract name:AMZN180615C01480000
# last_trade_date:2018-02-05 3:47PM EST
# strike price:1,480.00
# last price:89.10
# bid price:85.20
# ask price:90.20
# implied volatility:38.22%
# contract name:AMZN180615C01490000
# last_trade_date:2018-02-05 11:05AM EST
# strike price:1,490.00
# last price:101.89
# bid price:81.80
# ask price:86.80
# implied volatility:38.23%
# contract name:AMZN180615C01500000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:1,500.00
# last price:83.00
# bid price:79.05
# ask price:84.00
# implied volatility:38.39%
# contract name:AMZN180615C01510000
# last_trade_date:2018-02-05 2:16PM EST
# strike price:1,510.00
# last price:91.50
# bid price:74.15
# ask price:79.15
# implied volatility:37.89%
# contract name:AMZN180615C01520000
# last_trade_date:2018-02-05 1:41PM EST
# strike price:1,520.00
# last price:86.50
# bid price:71.95
# ask price:76.45
# implied volatility:38.02%
# contract name:AMZN180615C01530000
# last_trade_date:2018-02-05 2:19PM EST
# strike price:1,530.00
# last price:83.10
# bid price:68.55
# ask price:73.05
# implied volatility:37.89%
# contract name:AMZN180615C01540000
# last_trade_date:2018-02-05 2:33PM EST
# strike price:1,540.00
# last price:80.05
# bid price:65.05
# ask price:70.05
# implied volatility:37.86%
# contract name:AMZN180615C01550000
# last_trade_date:2018-02-05 2:59PM EST
# strike price:1,550.00
# last price:72.14
# bid price:62.10
# ask price:67.10
# implied volatility:37.82%
# contract name:AMZN180615C01560000
# last_trade_date:2018-02-05 12:20PM EST
# strike price:1,560.00
# last price:70.00
# bid price:59.55
# ask price:64.35
# implied volatility:37.80%
# contract name:AMZN180615C01580000
# last_trade_date:2018-02-05 2:45PM EST
# strike price:1,580.00
# last price:67.69
# bid price:53.90
# ask price:58.90
# implied volatility:37.70%
# contract name:AMZN180615C01600000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,600.00
# last price:52.50
# bid price:49.80
# ask price:54.80
# implied volatility:37.93%
# contract name:AMZN180615C01620000
# last_trade_date:2018-02-05 9:52AM EST
# strike price:1,620.00
# last price:43.95
# bid price:44.75
# ask price:49.60
# implied volatility:37.67%
# contract name:AMZN180615C01640000
# last_trade_date:2018-02-05 3:40PM EST
# strike price:1,640.00
# last price:43.70
# bid price:40.45
# ask price:45.25
# implied volatility:37.59%
# contract name:AMZN180615C01650000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:1,650.00
# last price:47.00
# bid price:38.30
# ask price:43.30
# implied volatility:37.58%
# contract name:AMZN180615C01660000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:1,660.00
# last price:44.85
# bid price:36.85
# ask price:41.85
# implied volatility:37.74%
# contract name:AMZN180615C01680000
# last_trade_date:2018-02-05 1:40PM EST
# strike price:1,680.00
# last price:41.75
# bid price:33.30
# ask price:38.30
# implied volatility:37.74%
# contract name:AMZN180615C01700000
# last_trade_date:2018-02-05 3:50PM EST
# strike price:1,700.00
# last price:32.50
# bid price:30.00
# ask price:35.00
# implied volatility:37.72%
# contract name:AMZN180615C01720000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:1,720.00
# last price:33.09
# bid price:27.20
# ask price:32.20
# implied volatility:37.82%
# contract name:AMZN180615C01740000
# last_trade_date:2018-02-05 3:40PM EST
# strike price:1,740.00
# last price:27.05
# bid price:24.40
# ask price:29.40
# implied volatility:37.81%
# contract name:AMZN180615C01760000
# last_trade_date:2018-02-05 2:02PM EST
# strike price:1,760.00
# last price:28.74
# bid price:22.20
# ask price:27.20
# implied volatility:37.99%
# contract name:AMZN180615C01780000
# last_trade_date:2018-02-05 12:45PM EST
# strike price:1,780.00
# last price:26.35
# bid price:19.40
# ask price:24.40
# implied volatility:37.78%
# contract name:AMZN180615C01800000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:1,800.00
# last price:19.50
# bid price:17.60
# ask price:22.60
# implied volatility:37.97%
# contract name:AMZN180615C01820000
# last_trade_date:2018-02-05 12:57PM EST
# strike price:1,820.00
# last price:21.85
# bid price:15.80
# ask price:20.80
# implied volatility:38.09%
# contract name:AMZN180615C01840000
# last_trade_date:2018-02-05 12:57PM EST
# strike price:1,840.00
# last price:19.85
# bid price:14.55
# ask price:19.50
# implied volatility:38.40%
# contract name:AMZN180615C01850000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,850.00
# last price:17.45
# bid price:13.85
# ask price:18.85
# implied volatility:38.54%
# contract name:AMZN180615C01860000
# last_trade_date:2018-02-05 9:54AM EST
# strike price:1,860.00
# last price:13.20
# bid price:13.10
# ask price:18.05
# implied volatility:38.57%
# contract name:AMZN180615C01880000
# last_trade_date:2018-02-05 1:50PM EST
# strike price:1,880.00
# last price:15.55
# bid price:11.20
# ask price:16.05
# implied volatility:38.32%
# contract name:AMZN180615C01900000
# last_trade_date:2018-02-05 1:45PM EST
# strike price:1,900.00
# last price:14.30
# bid price:10.60
# ask price:15.60
# implied volatility:38.97%
# contract name:AMZN180615C01920000
# last_trade_date:2018-02-05 1:49PM EST
# strike price:1,920.00
# last price:12.95
# bid price:9.25
# ask price:14.05
# implied volatility:38.86%
# contract name:AMZN180615C01940000
# last_trade_date:2018-02-05 11:24AM EST
# strike price:1,940.00
# last price:11.35
# bid price:8.55
# ask price:13.55
# implied volatility:39.40%
# contract name:AMZN180615C01950000
# last_trade_date:2018-02-05 1:44PM EST
# strike price:1,950.00
# last price:11.30
# bid price:8.15
# ask price:13.15
# implied volatility:39.55%
# contract name:AMZN180615C01960000
# last_trade_date:2018-02-05 1:44PM EST
# strike price:1,960.00
# last price:10.85
# bid price:7.70
# ask price:12.55
# implied volatility:39.55%
# contract name:AMZN180615C01980000
# last_trade_date:2018-02-05 11:51AM EST
# strike price:1,980.00
# last price:9.25
# bid price:6.85
# ask price:11.80
# implied volatility:39.82%
# contract name:AMZN180615C02000000
# last_trade_date:2018-02-05 3:56PM EST
# strike price:2,000.00
# last price:8.00
# bid price:6.00
# ask price:10.95
# implied volatility:39.97%
# contract name:AMZN180615C02050000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:2,050.00
# last price:7.45
# bid price:4.75
# ask price:9.70
# implied volatility:40.89%
# contract name:AMZN180615C02100000
# last_trade_date:2018-02-05 3:41PM EST
# strike price:2,100.00
# last price:6.15
# bid price:5.10
# ask price:8.40
# implied volatility:41.54%

# %%
filename='AMZNputoptk-iv6-15.csv'
f=open(filename,'w')
f.write(headers)
# Out:
# 93

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price,implied_volatility\n'

# %%
for container in containers:
    for put in puts:
        
        title_container=put.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=put.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=put.findAll('a',{'href':'/quote/AMZN/options?strike=false&straddle=false'})
        strike_price=strike_price2[0].text
    
        lp=put.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=put.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=put.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
        
        iv=put.findAll('td',{'class':'data-col10 Ta(end) Pstart(7px) Pend(6px)'})
        iv2=iv[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
        print('implied volatility:'+iv2)
        f.write(contract_name+','+last_trade_date.replace(',','')+','+strike_price.replace(',','')+','+last_price.replace(',','')+','+bid_price.replace(',','')+','+ask_price.replace(',','')+','+iv2+'\n')

f.close()
# Out:
# contract name:AMZN180615P00420000
# last_trade_date:2018-02-05 9:52AM EST
# strike price:420.00
# last price:0.10
# bid price:0.04
# ask price:0.20
# implied volatility:67.09%
# contract name:AMZN180615P00430000
# last_trade_date:2018-01-22 10:46AM EST
# strike price:430.00
# last price:0.10
# bid price:0.00
# ask price:0.33
# implied volatility:67.77%
# contract name:AMZN180615P00440000
# last_trade_date:2018-01-23 12:07PM EST
# strike price:440.00
# last price:0.05
# bid price:0.00
# ask price:0.35
# implied volatility:66.80%
# contract name:AMZN180615P00450000
# last_trade_date:2018-01-16 3:15PM EST
# strike price:450.00
# last price:0.09
# bid price:0.00
# ask price:0.35
# implied volatility:65.53%
# contract name:AMZN180615P00460000
# last_trade_date:2018-01-23 12:07PM EST
# strike price:460.00
# last price:0.08
# bid price:0.00
# ask price:0.41
# implied volatility:65.28%
# contract name:AMZN180615P00470000
# last_trade_date:2018-02-02 3:57PM EST
# strike price:470.00
# last price:0.25
# bid price:0.00
# ask price:0.30
# implied volatility:62.26%
# contract name:AMZN180615P00480000
# last_trade_date:2018-01-23 12:08PM EST
# strike price:480.00
# last price:0.11
# bid price:0.00
# ask price:0.49
# implied volatility:63.97%
# contract name:AMZN180615P00490000
# last_trade_date:2018-02-02 3:51PM EST
# strike price:490.00
# last price:0.25
# bid price:0.00
# ask price:0.91
# implied volatility:66.87%
# contract name:AMZN180615P00500000
# last_trade_date:2018-02-02 3:51PM EST
# strike price:500.00
# last price:0.30
# bid price:0.10
# ask price:0.70
# implied volatility:64.75%
# contract name:AMZN180615P00520000
# last_trade_date:2017-12-20 1:17PM EST
# strike price:520.00
# last price:0.45
# bid price:0.00
# ask price:0.74
# implied volatility:61.87%
# contract name:AMZN180615P00540000
# last_trade_date:2018-02-05 9:30AM EST
# strike price:540.00
# last price:0.45
# bid price:0.00
# ask price:2.38
# implied volatility:68.23%
# contract name:AMZN180615P00560000
# last_trade_date:2018-01-23 11:58AM EST
# strike price:560.00
# last price:0.40
# bid price:0.00
# ask price:0.79
# implied volatility:57.84%
# contract name:AMZN180615P00580000
# last_trade_date:2018-01-12 11:10AM EST
# strike price:580.00
# last price:0.30
# bid price:0.00
# ask price:0.59
# implied volatility:54.05%
# contract name:AMZN180615P00600000
# last_trade_date:2018-02-05 10:09AM EST
# strike price:600.00
# last price:0.50
# bid price:0.05
# ask price:1.57
# implied volatility:58.25%
# contract name:AMZN180615P00620000
# last_trade_date:2018-01-23 12:15PM EST
# strike price:620.00
# last price:0.45
# bid price:0.05
# ask price:0.94
# implied volatility:53.00%
# contract name:AMZN180615P00640000
# last_trade_date:2018-01-12 9:30AM EST
# strike price:640.00
# last price:0.24
# bid price:0.18
# ask price:0.78
# implied volatility:50.88%
# contract name:AMZN180615P00650000
# last_trade_date:2018-02-02 9:53AM EST
# strike price:650.00
# last price:0.82
# bid price:0.36
# ask price:1.33
# implied volatility:53.35%
# contract name:AMZN180615P00660000
# last_trade_date:2018-01-22 3:08PM EST
# strike price:660.00
# last price:0.68
# bid price:0.00
# ask price:1.08
# implied volatility:53.99%
# contract name:AMZN180615P00670000
# last_trade_date:2018-02-05 11:32AM EST
# strike price:670.00
# last price:0.58
# bid price:0.02
# ask price:2.77
# implied volatility:54.80%
# contract name:AMZN180615P00680000
# last_trade_date:2018-02-02 3:00PM EST
# strike price:680.00
# last price:0.76
# bid price:0.53
# ask price:1.53
# implied volatility:51.67%
# contract name:AMZN180615P00685000
# last_trade_date:2018-02-01 9:30AM EST
# strike price:685.00
# last price:1.60
# bid price:0.56
# ask price:1.52
# implied volatility:51.26%
# contract name:AMZN180615P00690000
# last_trade_date:2018-01-23 12:08PM EST
# strike price:690.00
# last price:0.80
# bid price:0.06
# ask price:1.21
# implied volatility:51.78%
# contract name:AMZN180615P00700000
# last_trade_date:2018-02-02 1:28PM EST
# strike price:700.00
# last price:0.61
# bid price:0.65
# ask price:1.60
# implied volatility:50.32%
# contract name:AMZN180615P00710000
# last_trade_date:2018-02-02 1:34PM EST
# strike price:710.00
# last price:0.60
# bid price:0.70
# ask price:1.67
# implied volatility:52.10%
# contract name:AMZN180615P00720000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:720.00
# last price:1.20
# bid price:0.85
# ask price:1.95
# implied volatility:52.27%
# contract name:AMZN180615P00730000
# last_trade_date:2018-01-23 1:16PM EST
# strike price:730.00
# last price:1.02
# bid price:0.85
# ask price:1.44
# implied volatility:49.11%
# contract name:AMZN180615P00740000
# last_trade_date:2018-01-22 2:33PM EST
# strike price:740.00
# last price:1.20
# bid price:0.57
# ask price:1.50
# implied volatility:48.44%
# contract name:AMZN180615P00750000
# last_trade_date:2018-02-05 3:50PM EST
# strike price:750.00
# last price:1.82
# bid price:0.95
# ask price:2.83
# implied volatility:52.24%
# contract name:AMZN180615P00760000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:760.00
# last price:1.85
# bid price:0.00
# ask price:3.75
# implied volatility:53.68%
# contract name:AMZN180615P00770000
# last_trade_date:2018-02-02 9:32AM EST
# strike price:770.00
# last price:1.00
# bid price:1.06
# ask price:2.03
# implied volatility:47.72%
# contract name:AMZN180615P00780000
# last_trade_date:2018-02-05 9:51AM EST
# strike price:780.00
# last price:1.37
# bid price:0.73
# ask price:4.00
# implied volatility:52.22%
# contract name:AMZN180615P00790000
# last_trade_date:2018-02-02 9:34AM EST
# strike price:790.00
# last price:1.00
# bid price:1.18
# ask price:2.14
# implied volatility:46.23%
# contract name:AMZN180615P00800000
# last_trade_date:2018-02-05 3:46PM EST
# strike price:800.00
# last price:2.88
# bid price:1.47
# ask price:2.65
# implied volatility:46.85%
# contract name:AMZN180615P00810000
# last_trade_date:2018-01-25 11:41AM EST
# strike price:810.00
# last price:1.70
# bid price:1.33
# ask price:1.84
# implied volatility:43.40%
# contract name:AMZN180615P00820000
# last_trade_date:2018-02-05 1:42PM EST
# strike price:820.00
# last price:1.84
# bid price:1.41
# ask price:4.55
# implied volatility:49.37%
# contract name:AMZN180615P00830000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:830.00
# last price:2.20
# bid price:1.46
# ask price:4.35
# implied volatility:47.99%
# contract name:AMZN180615P00840000
# last_trade_date:2018-02-02 9:39AM EST
# strike price:840.00
# last price:1.30
# bid price:1.57
# ask price:2.53
# implied volatility:42.86%
# contract name:AMZN180615P00850000
# last_trade_date:2018-02-05 3:53PM EST
# strike price:850.00
# last price:3.60
# bid price:1.99
# ask price:5.00
# implied volatility:47.27%
# contract name:AMZN180615P00855000
# last_trade_date:2018-01-05 10:34AM EST
# strike price:855.00
# last price:3.90
# bid price:3.30
# ask price:3.90
# implied volatility:44.69%
# contract name:AMZN180615P00860000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:860.00
# last price:4.13
# bid price:2.51
# ask price:5.65
# implied volatility:47.40%
# contract name:AMZN180615P00870000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:870.00
# last price:3.50
# bid price:2.29
# ask price:5.95
# implied volatility:46.90%
# contract name:AMZN180615P00880000
# last_trade_date:2018-01-31 1:30PM EST
# strike price:880.00
# last price:3.25
# bid price:2.10
# ask price:3.35
# implied volatility:41.27%
# contract name:AMZN180615P00900000
# last_trade_date:2018-02-05 3:53PM EST
# strike price:900.00
# last price:5.23
# bid price:3.80
# ask price:6.00
# implied volatility:44.08%
# contract name:AMZN180615P00920000
# last_trade_date:2018-02-05 3:46PM EST
# strike price:920.00
# last price:5.90
# bid price:4.35
# ask price:7.75
# implied volatility:44.53%
# contract name:AMZN180615P00940000
# last_trade_date:2018-02-05 2:49PM EST
# strike price:940.00
# last price:4.98
# bid price:5.35
# ask price:8.50
# implied volatility:43.49%
# contract name:AMZN180615P00960000
# last_trade_date:2018-02-05 2:48PM EST
# strike price:960.00
# last price:5.75
# bid price:6.40
# ask price:9.60
# implied volatility:42.76%
# contract name:AMZN180615P00980000
# last_trade_date:2018-02-05 1:19PM EST
# strike price:980.00
# last price:6.20
# bid price:7.65
# ask price:11.05
# implied volatility:42.24%
# contract name:AMZN180615P01000000
# last_trade_date:2018-02-05 3:50PM EST
# strike price:1,000.00
# last price:10.54
# bid price:9.00
# ask price:14.00
# implied volatility:42.85%
# contract name:AMZN180615P01020000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,020.00
# last price:8.50
# bid price:10.75
# ask price:15.15
# implied volatility:41.73%
# contract name:AMZN180615P01040000
# last_trade_date:2018-02-05 2:26PM EST
# strike price:1,040.00
# last price:10.00
# bid price:12.00
# ask price:16.85
# implied volatility:40.96%
# contract name:AMZN180615P01060000
# last_trade_date:2018-02-05 2:28PM EST
# strike price:1,060.00
# last price:11.65
# bid price:14.95
# ask price:19.90
# implied volatility:40.96%
# contract name:AMZN180615P01080000
# last_trade_date:2018-02-05 2:18PM EST
# strike price:1,080.00
# last price:12.53
# bid price:17.00
# ask price:21.65
# implied volatility:39.95%
# contract name:AMZN180615P01100000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,100.00
# last price:18.00
# bid price:19.40
# ask price:24.35
# implied volatility:39.41%
# contract name:AMZN180615P01120000
# last_trade_date:2018-02-05 12:02PM EST
# strike price:1,120.00
# last price:15.05
# bid price:22.80
# ask price:27.80
# implied volatility:39.11%
# contract name:AMZN180615P01140000
# last_trade_date:2018-02-05 2:15PM EST
# strike price:1,140.00
# last price:19.10
# bid price:26.25
# ask price:31.25
# implied volatility:38.65%
# contract name:AMZN180615P01160000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:1,160.00
# last price:31.00
# bid price:30.40
# ask price:35.40
# implied volatility:38.36%
# contract name:AMZN180615P01180000
# last_trade_date:2018-02-05 3:56PM EST
# strike price:1,180.00
# last price:40.00
# bid price:34.80
# ask price:39.80
# implied volatility:38.00%
# contract name:AMZN180615P01200000
# last_trade_date:2017-12-19 12:22PM EST
# strike price:1,200.00
# last price:88.64
# bid price:85.55
# ask price:87.75
# implied volatility:53.68%
# contract name:AMZN180615P01220000
# last_trade_date:2018-02-05 3:55PM EST
# strike price:1,220.00
# last price:50.80
# bid price:45.15
# ask price:50.15
# implied volatility:37.42%
# contract name:AMZN180615P01240000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,240.00
# last price:45.90
# bid price:51.05
# ask price:55.60
# implied volatility:36.99%
# contract name:AMZN180615P01260000
# last_trade_date:2018-02-05 3:45PM EST
# strike price:1,260.00
# last price:57.00
# bid price:57.90
# ask price:61.65
# implied volatility:36.61%
# contract name:AMZN180615P01280000
# last_trade_date:2018-02-05 3:47PM EST
# strike price:1,280.00
# last price:66.00
# bid price:63.75
# ask price:68.75
# implied volatility:36.44%
# contract name:AMZN180615P01300000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,300.00
# last price:73.30
# bid price:71.20
# ask price:76.20
# implied volatility:36.21%
# contract name:AMZN180615P01320000
# last_trade_date:2018-02-05 2:32PM EST
# strike price:1,320.00
# last price:62.60
# bid price:79.55
# ask price:83.75
# implied volatility:35.85%
# contract name:AMZN180615P01340000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:1,340.00
# last price:80.70
# bid price:88.50
# ask price:93.50
# implied volatility:36.02%
# contract name:AMZN180615P01350000
# last_trade_date:2018-02-05 2:38PM EST
# strike price:1,350.00
# last price:72.90
# bid price:92.10
# ask price:97.10
# implied volatility:35.64%
# contract name:AMZN180615P01360000
# last_trade_date:2018-02-05 2:35PM EST
# strike price:1,360.00
# last price:77.90
# bid price:97.50
# ask price:102.50
# implied volatility:35.78%
# contract name:AMZN180615P01370000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:1,370.00
# last price:88.60
# bid price:101.55
# ask price:106.55
# implied volatility:35.46%
# contract name:AMZN180615P01380000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:1,380.00
# last price:106.20
# bid price:106.70
# ask price:111.70
# implied volatility:35.44%
# contract name:AMZN180615P01390000
# last_trade_date:2018-02-05 2:15PM EST
# strike price:1,390.00
# last price:86.20
# bid price:110.95
# ask price:115.95
# implied volatility:35.11%
# contract name:AMZN180615P01400000
# last_trade_date:2018-02-05 3:51PM EST
# strike price:1,400.00
# last price:121.00
# bid price:116.85
# ask price:121.85
# implied volatility:35.23%
# contract name:AMZN180615P01410000
# last_trade_date:2018-02-05 1:46PM EST
# strike price:1,410.00
# last price:96.50
# bid price:122.30
# ask price:127.30
# implied volatility:35.18%
# contract name:AMZN180615P01420000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:1,420.00
# last price:119.20
# bid price:128.25
# ask price:132.15
# implied volatility:34.91%
# contract name:AMZN180615P01430000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,430.00
# last price:117.13
# bid price:133.10
# ask price:137.65
# implied volatility:34.79%
# contract name:AMZN180615P01440000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:1,440.00
# last price:130.00
# bid price:138.65
# ask price:143.65
# implied volatility:34.79%
# contract name:AMZN180615P01450000
# last_trade_date:2018-02-05 11:08AM EST
# strike price:1,450.00
# last price:105.64
# bid price:144.75
# ask price:149.75
# implied volatility:34.78%
# contract name:AMZN180615P01460000
# last_trade_date:2018-02-05 1:58PM EST
# strike price:1,460.00
# last price:116.30
# bid price:151.25
# ask price:156.25
# implied volatility:34.85%
# contract name:AMZN180615P01470000
# last_trade_date:2018-02-05 2:02PM EST
# strike price:1,470.00
# last price:123.95
# bid price:157.35
# ask price:162.25
# implied volatility:34.73%
# contract name:AMZN180615P01480000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:1,480.00
# last price:141.40
# bid price:163.65
# ask price:168.65
# implied volatility:34.69%
# contract name:AMZN180615P01490000
# last_trade_date:2018-02-05 1:55PM EST
# strike price:1,490.00
# last price:135.00
# bid price:168.85
# ask price:173.85
# implied volatility:34.25%
# contract name:AMZN180615P01500000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,500.00
# last price:160.32
# bid price:176.55
# ask price:180.70
# implied volatility:34.27%
# contract name:AMZN180615P01510000
# last_trade_date:2018-02-05 10:04PM EST
# strike price:1,510.00
# last price:166.54
# bid price:181.85
# ask price:186.85
# implied volatility:34.04%
# contract name:AMZN180615P01520000
# last_trade_date:2018-02-05 10:31AM EST
# strike price:1,520.00
# last price:147.30
# bid price:189.60
# ask price:194.25
# implied volatility:34.17%
# contract name:AMZN180615P01540000
# last_trade_date:2018-02-05 12:52PM EST
# strike price:1,540.00
# last price:161.05
# bid price:203.25
# ask price:207.90
# implied volatility:33.95%
# contract name:AMZN180615P01550000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,550.00
# last price:192.00
# bid price:209.20
# ask price:214.20
# implied volatility:33.60%
# contract name:AMZN180615P01560000
# last_trade_date:2018-02-05 3:56PM EST
# strike price:1,560.00
# last price:215.05
# bid price:217.15
# ask price:221.55
# implied volatility:33.57%
# contract name:AMZN180615P01580000
# last_trade_date:2018-02-05 10:48AM EST
# strike price:1,580.00
# last price:179.80
# bid price:231.25
# ask price:236.25
# implied volatility:33.39%
# contract name:AMZN180615P01600000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,600.00
# last price:245.00
# bid price:247.05
# ask price:252.05
# implied volatility:33.46%
# contract name:AMZN180615P01620000
# last_trade_date:2018-01-31 10:26AM EST
# strike price:1,620.00
# last price:198.10
# bid price:224.80
# ask price:229.15
# implied volatility:0.00%
# contract name:AMZN180615P01640000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,640.00
# last price:225.26
# bid price:241.65
# ask price:245.15
# implied volatility:0.00%
# contract name:AMZN180615P01650000
# last_trade_date:2018-02-05 1:55PM EST
# strike price:1,650.00
# last price:243.50
# bid price:286.05
# ask price:291.05
# implied volatility:32.83%
# contract name:AMZN180615P01660000
# last_trade_date:2018-02-05 10:12AM EST
# strike price:1,660.00
# last price:248.40
# bid price:294.30
# ask price:299.30
# implied volatility:32.78%
# contract name:AMZN180615P01680000
# last_trade_date:2018-02-05 11:09AM EST
# strike price:1,680.00
# last price:259.35
# bid price:311.60
# ask price:316.60
# implied volatility:32.91%
# contract name:AMZN180615P01700000
# last_trade_date:2018-02-05 11:51AM EST
# strike price:1,700.00
# last price:285.85
# bid price:328.35
# ask price:333.35
# implied volatility:32.68%
# contract name:AMZN180615P01720000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,720.00
# last price:344.65
# bid price:307.40
# ask price:310.85
# implied volatility:0.00%
# contract name:AMZN180615P01760000
# last_trade_date:2018-02-05 9:38AM EST
# strike price:1,760.00
# last price:364.65
# bid price:380.65
# ask price:385.65
# implied volatility:32.11%
# contract name:AMZN180615P01780000
# last_trade_date:2018-02-05 1:35PM EST
# strike price:1,780.00
# last price:359.40
# bid price:398.75
# ask price:403.75
# implied volatility:32.02%
# contract name:AMZN180615P01800000
# last_trade_date:2018-02-05 11:41AM EST
# strike price:1,800.00
# last price:372.70
# bid price:416.95
# ask price:421.95
# implied volatility:31.86%
# contract name:AMZN180615P01820000
# last_trade_date:2018-02-05 1:35PM EST
# strike price:1,820.00
# last price:395.45
# bid price:436.10
# ask price:441.10
# implied volatility:32.24%
# contract name:AMZN180615P01840000
# last_trade_date:2018-02-05 1:35PM EST
# strike price:1,840.00
# last price:413.75
# bid price:454.60
# ask price:459.60
# implied volatility:32.06%
# contract name:AMZN180615P01850000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,850.00
# last price:427.95
# bid price:424.40
# ask price:429.40
# implied volatility:0.00%
# contract name:AMZN180615P01860000
# last_trade_date:2018-02-05 2:38PM EST
# strike price:1,860.00
# last price:431.05
# bid price:473.20
# ask price:478.20
# implied volatility:31.83%
# contract name:AMZN180615P01880000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,880.00
# last price:422.30
# bid price:452.80
# ask price:457.80
# implied volatility:0.00%
# contract name:AMZN180615P01940000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,940.00
# last price:501.50
# bid price:508.55
# ask price:513.55
# implied volatility:0.00%
# contract name:AMZN180615P01950000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,950.00
# last price:497.65
# bid price:518.40
# ask price:523.40
# implied volatility:0.00%
# contract name:AMZN180615P01980000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,980.00
# last price:524.65
# bid price:549.40
# ask price:554.40
# implied volatility:0.00%
# contract name:AMZN180615P02000000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:2,000.00
# last price:580.35
# bid price:567.30
# ask price:572.30
# implied volatility:0.00%
# contract name:AMZN180615P02050000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:2,050.00
# last price:632.75
# bid price:616.85
# ask price:621.85
# implied volatility:0.00%
# contract name:AMZN180615P02100000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:2,100.00
# last price:624.95
# bid price:666.35
# ask price:671.35
# implied volatility:0.00%
# contract name:AMZN180615P00420000
# last_trade_date:2018-02-05 9:52AM EST
# strike price:420.00
# last price:0.10
# bid price:0.04
# ask price:0.20
# implied volatility:67.09%
# contract name:AMZN180615P00430000
# last_trade_date:2018-01-22 10:46AM EST
# strike price:430.00
# last price:0.10
# bid price:0.00
# ask price:0.33
# implied volatility:67.77%
# contract name:AMZN180615P00440000
# last_trade_date:2018-01-23 12:07PM EST
# strike price:440.00
# last price:0.05
# bid price:0.00
# ask price:0.35
# implied volatility:66.80%
# contract name:AMZN180615P00450000
# last_trade_date:2018-01-16 3:15PM EST
# strike price:450.00
# last price:0.09
# bid price:0.00
# ask price:0.35
# implied volatility:65.53%
# contract name:AMZN180615P00460000
# last_trade_date:2018-01-23 12:07PM EST
# strike price:460.00
# last price:0.08
# bid price:0.00
# ask price:0.41
# implied volatility:65.28%
# contract name:AMZN180615P00470000
# last_trade_date:2018-02-02 3:57PM EST
# strike price:470.00
# last price:0.25
# bid price:0.00
# ask price:0.30
# implied volatility:62.26%
# contract name:AMZN180615P00480000
# last_trade_date:2018-01-23 12:08PM EST
# strike price:480.00
# last price:0.11
# bid price:0.00
# ask price:0.49
# implied volatility:63.97%
# contract name:AMZN180615P00490000
# last_trade_date:2018-02-02 3:51PM EST
# strike price:490.00
# last price:0.25
# bid price:0.00
# ask price:0.91
# implied volatility:66.87%
# contract name:AMZN180615P00500000
# last_trade_date:2018-02-02 3:51PM EST
# strike price:500.00
# last price:0.30
# bid price:0.10
# ask price:0.70
# implied volatility:64.75%
# contract name:AMZN180615P00520000
# last_trade_date:2017-12-20 1:17PM EST
# strike price:520.00
# last price:0.45
# bid price:0.00
# ask price:0.74
# implied volatility:61.87%
# contract name:AMZN180615P00540000
# last_trade_date:2018-02-05 9:30AM EST
# strike price:540.00
# last price:0.45
# bid price:0.00
# ask price:2.38
# implied volatility:68.23%
# contract name:AMZN180615P00560000
# last_trade_date:2018-01-23 11:58AM EST
# strike price:560.00
# last price:0.40
# bid price:0.00
# ask price:0.79
# implied volatility:57.84%
# contract name:AMZN180615P00580000
# last_trade_date:2018-01-12 11:10AM EST
# strike price:580.00
# last price:0.30
# bid price:0.00
# ask price:0.59
# implied volatility:54.05%
# contract name:AMZN180615P00600000
# last_trade_date:2018-02-05 10:09AM EST
# strike price:600.00
# last price:0.50
# bid price:0.05
# ask price:1.57
# implied volatility:58.25%
# contract name:AMZN180615P00620000
# last_trade_date:2018-01-23 12:15PM EST
# strike price:620.00
# last price:0.45
# bid price:0.05
# ask price:0.94
# implied volatility:53.00%
# contract name:AMZN180615P00640000
# last_trade_date:2018-01-12 9:30AM EST
# strike price:640.00
# last price:0.24
# bid price:0.18
# ask price:0.78
# implied volatility:50.88%
# contract name:AMZN180615P00650000
# last_trade_date:2018-02-02 9:53AM EST
# strike price:650.00
# last price:0.82
# bid price:0.36
# ask price:1.33
# implied volatility:53.35%
# contract name:AMZN180615P00660000
# last_trade_date:2018-01-22 3:08PM EST
# strike price:660.00
# last price:0.68
# bid price:0.00
# ask price:1.08
# implied volatility:53.99%
# contract name:AMZN180615P00670000
# last_trade_date:2018-02-05 11:32AM EST
# strike price:670.00
# last price:0.58
# bid price:0.02
# ask price:2.77
# implied volatility:54.80%
# contract name:AMZN180615P00680000
# last_trade_date:2018-02-02 3:00PM EST
# strike price:680.00
# last price:0.76
# bid price:0.53
# ask price:1.53
# implied volatility:51.67%
# contract name:AMZN180615P00685000
# last_trade_date:2018-02-01 9:30AM EST
# strike price:685.00
# last price:1.60
# bid price:0.56
# ask price:1.52
# implied volatility:51.26%
# contract name:AMZN180615P00690000
# last_trade_date:2018-01-23 12:08PM EST
# strike price:690.00
# last price:0.80
# bid price:0.06
# ask price:1.21
# implied volatility:51.78%
# contract name:AMZN180615P00700000
# last_trade_date:2018-02-02 1:28PM EST
# strike price:700.00
# last price:0.61
# bid price:0.65
# ask price:1.60
# implied volatility:50.32%
# contract name:AMZN180615P00710000
# last_trade_date:2018-02-02 1:34PM EST
# strike price:710.00
# last price:0.60
# bid price:0.70
# ask price:1.67
# implied volatility:52.10%
# contract name:AMZN180615P00720000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:720.00
# last price:1.20
# bid price:0.85
# ask price:1.95
# implied volatility:52.27%
# contract name:AMZN180615P00730000
# last_trade_date:2018-01-23 1:16PM EST
# strike price:730.00
# last price:1.02
# bid price:0.85
# ask price:1.44
# implied volatility:49.11%
# contract name:AMZN180615P00740000
# last_trade_date:2018-01-22 2:33PM EST
# strike price:740.00
# last price:1.20
# bid price:0.57
# ask price:1.50
# implied volatility:48.44%
# contract name:AMZN180615P00750000
# last_trade_date:2018-02-05 3:50PM EST
# strike price:750.00
# last price:1.82
# bid price:0.95
# ask price:2.83
# implied volatility:52.24%
# contract name:AMZN180615P00760000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:760.00
# last price:1.85
# bid price:0.00
# ask price:3.75
# implied volatility:53.68%
# contract name:AMZN180615P00770000
# last_trade_date:2018-02-02 9:32AM EST
# strike price:770.00
# last price:1.00
# bid price:1.06
# ask price:2.03
# implied volatility:47.72%
# contract name:AMZN180615P00780000
# last_trade_date:2018-02-05 9:51AM EST
# strike price:780.00
# last price:1.37
# bid price:0.73
# ask price:4.00
# implied volatility:52.22%
# contract name:AMZN180615P00790000
# last_trade_date:2018-02-02 9:34AM EST
# strike price:790.00
# last price:1.00
# bid price:1.18
# ask price:2.14
# implied volatility:46.23%
# contract name:AMZN180615P00800000
# last_trade_date:2018-02-05 3:46PM EST
# strike price:800.00
# last price:2.88
# bid price:1.47
# ask price:2.65
# implied volatility:46.85%
# contract name:AMZN180615P00810000
# last_trade_date:2018-01-25 11:41AM EST
# strike price:810.00
# last price:1.70
# bid price:1.33
# ask price:1.84
# implied volatility:43.40%
# contract name:AMZN180615P00820000
# last_trade_date:2018-02-05 1:42PM EST
# strike price:820.00
# last price:1.84
# bid price:1.41
# ask price:4.55
# implied volatility:49.37%
# contract name:AMZN180615P00830000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:830.00
# last price:2.20
# bid price:1.46
# ask price:4.35
# implied volatility:47.99%
# contract name:AMZN180615P00840000
# last_trade_date:2018-02-02 9:39AM EST
# strike price:840.00
# last price:1.30
# bid price:1.57
# ask price:2.53
# implied volatility:42.86%
# contract name:AMZN180615P00850000
# last_trade_date:2018-02-05 3:53PM EST
# strike price:850.00
# last price:3.60
# bid price:1.99
# ask price:5.00
# implied volatility:47.27%
# contract name:AMZN180615P00855000
# last_trade_date:2018-01-05 10:34AM EST
# strike price:855.00
# last price:3.90
# bid price:3.30
# ask price:3.90
# implied volatility:44.69%
# contract name:AMZN180615P00860000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:860.00
# last price:4.13
# bid price:2.51
# ask price:5.65
# implied volatility:47.40%
# contract name:AMZN180615P00870000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:870.00
# last price:3.50
# bid price:2.29
# ask price:5.95
# implied volatility:46.90%
# contract name:AMZN180615P00880000
# last_trade_date:2018-01-31 1:30PM EST
# strike price:880.00
# last price:3.25
# bid price:2.10
# ask price:3.35
# implied volatility:41.27%
# contract name:AMZN180615P00900000
# last_trade_date:2018-02-05 3:53PM EST
# strike price:900.00
# last price:5.23
# bid price:3.80
# ask price:6.00
# implied volatility:44.08%
# contract name:AMZN180615P00920000
# last_trade_date:2018-02-05 3:46PM EST
# strike price:920.00
# last price:5.90
# bid price:4.35
# ask price:7.75
# implied volatility:44.53%
# contract name:AMZN180615P00940000
# last_trade_date:2018-02-05 2:49PM EST
# strike price:940.00
# last price:4.98
# bid price:5.35
# ask price:8.50
# implied volatility:43.49%
# contract name:AMZN180615P00960000
# last_trade_date:2018-02-05 2:48PM EST
# strike price:960.00
# last price:5.75
# bid price:6.40
# ask price:9.60
# implied volatility:42.76%
# contract name:AMZN180615P00980000
# last_trade_date:2018-02-05 1:19PM EST
# strike price:980.00
# last price:6.20
# bid price:7.65
# ask price:11.05
# implied volatility:42.24%
# contract name:AMZN180615P01000000
# last_trade_date:2018-02-05 3:50PM EST
# strike price:1,000.00
# last price:10.54
# bid price:9.00
# ask price:14.00
# implied volatility:42.85%
# contract name:AMZN180615P01020000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,020.00
# last price:8.50
# bid price:10.75
# ask price:15.15
# implied volatility:41.73%
# contract name:AMZN180615P01040000
# last_trade_date:2018-02-05 2:26PM EST
# strike price:1,040.00
# last price:10.00
# bid price:12.00
# ask price:16.85
# implied volatility:40.96%
# contract name:AMZN180615P01060000
# last_trade_date:2018-02-05 2:28PM EST
# strike price:1,060.00
# last price:11.65
# bid price:14.95
# ask price:19.90
# implied volatility:40.96%
# contract name:AMZN180615P01080000
# last_trade_date:2018-02-05 2:18PM EST
# strike price:1,080.00
# last price:12.53
# bid price:17.00
# ask price:21.65
# implied volatility:39.95%
# contract name:AMZN180615P01100000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,100.00
# last price:18.00
# bid price:19.40
# ask price:24.35
# implied volatility:39.41%
# contract name:AMZN180615P01120000
# last_trade_date:2018-02-05 12:02PM EST
# strike price:1,120.00
# last price:15.05
# bid price:22.80
# ask price:27.80
# implied volatility:39.11%
# contract name:AMZN180615P01140000
# last_trade_date:2018-02-05 2:15PM EST
# strike price:1,140.00
# last price:19.10
# bid price:26.25
# ask price:31.25
# implied volatility:38.65%
# contract name:AMZN180615P01160000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:1,160.00
# last price:31.00
# bid price:30.40
# ask price:35.40
# implied volatility:38.36%
# contract name:AMZN180615P01180000
# last_trade_date:2018-02-05 3:56PM EST
# strike price:1,180.00
# last price:40.00
# bid price:34.80
# ask price:39.80
# implied volatility:38.00%
# contract name:AMZN180615P01200000
# last_trade_date:2017-12-19 12:22PM EST
# strike price:1,200.00
# last price:88.64
# bid price:85.55
# ask price:87.75
# implied volatility:53.68%
# contract name:AMZN180615P01220000
# last_trade_date:2018-02-05 3:55PM EST
# strike price:1,220.00
# last price:50.80
# bid price:45.15
# ask price:50.15
# implied volatility:37.42%
# contract name:AMZN180615P01240000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,240.00
# last price:45.90
# bid price:51.05
# ask price:55.60
# implied volatility:36.99%
# contract name:AMZN180615P01260000
# last_trade_date:2018-02-05 3:45PM EST
# strike price:1,260.00
# last price:57.00
# bid price:57.90
# ask price:61.65
# implied volatility:36.61%
# contract name:AMZN180615P01280000
# last_trade_date:2018-02-05 3:47PM EST
# strike price:1,280.00
# last price:66.00
# bid price:63.75
# ask price:68.75
# implied volatility:36.44%
# contract name:AMZN180615P01300000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,300.00
# last price:73.30
# bid price:71.20
# ask price:76.20
# implied volatility:36.21%
# contract name:AMZN180615P01320000
# last_trade_date:2018-02-05 2:32PM EST
# strike price:1,320.00
# last price:62.60
# bid price:79.55
# ask price:83.75
# implied volatility:35.85%
# contract name:AMZN180615P01340000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:1,340.00
# last price:80.70
# bid price:88.50
# ask price:93.50
# implied volatility:36.02%
# contract name:AMZN180615P01350000
# last_trade_date:2018-02-05 2:38PM EST
# strike price:1,350.00
# last price:72.90
# bid price:92.10
# ask price:97.10
# implied volatility:35.64%
# contract name:AMZN180615P01360000
# last_trade_date:2018-02-05 2:35PM EST
# strike price:1,360.00
# last price:77.90
# bid price:97.50
# ask price:102.50
# implied volatility:35.78%
# contract name:AMZN180615P01370000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:1,370.00
# last price:88.60
# bid price:101.55
# ask price:106.55
# implied volatility:35.46%
# contract name:AMZN180615P01380000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:1,380.00
# last price:106.20
# bid price:106.70
# ask price:111.70
# implied volatility:35.44%
# contract name:AMZN180615P01390000
# last_trade_date:2018-02-05 2:15PM EST
# strike price:1,390.00
# last price:86.20
# bid price:110.95
# ask price:115.95
# implied volatility:35.11%
# contract name:AMZN180615P01400000
# last_trade_date:2018-02-05 3:51PM EST
# strike price:1,400.00
# last price:121.00
# bid price:116.85
# ask price:121.85
# implied volatility:35.23%
# contract name:AMZN180615P01410000
# last_trade_date:2018-02-05 1:46PM EST
# strike price:1,410.00
# last price:96.50
# bid price:122.30
# ask price:127.30
# implied volatility:35.18%
# contract name:AMZN180615P01420000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:1,420.00
# last price:119.20
# bid price:128.25
# ask price:132.15
# implied volatility:34.91%
# contract name:AMZN180615P01430000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,430.00
# last price:117.13
# bid price:133.10
# ask price:137.65
# implied volatility:34.79%
# contract name:AMZN180615P01440000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:1,440.00
# last price:130.00
# bid price:138.65
# ask price:143.65
# implied volatility:34.79%
# contract name:AMZN180615P01450000
# last_trade_date:2018-02-05 11:08AM EST
# strike price:1,450.00
# last price:105.64
# bid price:144.75
# ask price:149.75
# implied volatility:34.78%
# contract name:AMZN180615P01460000
# last_trade_date:2018-02-05 1:58PM EST
# strike price:1,460.00
# last price:116.30
# bid price:151.25
# ask price:156.25
# implied volatility:34.85%
# contract name:AMZN180615P01470000
# last_trade_date:2018-02-05 2:02PM EST
# strike price:1,470.00
# last price:123.95
# bid price:157.35
# ask price:162.25
# implied volatility:34.73%
# contract name:AMZN180615P01480000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:1,480.00
# last price:141.40
# bid price:163.65
# ask price:168.65
# implied volatility:34.69%
# contract name:AMZN180615P01490000
# last_trade_date:2018-02-05 1:55PM EST
# strike price:1,490.00
# last price:135.00
# bid price:168.85
# ask price:173.85
# implied volatility:34.25%
# contract name:AMZN180615P01500000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,500.00
# last price:160.32
# bid price:176.55
# ask price:180.70
# implied volatility:34.27%
# contract name:AMZN180615P01510000
# last_trade_date:2018-02-05 10:04PM EST
# strike price:1,510.00
# last price:166.54
# bid price:181.85
# ask price:186.85
# implied volatility:34.04%
# contract name:AMZN180615P01520000
# last_trade_date:2018-02-05 10:31AM EST
# strike price:1,520.00
# last price:147.30
# bid price:189.60
# ask price:194.25
# implied volatility:34.17%
# contract name:AMZN180615P01540000
# last_trade_date:2018-02-05 12:52PM EST
# strike price:1,540.00
# last price:161.05
# bid price:203.25
# ask price:207.90
# implied volatility:33.95%
# contract name:AMZN180615P01550000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,550.00
# last price:192.00
# bid price:209.20
# ask price:214.20
# implied volatility:33.60%
# contract name:AMZN180615P01560000
# last_trade_date:2018-02-05 3:56PM EST
# strike price:1,560.00
# last price:215.05
# bid price:217.15
# ask price:221.55
# implied volatility:33.57%
# contract name:AMZN180615P01580000
# last_trade_date:2018-02-05 10:48AM EST
# strike price:1,580.00
# last price:179.80
# bid price:231.25
# ask price:236.25
# implied volatility:33.39%
# contract name:AMZN180615P01600000
# last_trade_date:2018-02-05 3:59PM EST
# strike price:1,600.00
# last price:245.00
# bid price:247.05
# ask price:252.05
# implied volatility:33.46%
# contract name:AMZN180615P01620000
# last_trade_date:2018-01-31 10:26AM EST
# strike price:1,620.00
# last price:198.10
# bid price:224.80
# ask price:229.15
# implied volatility:0.00%
# contract name:AMZN180615P01640000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,640.00
# last price:225.26
# bid price:241.65
# ask price:245.15
# implied volatility:0.00%
# contract name:AMZN180615P01650000
# last_trade_date:2018-02-05 1:55PM EST
# strike price:1,650.00
# last price:243.50
# bid price:286.05
# ask price:291.05
# implied volatility:32.83%
# contract name:AMZN180615P01660000
# last_trade_date:2018-02-05 10:12AM EST
# strike price:1,660.00
# last price:248.40
# bid price:294.30
# ask price:299.30
# implied volatility:32.78%
# contract name:AMZN180615P01680000
# last_trade_date:2018-02-05 11:09AM EST
# strike price:1,680.00
# last price:259.35
# bid price:311.60
# ask price:316.60
# implied volatility:32.91%
# contract name:AMZN180615P01700000
# last_trade_date:2018-02-05 11:51AM EST
# strike price:1,700.00
# last price:285.85
# bid price:328.35
# ask price:333.35
# implied volatility:32.68%
# contract name:AMZN180615P01720000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,720.00
# last price:344.65
# bid price:307.40
# ask price:310.85
# implied volatility:0.00%
# contract name:AMZN180615P01760000
# last_trade_date:2018-02-05 9:38AM EST
# strike price:1,760.00
# last price:364.65
# bid price:380.65
# ask price:385.65
# implied volatility:32.11%
# contract name:AMZN180615P01780000
# last_trade_date:2018-02-05 1:35PM EST
# strike price:1,780.00
# last price:359.40
# bid price:398.75
# ask price:403.75
# implied volatility:32.02%
# contract name:AMZN180615P01800000
# last_trade_date:2018-02-05 11:41AM EST
# strike price:1,800.00
# last price:372.70
# bid price:416.95
# ask price:421.95
# implied volatility:31.86%
# contract name:AMZN180615P01820000
# last_trade_date:2018-02-05 1:35PM EST
# strike price:1,820.00
# last price:395.45
# bid price:436.10
# ask price:441.10
# implied volatility:32.24%
# contract name:AMZN180615P01840000
# last_trade_date:2018-02-05 1:35PM EST
# strike price:1,840.00
# last price:413.75
# bid price:454.60
# ask price:459.60
# implied volatility:32.06%
# contract name:AMZN180615P01850000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,850.00
# last price:427.95
# bid price:424.40
# ask price:429.40
# implied volatility:0.00%
# contract name:AMZN180615P01860000
# last_trade_date:2018-02-05 2:38PM EST
# strike price:1,860.00
# last price:431.05
# bid price:473.20
# ask price:478.20
# implied volatility:31.83%
# contract name:AMZN180615P01880000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,880.00
# last price:422.30
# bid price:452.80
# ask price:457.80
# implied volatility:0.00%
# contract name:AMZN180615P01940000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,940.00
# last price:501.50
# bid price:508.55
# ask price:513.55
# implied volatility:0.00%
# contract name:AMZN180615P01950000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,950.00
# last price:497.65
# bid price:518.40
# ask price:523.40
# implied volatility:0.00%
# contract name:AMZN180615P01980000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,980.00
# last price:524.65
# bid price:549.40
# ask price:554.40
# implied volatility:0.00%
# contract name:AMZN180615P02000000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:2,000.00
# last price:580.35
# bid price:567.30
# ask price:572.30
# implied volatility:0.00%
# contract name:AMZN180615P02050000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:2,050.00
# last price:632.75
# bid price:616.85
# ask price:621.85
# implied volatility:0.00%
# contract name:AMZN180615P02100000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:2,100.00
# last price:624.95
# bid price:666.35
# ask price:671.35
# implied volatility:0.00%

# %%
# Out:
# '900.00'

# %%
# Out:
# '519.25'
