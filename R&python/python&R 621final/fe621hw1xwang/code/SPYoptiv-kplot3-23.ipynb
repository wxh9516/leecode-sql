# %%
from bs4 import BeautifulSoup as soup

# %%
from urllib.request import urlopen as uReq

# %%
my_url = 'https://finance.yahoo.com/quote/SPY/options?p=SPY&date=1522281600'

# %%
uClient = uReq(my_url)

# %%
page_html = uClient.read()

# %%
uClient.close()

# %%
page_soup = soup(page_html,'lxml')

# %%
page_soup.body.span
# Out:
# <span data-reactid="7">Summary</span>

# %%
containers=page_soup.findAll('tbody')

# %%
calls=containers[0]

# %%
puts=containers[1]

# %%
len(containers)
# Out:
# 2

# %%
filename='SPYcalloptk-iv3-29.csv'
f=open(filename,'w')

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price,implied_volatility\n'

# %%
f.write(headers)
# Out:
# 93

# %%
for container in containers:
    for call in calls:
        
        title_container=call.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=call.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=call.findAll('td',{'class':'data-col2 Ta(end) Pstart(7px)'})
        strike_price=strike_price2[0].text
    
        lp=call.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=call.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=call.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
        
        iv=call.findAll('td',{'class':'data-col10 Ta(end) Pstart(7px) Pend(6px)'})
        iv2=iv[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
        print('implied volatility:'+iv2)
    
        f.write(contract_name+','+last_trade_date+','+strike_price.replace(',','')+','+last_price+','+bid_price+','+ask_price+','+iv2+'\n')

f.close()
# Out:
# contract name:SPY180329C00166000
# last_trade_date:2018-01-10 12:23PM EST
# strike price:166.00
# last price:108.66
# bid price:112.49
# ask price:112.79
# implied volatility:133.69%
# contract name:SPY180329C00167000
# last_trade_date:2018-01-09 12:08PM EST
# strike price:167.00
# last price:108.48
# bid price:111.49
# ask price:111.80
# implied volatility:132.48%
# contract name:SPY180329C00168000
# last_trade_date:2017-07-18 2:36PM EST
# strike price:168.00
# last price:78.15
# bid price:89.48
# ask price:89.78
# implied volatility:0.00%
# contract name:SPY180329C00169000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:169.00
# last price:71.52
# bid price:88.51
# ask price:88.78
# implied volatility:0.00%
# contract name:SPY180329C00170000
# last_trade_date:2018-01-22 3:24PM EST
# strike price:170.00
# last price:112.55
# bid price:117.06
# ask price:117.42
# implied volatility:167.90%
# contract name:SPY180329C00171000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:171.00
# last price:69.57
# bid price:86.52
# ask price:86.79
# implied volatility:0.00%
# contract name:SPY180329C00172000
# last_trade_date:2018-01-09 11:59AM EST
# strike price:172.00
# last price:103.51
# bid price:106.51
# ask price:106.82
# implied volatility:126.54%
# contract name:SPY180329C00173000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:173.00
# last price:68.74
# bid price:84.53
# ask price:84.81
# implied volatility:0.00%
# contract name:SPY180329C00174000
# last_trade_date:2018-01-09 11:59AM EST
# strike price:174.00
# last price:101.51
# bid price:104.52
# ask price:104.82
# implied volatility:124.18%
# contract name:SPY180329C00175000
# last_trade_date:2017-08-29 1:03PM EST
# strike price:175.00
# last price:69.85
# bid price:82.55
# ask price:82.82
# implied volatility:0.00%
# contract name:SPY180329C00176000
# last_trade_date:2017-10-03 10:18AM EST
# strike price:176.00
# last price:76.96
# bid price:81.53
# ask price:81.82
# implied volatility:0.00%
# contract name:SPY180329C00177000
# last_trade_date:2018-01-17 3:29PM EST
# strike price:177.00
# last price:103.40
# bid price:103.79
# ask price:104.12
# implied volatility:131.22%
# contract name:SPY180329C00178000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:178.00
# last price:64.18
# bid price:79.57
# ask price:79.84
# implied volatility:0.00%
# contract name:SPY180329C00179000
# last_trade_date:2017-11-08 1:36PM EST
# strike price:179.00
# last price:80.30
# bid price:79.15
# ask price:79.55
# implied volatility:0.00%
# contract name:SPY180329C00180000
# last_trade_date:2017-12-20 11:46AM EST
# strike price:180.00
# last price:88.31
# bid price:88.07
# ask price:88.42
# implied volatility:0.00%
# contract name:SPY180329C00181000
# last_trade_date:2017-09-14 9:39AM EST
# strike price:181.00
# last price:69.04
# bid price:76.59
# ask price:76.86
# implied volatility:0.00%
# contract name:SPY180329C00182000
# last_trade_date:2017-11-09 1:47PM EST
# strike price:182.00
# last price:75.88
# bid price:76.18
# ask price:76.57
# implied volatility:0.00%
# contract name:SPY180329C00183000
# last_trade_date:2017-10-17 10:28AM EST
# strike price:183.00
# last price:72.87
# bid price:74.61
# ask price:74.88
# implied volatility:0.00%
# contract name:SPY180329C00184000
# last_trade_date:2017-07-17 10:38AM EST
# strike price:184.00
# last price:62.38
# bid price:73.62
# ask price:73.89
# implied volatility:0.00%
# contract name:SPY180329C00185000
# last_trade_date:2017-09-14 9:38AM EST
# strike price:185.00
# last price:65.05
# bid price:72.63
# ask price:72.90
# implied volatility:0.00%
# contract name:SPY180329C00186000
# last_trade_date:2017-06-29 9:01AM EST
# strike price:186.00
# last price:58.11
# bid price:71.64
# ask price:71.91
# implied volatility:0.00%
# contract name:SPY180329C00187000
# last_trade_date:2017-11-02 2:21PM EST
# strike price:187.00
# last price:70.59
# bid price:71.57
# ask price:71.91
# implied volatility:0.00%
# contract name:SPY180329C00188000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:188.00
# last price:54.57
# bid price:69.67
# ask price:69.93
# implied volatility:0.00%
# contract name:SPY180329C00189000
# last_trade_date:2017-06-29 9:01AM EST
# strike price:189.00
# last price:55.27
# bid price:68.68
# ask price:68.95
# implied volatility:0.00%
# contract name:SPY180329C00190000
# last_trade_date:2018-01-11 3:35PM EST
# strike price:190.00
# last price:86.32
# bid price:88.59
# ask price:88.88
# implied volatility:106.25%
# contract name:SPY180329C00191000
# last_trade_date:2017-11-08 12:12PM EST
# strike price:191.00
# last price:67.99
# bid price:67.27
# ask price:67.65
# implied volatility:0.00%
# contract name:SPY180329C00192000
# last_trade_date:2017-12-15 10:45AM EST
# strike price:192.00
# last price:75.25
# bid price:75.99
# ask price:76.33
# implied volatility:0.00%
# contract name:SPY180329C00193000
# last_trade_date:2017-11-08 12:14PM EST
# strike price:193.00
# last price:66.05
# bid price:65.30
# ask price:65.68
# implied volatility:0.00%
# contract name:SPY180329C00194000
# last_trade_date:2017-11-03 2:42PM EST
# strike price:194.00
# last price:64.84
# bid price:64.64
# ask price:64.98
# implied volatility:0.00%
# contract name:SPY180329C00195000
# last_trade_date:2017-11-03 2:43PM EST
# strike price:195.00
# last price:63.86
# bid price:63.64
# ask price:63.98
# implied volatility:0.00%
# contract name:SPY180329C00196000
# last_trade_date:2018-01-29 2:41PM EST
# strike price:196.00
# last price:90.00
# bid price:79.73
# ask price:80.13
# implied volatility:87.37%
# contract name:SPY180329C00197000
# last_trade_date:2017-11-08 12:12PM EST
# strike price:197.00
# last price:62.09
# bid price:61.36
# ask price:61.74
# implied volatility:0.00%
# contract name:SPY180329C00198000
# last_trade_date:2017-12-11 2:01PM EST
# strike price:198.00
# last price:68.31
# bid price:70.06
# ask price:70.39
# implied volatility:0.00%
# contract name:SPY180329C00199000
# last_trade_date:2017-12-14 11:19AM EST
# strike price:199.00
# last price:67.69
# bid price:69.07
# ask price:69.40
# implied volatility:0.00%
# contract name:SPY180329C00200000
# last_trade_date:2018-02-02 3:55PM EST
# strike price:200.00
# last price:76.36
# bid price:75.75
# ask price:76.15
# implied volatility:83.52%
# contract name:SPY180329C00201000
# last_trade_date:2017-11-03 2:44PM EST
# strike price:201.00
# last price:57.95
# bid price:57.75
# ask price:58.09
# implied volatility:0.00%
# contract name:SPY180329C00202000
# last_trade_date:2017-12-20 9:48AM EST
# strike price:202.00
# last price:66.50
# bid price:66.27
# ask price:66.61
# implied volatility:0.00%
# contract name:SPY180329C00203000
# last_trade_date:2017-12-13 12:15PM EST
# strike price:203.00
# last price:64.19
# bid price:65.12
# ask price:65.45
# implied volatility:0.00%
# contract name:SPY180329C00204000
# last_trade_date:2017-10-03 10:00AM EST
# strike price:204.00
# last price:49.63
# bid price:53.96
# ask price:54.21
# implied volatility:0.00%
# contract name:SPY180329C00205000
# last_trade_date:2018-01-04 12:28PM EST
# strike price:205.00
# last price:67.47
# bid price:69.18
# ask price:69.46
# implied volatility:71.27%
# contract name:SPY180329C00206000
# last_trade_date:2017-07-20 9:11AM EST
# strike price:206.00
# last price:42.91
# bid price:52.01
# ask price:52.26
# implied volatility:0.00%
# contract name:SPY180329C00207000
# last_trade_date:2017-11-20 10:36AM EST
# strike price:207.00
# last price:51.78
# bid price:53.59
# ask price:53.93
# implied volatility:0.00%
# contract name:SPY180329C00208000
# last_trade_date:2017-11-08 2:34PM EST
# strike price:208.00
# last price:51.66
# bid price:50.63
# ask price:50.99
# implied volatility:0.00%
# contract name:SPY180329C00209000
# last_trade_date:2017-06-29 9:00AM EST
# strike price:209.00
# last price:36.89
# bid price:49.10
# ask price:49.35
# implied volatility:0.00%
# contract name:SPY180329C00210000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:210.00
# last price:60.30
# bid price:52.54
# ask price:54.11
# implied volatility:0.00%
# contract name:SPY180329C00211000
# last_trade_date:2017-07-20 8:34AM EST
# strike price:211.00
# last price:38.39
# bid price:47.15
# ask price:47.40
# implied volatility:0.00%
# contract name:SPY180329C00212000
# last_trade_date:2017-12-22 11:51PM EST
# strike price:212.00
# last price:56.86
# bid price:56.41
# ask price:56.75
# implied volatility:0.00%
# contract name:SPY180329C00213000
# last_trade_date:2018-01-04 3:46PM EST
# strike price:213.00
# last price:59.65
# bid price:61.23
# ask price:61.53
# implied volatility:64.38%
# contract name:SPY180329C00214000
# last_trade_date:2017-12-06 3:57PM EST
# strike price:214.00
# last price:49.72
# bid price:50.57
# ask price:50.91
# implied volatility:0.00%
# contract name:SPY180329C00215000
# last_trade_date:2018-01-17 12:17PM EST
# strike price:215.00
# last price:64.39
# bid price:66.00
# ask price:66.35
# implied volatility:88.65%
# contract name:SPY180329C00216000
# last_trade_date:2017-12-04 12:19PM EST
# strike price:216.00
# last price:50.44
# bid price:48.49
# ask price:48.85
# implied volatility:0.00%
# contract name:SPY180329C00217000
# last_trade_date:2018-02-06 10:31AM EST
# strike price:217.00
# last price:50.02
# bid price:52.29
# ask price:54.21
# implied volatility:45.04%
# contract name:SPY180329C00218000
# last_trade_date:2018-02-06 10:06AM EST
# strike price:218.00
# last price:51.00
# bid price:51.42
# ask price:53.23
# implied volatility:44.45%
# contract name:SPY180329C00219000
# last_trade_date:2017-09-11 2:04PM EST
# strike price:219.00
# last price:32.15
# bid price:39.48
# ask price:39.72
# implied volatility:0.00%
# contract name:SPY180329C00220000
# last_trade_date:2018-02-06 9:48AM EST
# strike price:220.00
# last price:46.44
# bid price:49.37
# ask price:51.35
# implied volatility:43.69%
# contract name:SPY180329C00221000
# last_trade_date:2018-02-06 10:37AM EST
# strike price:221.00
# last price:45.63
# bid price:48.46
# ask price:50.40
# implied volatility:43.24%
# contract name:SPY180329C00222000
# last_trade_date:2018-02-06 10:37AM EST
# strike price:222.00
# last price:44.73
# bid price:47.55
# ask price:49.43
# implied volatility:42.68%
# contract name:SPY180329C00223000
# last_trade_date:2018-02-06 10:37AM EST
# strike price:223.00
# last price:43.82
# bid price:46.63
# ask price:48.46
# implied volatility:42.10%
# contract name:SPY180329C00224000
# last_trade_date:2017-07-17 9:46AM EST
# strike price:224.00
# last price:25.61
# bid price:34.77
# ask price:34.99
# implied volatility:0.00%
# contract name:SPY180329C00225000
# last_trade_date:2018-02-06 9:31AM EST
# strike price:225.00
# last price:38.32
# bid price:39.67
# ask price:39.97
# implied volatility:0.00%
# contract name:SPY180329C00226000
# last_trade_date:2018-02-06 10:32AM EST
# strike price:226.00
# last price:41.21
# bid price:43.72
# ask price:45.49
# implied volatility:40.05%
# contract name:SPY180329C00227000
# last_trade_date:2018-02-06 11:34AM EST
# strike price:227.00
# last price:38.84
# bid price:42.74
# ask price:44.60
# implied volatility:39.88%
# contract name:SPY180329C00228000
# last_trade_date:2018-02-06 11:34AM EST
# strike price:228.00
# last price:37.94
# bid price:41.77
# ask price:43.57
# implied volatility:38.99%
# contract name:SPY180329C00229000
# last_trade_date:2018-02-06 11:34AM EST
# strike price:229.00
# last price:37.01
# bid price:40.78
# ask price:42.67
# implied volatility:38.75%
# contract name:SPY180329C00230000
# last_trade_date:2017-06-16 11:57AM EST
# strike price:230.00
# last price:19.63
# bid price:19.80
# ask price:19.93
# implied volatility:0.00%
# contract name:SPY180329C00231000
# last_trade_date:2018-02-06 10:25AM EST
# strike price:231.00
# last price:36.45
# bid price:38.93
# ask price:40.68
# implied volatility:37.31%
# contract name:SPY180329C00232000
# last_trade_date:2018-02-06 2:09PM EST
# strike price:232.00
# last price:34.23
# bid price:38.02
# ask price:39.71
# implied volatility:36.70%
# contract name:SPY180329C00233000
# last_trade_date:2018-02-06 1:50PM EST
# strike price:233.00
# last price:34.20
# bid price:37.02
# ask price:38.77
# implied volatility:36.23%
# contract name:SPY180329C00234000
# last_trade_date:2018-02-06 10:02AM EST
# strike price:234.00
# last price:34.86
# bid price:36.11
# ask price:37.88
# implied volatility:35.99%
# contract name:SPY180329C00235000
# last_trade_date:2018-02-06 11:07AM EST
# strike price:235.00
# last price:33.14
# bid price:35.14
# ask price:36.85
# implied volatility:35.10%
# contract name:SPY180329C00236000
# last_trade_date:2018-02-06 11:07AM EST
# strike price:236.00
# last price:32.26
# bid price:34.21
# ask price:35.97
# implied volatility:34.86%
# contract name:SPY180329C00237000
# last_trade_date:2018-02-06 9:41AM EST
# strike price:237.00
# last price:30.43
# bid price:33.22
# ask price:35.02
# implied volatility:34.31%
# contract name:SPY180329C00238000
# last_trade_date:2018-02-06 9:40AM EST
# strike price:238.00
# last price:29.65
# bid price:32.30
# ask price:34.07
# implied volatility:33.77%
# contract name:SPY180329C00239000
# last_trade_date:2018-02-06 2:54PM EST
# strike price:239.00
# last price:29.79
# bid price:31.57
# ask price:33.12
# implied volatility:33.20%
# contract name:SPY180329C00240000
# last_trade_date:2018-02-06 2:54PM EST
# strike price:240.00
# last price:28.87
# bid price:30.51
# ask price:32.11
# implied volatility:32.39%
# contract name:SPY180329C00241000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:241.00
# last price:27.23
# bid price:29.75
# ask price:31.23
# implied volatility:32.09%
# contract name:SPY180329C00242000
# last_trade_date:2018-02-06 3:33PM EST
# strike price:242.00
# last price:29.32
# bid price:28.82
# ask price:30.22
# implied volatility:31.28%
# contract name:SPY180329C00243000
# last_trade_date:2018-02-06 3:38PM EST
# strike price:243.00
# last price:28.98
# bid price:27.90
# ask price:29.35
# implied volatility:30.99%
# contract name:SPY180329C00244000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:244.00
# last price:28.28
# bid price:27.47
# ask price:27.75
# implied volatility:27.87%
# contract name:SPY180329C00245000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:245.00
# last price:26.98
# bid price:26.57
# ask price:26.82
# implied volatility:27.38%
# contract name:SPY180329C00246000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:246.00
# last price:26.07
# bid price:25.62
# ask price:25.90
# implied volatility:26.93%
# contract name:SPY180329C00247000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:247.00
# last price:25.51
# bid price:24.70
# ask price:24.98
# implied volatility:26.45%
# contract name:SPY180329C00248000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:248.00
# last price:24.10
# bid price:23.79
# ask price:24.07
# implied volatility:26.00%
# contract name:SPY180329C00249000
# last_trade_date:2018-02-06 3:33PM EST
# strike price:249.00
# last price:23.07
# bid price:22.88
# ask price:23.16
# implied volatility:25.54%
# contract name:SPY180329C00250000
# last_trade_date:2018-02-06 3:10PM EST
# strike price:250.00
# last price:22.10
# bid price:21.98
# ask price:22.26
# implied volatility:25.09%
# contract name:SPY180329C00251000
# last_trade_date:2018-02-06 3:11PM EST
# strike price:251.00
# last price:20.91
# bid price:21.08
# ask price:21.36
# implied volatility:24.62%
# contract name:SPY180329C00252000
# last_trade_date:2018-02-06 3:10PM EST
# strike price:252.00
# last price:20.31
# bid price:20.19
# ask price:20.47
# implied volatility:24.17%
# contract name:SPY180329C00253000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:253.00
# last price:19.52
# bid price:19.31
# ask price:19.59
# implied volatility:23.74%
# contract name:SPY180329C00254000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:254.00
# last price:18.65
# bid price:18.44
# ask price:18.71
# implied volatility:23.28%
# contract name:SPY180329C00255000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:255.00
# last price:17.80
# bid price:17.59
# ask price:17.85
# implied volatility:22.86%
# contract name:SPY180329C00256000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:256.00
# last price:16.96
# bid price:16.75
# ask price:16.99
# implied volatility:22.42%
# contract name:SPY180329C00257000
# last_trade_date:2018-02-06 3:35PM EST
# strike price:257.00
# last price:15.99
# bid price:15.88
# ask price:16.15
# implied volatility:22.01%
# contract name:SPY180329C00258000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:258.00
# last price:15.30
# bid price:15.05
# ask price:15.31
# implied volatility:21.58%
# contract name:SPY180329C00259000
# last_trade_date:2018-02-06 3:35PM EST
# strike price:259.00
# last price:14.36
# bid price:14.27
# ask price:14.49
# implied volatility:21.17%
# contract name:SPY180329C00260000
# last_trade_date:2018-02-06 2:35PM EST
# strike price:260.00
# last price:11.31
# bid price:13.46
# ask price:13.68
# implied volatility:20.76%
# contract name:SPY180329C00261000
# last_trade_date:2018-02-06 10:11AM EST
# strike price:261.00
# last price:11.39
# bid price:12.67
# ask price:12.89
# implied volatility:20.38%
# contract name:SPY180329C00262000
# last_trade_date:2018-02-06 12:17PM EST
# strike price:262.00
# last price:9.70
# bid price:11.89
# ask price:12.12
# implied volatility:20.01%
# contract name:SPY180329C00263000
# last_trade_date:2018-02-06 1:02PM EST
# strike price:263.00
# last price:9.65
# bid price:11.14
# ask price:11.36
# implied volatility:19.64%
# contract name:SPY180329C00264000
# last_trade_date:2018-02-06 3:35PM EST
# strike price:264.00
# last price:10.68
# bid price:10.40
# ask price:10.62
# implied volatility:19.27%
# contract name:SPY180329C00265000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:265.00
# last price:9.36
# bid price:9.68
# ask price:9.90
# implied volatility:18.92%
# contract name:SPY180329C00266000
# last_trade_date:2018-02-06 4:01PM EST
# strike price:266.00
# last price:9.65
# bid price:8.98
# ask price:9.20
# implied volatility:18.57%
# contract name:SPY180329C00267000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:267.00
# last price:8.41
# bid price:8.29
# ask price:8.52
# implied volatility:18.24%
# contract name:SPY180329C00268000
# last_trade_date:2018-02-06 3:55PM EST
# strike price:268.00
# last price:7.72
# bid price:7.65
# ask price:7.89
# implied volatility:17.97%
# contract name:SPY180329C00269000
# last_trade_date:2018-02-06 3:41PM EST
# strike price:269.00
# last price:7.90
# bid price:7.02
# ask price:7.24
# implied volatility:17.60%
# contract name:SPY180329C00270000
# last_trade_date:2018-02-06 4:00PM EST
# strike price:270.00
# last price:6.82
# bid price:6.42
# ask price:6.66
# implied volatility:17.36%
# contract name:SPY180329C00271000
# last_trade_date:2018-02-06 3:21PM EST
# strike price:271.00
# last price:5.39
# bid price:5.84
# ask price:6.09
# implied volatility:17.08%
# contract name:SPY180329C00272000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:272.00
# last price:5.72
# bid price:5.32
# ask price:5.53
# implied volatility:16.77%
# contract name:SPY180329C00273000
# last_trade_date:2018-02-06 4:14PM EST
# strike price:273.00
# last price:5.15
# bid price:4.80
# ask price:5.03
# implied volatility:16.55%
# contract name:SPY180329C00274000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:274.00
# last price:4.70
# bid price:4.33
# ask price:4.56
# implied volatility:16.34%
# contract name:SPY180329C00275000
# last_trade_date:2018-02-06 4:01PM EST
# strike price:275.00
# last price:4.48
# bid price:3.90
# ask price:4.11
# implied volatility:16.12%
# contract name:SPY180329C00276000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:276.00
# last price:3.80
# bid price:3.51
# ask price:3.73
# implied volatility:16.02%
# contract name:SPY180329C00277000
# last_trade_date:2018-02-06 3:27PM EST
# strike price:277.00
# last price:2.96
# bid price:3.15
# ask price:3.37
# implied volatility:15.90%
# contract name:SPY180329C00278000
# last_trade_date:2018-02-06 3:41PM EST
# strike price:278.00
# last price:3.62
# bid price:2.83
# ask price:3.04
# implied volatility:15.81%
# contract name:SPY180329C00279000
# last_trade_date:2018-02-06 1:45PM EST
# strike price:279.00
# last price:1.77
# bid price:2.54
# ask price:2.74
# implied volatility:15.74%
# contract name:SPY180329C00280000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:280.00
# last price:2.92
# bid price:2.28
# ask price:2.46
# implied volatility:15.66%
# contract name:SPY180329C00281000
# last_trade_date:2018-02-06 3:49PM EST
# strike price:281.00
# last price:2.65
# bid price:2.10
# ask price:2.24
# implied volatility:15.71%
# contract name:SPY180329C00282000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:282.00
# last price:2.48
# bid price:1.91
# ask price:2.05
# implied volatility:15.79%
# contract name:SPY180329C00283000
# last_trade_date:2018-02-06 3:49PM EST
# strike price:283.00
# last price:2.30
# bid price:1.73
# ask price:1.88
# implied volatility:15.90%
# contract name:SPY180329C00284000
# last_trade_date:2018-02-06 3:49PM EST
# strike price:284.00
# last price:2.14
# bid price:1.58
# ask price:1.72
# implied volatility:15.99%
# contract name:SPY180329C00285000
# last_trade_date:2018-02-06 4:12PM EST
# strike price:285.00
# last price:1.60
# bid price:1.44
# ask price:1.60
# implied volatility:16.19%
# contract name:SPY180329C00286000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:286.00
# last price:1.64
# bid price:1.32
# ask price:1.48
# implied volatility:16.35%
# contract name:SPY180329C00287000
# last_trade_date:2018-02-06 3:50PM EST
# strike price:287.00
# last price:1.79
# bid price:1.21
# ask price:1.37
# implied volatility:16.50%
# contract name:SPY180329C00288000
# last_trade_date:2018-02-06 3:55PM EST
# strike price:288.00
# last price:1.58
# bid price:1.11
# ask price:1.28
# implied volatility:16.71%
# contract name:SPY180329C00289000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:289.00
# last price:1.57
# bid price:1.02
# ask price:1.20
# implied volatility:16.93%
# contract name:SPY180329C00290000
# last_trade_date:2018-02-06 4:09PM EST
# strike price:290.00
# last price:1.20
# bid price:0.94
# ask price:1.12
# implied volatility:17.13%
# contract name:SPY180329C00291000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:291.00
# last price:1.38
# bid price:0.87
# ask price:1.04
# implied volatility:17.29%
# contract name:SPY180329C00292000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:292.00
# last price:1.20
# bid price:0.80
# ask price:0.99
# implied volatility:17.57%
# contract name:SPY180329C00293000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:293.00
# last price:1.23
# bid price:0.74
# ask price:0.92
# implied volatility:17.73%
# contract name:SPY180329C00294000
# last_trade_date:2018-02-06 3:53PM EST
# strike price:294.00
# last price:1.16
# bid price:0.68
# ask price:0.87
# implied volatility:17.96%
# contract name:SPY180329C00295000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:295.00
# last price:0.91
# bid price:0.63
# ask price:0.82
# implied volatility:18.18%
# contract name:SPY180329C00296000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:296.00
# last price:0.96
# bid price:0.58
# ask price:0.78
# implied volatility:18.43%
# contract name:SPY180329C00297000
# last_trade_date:2018-02-06 2:40PM EST
# strike price:297.00
# last price:0.38
# bid price:0.53
# ask price:0.73
# implied volatility:18.60%
# contract name:SPY180329C00299000
# last_trade_date:2018-02-06 10:47AM EST
# strike price:299.00
# last price:0.04
# bid price:0.45
# ask price:0.65
# implied volatility:19.02%
# contract name:SPY180329C00300000
# last_trade_date:2018-02-06 3:56PM EST
# strike price:300.00
# last price:0.72
# bid price:0.42
# ask price:0.62
# implied volatility:19.26%
# contract name:SPY180329C00301000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:301.00
# last price:0.77
# bid price:0.39
# ask price:0.58
# implied volatility:19.41%
# contract name:SPY180329C00302000
# last_trade_date:2018-02-06 3:33PM EST
# strike price:302.00
# last price:0.44
# bid price:0.36
# ask price:0.55
# implied volatility:19.63%
# contract name:SPY180329C00303000
# last_trade_date:2018-02-02 11:20AM EST
# strike price:303.00
# last price:0.10
# bid price:0.05
# ask price:0.08
# implied volatility:14.36%
# contract name:SPY180329C00304000
# last_trade_date:2018-01-26 11:45PM EST
# strike price:304.00
# last price:0.33
# bid price:0.31
# ask price:0.33
# implied volatility:18.48%
# contract name:SPY180329C00305000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:305.00
# last price:0.55
# bid price:0.28
# ask price:0.46
# implied volatility:20.15%
# contract name:SPY180329C00306000
# last_trade_date:2018-02-02 11:45PM EST
# strike price:306.00
# last price:0.13
# bid price:0.04
# ask price:0.07
# implied volatility:15.09%
# contract name:SPY180329C00307000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:307.00
# last price:0.20
# bid price:0.23
# ask price:0.41
# implied volatility:20.51%
# contract name:SPY180329C00308000
# last_trade_date:2018-02-06 3:09PM EST
# strike price:308.00
# last price:0.18
# bid price:0.21
# ask price:0.39
# implied volatility:20.70%
# contract name:SPY180329C00309000
# last_trade_date:2018-01-30 9:55AM EST
# strike price:309.00
# last price:0.11
# bid price:0.02
# ask price:0.06
# implied volatility:15.77%
# contract name:SPY180329C00310000
# last_trade_date:2018-02-02 11:45PM EST
# strike price:310.00
# last price:0.08
# bid price:0.02
# ask price:0.06
# implied volatility:16.11%
# contract name:SPY180329C00166000
# last_trade_date:2018-01-10 12:23PM EST
# strike price:166.00
# last price:108.66
# bid price:112.49
# ask price:112.79
# implied volatility:133.69%
# contract name:SPY180329C00167000
# last_trade_date:2018-01-09 12:08PM EST
# strike price:167.00
# last price:108.48
# bid price:111.49
# ask price:111.80
# implied volatility:132.48%
# contract name:SPY180329C00168000
# last_trade_date:2017-07-18 2:36PM EST
# strike price:168.00
# last price:78.15
# bid price:89.48
# ask price:89.78
# implied volatility:0.00%
# contract name:SPY180329C00169000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:169.00
# last price:71.52
# bid price:88.51
# ask price:88.78
# implied volatility:0.00%
# contract name:SPY180329C00170000
# last_trade_date:2018-01-22 3:24PM EST
# strike price:170.00
# last price:112.55
# bid price:117.06
# ask price:117.42
# implied volatility:167.90%
# contract name:SPY180329C00171000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:171.00
# last price:69.57
# bid price:86.52
# ask price:86.79
# implied volatility:0.00%
# contract name:SPY180329C00172000
# last_trade_date:2018-01-09 11:59AM EST
# strike price:172.00
# last price:103.51
# bid price:106.51
# ask price:106.82
# implied volatility:126.54%
# contract name:SPY180329C00173000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:173.00
# last price:68.74
# bid price:84.53
# ask price:84.81
# implied volatility:0.00%
# contract name:SPY180329C00174000
# last_trade_date:2018-01-09 11:59AM EST
# strike price:174.00
# last price:101.51
# bid price:104.52
# ask price:104.82
# implied volatility:124.18%
# contract name:SPY180329C00175000
# last_trade_date:2017-08-29 1:03PM EST
# strike price:175.00
# last price:69.85
# bid price:82.55
# ask price:82.82
# implied volatility:0.00%
# contract name:SPY180329C00176000
# last_trade_date:2017-10-03 10:18AM EST
# strike price:176.00
# last price:76.96
# bid price:81.53
# ask price:81.82
# implied volatility:0.00%
# contract name:SPY180329C00177000
# last_trade_date:2018-01-17 3:29PM EST
# strike price:177.00
# last price:103.40
# bid price:103.79
# ask price:104.12
# implied volatility:131.22%
# contract name:SPY180329C00178000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:178.00
# last price:64.18
# bid price:79.57
# ask price:79.84
# implied volatility:0.00%
# contract name:SPY180329C00179000
# last_trade_date:2017-11-08 1:36PM EST
# strike price:179.00
# last price:80.30
# bid price:79.15
# ask price:79.55
# implied volatility:0.00%
# contract name:SPY180329C00180000
# last_trade_date:2017-12-20 11:46AM EST
# strike price:180.00
# last price:88.31
# bid price:88.07
# ask price:88.42
# implied volatility:0.00%
# contract name:SPY180329C00181000
# last_trade_date:2017-09-14 9:39AM EST
# strike price:181.00
# last price:69.04
# bid price:76.59
# ask price:76.86
# implied volatility:0.00%
# contract name:SPY180329C00182000
# last_trade_date:2017-11-09 1:47PM EST
# strike price:182.00
# last price:75.88
# bid price:76.18
# ask price:76.57
# implied volatility:0.00%
# contract name:SPY180329C00183000
# last_trade_date:2017-10-17 10:28AM EST
# strike price:183.00
# last price:72.87
# bid price:74.61
# ask price:74.88
# implied volatility:0.00%
# contract name:SPY180329C00184000
# last_trade_date:2017-07-17 10:38AM EST
# strike price:184.00
# last price:62.38
# bid price:73.62
# ask price:73.89
# implied volatility:0.00%
# contract name:SPY180329C00185000
# last_trade_date:2017-09-14 9:38AM EST
# strike price:185.00
# last price:65.05
# bid price:72.63
# ask price:72.90
# implied volatility:0.00%
# contract name:SPY180329C00186000
# last_trade_date:2017-06-29 9:01AM EST
# strike price:186.00
# last price:58.11
# bid price:71.64
# ask price:71.91
# implied volatility:0.00%
# contract name:SPY180329C00187000
# last_trade_date:2017-11-02 2:21PM EST
# strike price:187.00
# last price:70.59
# bid price:71.57
# ask price:71.91
# implied volatility:0.00%
# contract name:SPY180329C00188000
# last_trade_date:2017-06-02 10:46PM EST
# strike price:188.00
# last price:54.57
# bid price:69.67
# ask price:69.93
# implied volatility:0.00%
# contract name:SPY180329C00189000
# last_trade_date:2017-06-29 9:01AM EST
# strike price:189.00
# last price:55.27
# bid price:68.68
# ask price:68.95
# implied volatility:0.00%
# contract name:SPY180329C00190000
# last_trade_date:2018-01-11 3:35PM EST
# strike price:190.00
# last price:86.32
# bid price:88.59
# ask price:88.88
# implied volatility:106.25%
# contract name:SPY180329C00191000
# last_trade_date:2017-11-08 12:12PM EST
# strike price:191.00
# last price:67.99
# bid price:67.27
# ask price:67.65
# implied volatility:0.00%
# contract name:SPY180329C00192000
# last_trade_date:2017-12-15 10:45AM EST
# strike price:192.00
# last price:75.25
# bid price:75.99
# ask price:76.33
# implied volatility:0.00%
# contract name:SPY180329C00193000
# last_trade_date:2017-11-08 12:14PM EST
# strike price:193.00
# last price:66.05
# bid price:65.30
# ask price:65.68
# implied volatility:0.00%
# contract name:SPY180329C00194000
# last_trade_date:2017-11-03 2:42PM EST
# strike price:194.00
# last price:64.84
# bid price:64.64
# ask price:64.98
# implied volatility:0.00%
# contract name:SPY180329C00195000
# last_trade_date:2017-11-03 2:43PM EST
# strike price:195.00
# last price:63.86
# bid price:63.64
# ask price:63.98
# implied volatility:0.00%
# contract name:SPY180329C00196000
# last_trade_date:2018-01-29 2:41PM EST
# strike price:196.00
# last price:90.00
# bid price:79.73
# ask price:80.13
# implied volatility:87.37%
# contract name:SPY180329C00197000
# last_trade_date:2017-11-08 12:12PM EST
# strike price:197.00
# last price:62.09
# bid price:61.36
# ask price:61.74
# implied volatility:0.00%
# contract name:SPY180329C00198000
# last_trade_date:2017-12-11 2:01PM EST
# strike price:198.00
# last price:68.31
# bid price:70.06
# ask price:70.39
# implied volatility:0.00%
# contract name:SPY180329C00199000
# last_trade_date:2017-12-14 11:19AM EST
# strike price:199.00
# last price:67.69
# bid price:69.07
# ask price:69.40
# implied volatility:0.00%
# contract name:SPY180329C00200000
# last_trade_date:2018-02-02 3:55PM EST
# strike price:200.00
# last price:76.36
# bid price:75.75
# ask price:76.15
# implied volatility:83.52%
# contract name:SPY180329C00201000
# last_trade_date:2017-11-03 2:44PM EST
# strike price:201.00
# last price:57.95
# bid price:57.75
# ask price:58.09
# implied volatility:0.00%
# contract name:SPY180329C00202000
# last_trade_date:2017-12-20 9:48AM EST
# strike price:202.00
# last price:66.50
# bid price:66.27
# ask price:66.61
# implied volatility:0.00%
# contract name:SPY180329C00203000
# last_trade_date:2017-12-13 12:15PM EST
# strike price:203.00
# last price:64.19
# bid price:65.12
# ask price:65.45
# implied volatility:0.00%
# contract name:SPY180329C00204000
# last_trade_date:2017-10-03 10:00AM EST
# strike price:204.00
# last price:49.63
# bid price:53.96
# ask price:54.21
# implied volatility:0.00%
# contract name:SPY180329C00205000
# last_trade_date:2018-01-04 12:28PM EST
# strike price:205.00
# last price:67.47
# bid price:69.18
# ask price:69.46
# implied volatility:71.27%
# contract name:SPY180329C00206000
# last_trade_date:2017-07-20 9:11AM EST
# strike price:206.00
# last price:42.91
# bid price:52.01
# ask price:52.26
# implied volatility:0.00%
# contract name:SPY180329C00207000
# last_trade_date:2017-11-20 10:36AM EST
# strike price:207.00
# last price:51.78
# bid price:53.59
# ask price:53.93
# implied volatility:0.00%
# contract name:SPY180329C00208000
# last_trade_date:2017-11-08 2:34PM EST
# strike price:208.00
# last price:51.66
# bid price:50.63
# ask price:50.99
# implied volatility:0.00%
# contract name:SPY180329C00209000
# last_trade_date:2017-06-29 9:00AM EST
# strike price:209.00
# last price:36.89
# bid price:49.10
# ask price:49.35
# implied volatility:0.00%
# contract name:SPY180329C00210000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:210.00
# last price:60.30
# bid price:52.54
# ask price:54.11
# implied volatility:0.00%
# contract name:SPY180329C00211000
# last_trade_date:2017-07-20 8:34AM EST
# strike price:211.00
# last price:38.39
# bid price:47.15
# ask price:47.40
# implied volatility:0.00%
# contract name:SPY180329C00212000
# last_trade_date:2017-12-22 11:51PM EST
# strike price:212.00
# last price:56.86
# bid price:56.41
# ask price:56.75
# implied volatility:0.00%
# contract name:SPY180329C00213000
# last_trade_date:2018-01-04 3:46PM EST
# strike price:213.00
# last price:59.65
# bid price:61.23
# ask price:61.53
# implied volatility:64.38%
# contract name:SPY180329C00214000
# last_trade_date:2017-12-06 3:57PM EST
# strike price:214.00
# last price:49.72
# bid price:50.57
# ask price:50.91
# implied volatility:0.00%
# contract name:SPY180329C00215000
# last_trade_date:2018-01-17 12:17PM EST
# strike price:215.00
# last price:64.39
# bid price:66.00
# ask price:66.35
# implied volatility:88.65%
# contract name:SPY180329C00216000
# last_trade_date:2017-12-04 12:19PM EST
# strike price:216.00
# last price:50.44
# bid price:48.49
# ask price:48.85
# implied volatility:0.00%
# contract name:SPY180329C00217000
# last_trade_date:2018-02-06 10:31AM EST
# strike price:217.00
# last price:50.02
# bid price:52.29
# ask price:54.21
# implied volatility:45.04%
# contract name:SPY180329C00218000
# last_trade_date:2018-02-06 10:06AM EST
# strike price:218.00
# last price:51.00
# bid price:51.42
# ask price:53.23
# implied volatility:44.45%
# contract name:SPY180329C00219000
# last_trade_date:2017-09-11 2:04PM EST
# strike price:219.00
# last price:32.15
# bid price:39.48
# ask price:39.72
# implied volatility:0.00%
# contract name:SPY180329C00220000
# last_trade_date:2018-02-06 9:48AM EST
# strike price:220.00
# last price:46.44
# bid price:49.37
# ask price:51.35
# implied volatility:43.69%
# contract name:SPY180329C00221000
# last_trade_date:2018-02-06 10:37AM EST
# strike price:221.00
# last price:45.63
# bid price:48.46
# ask price:50.40
# implied volatility:43.24%
# contract name:SPY180329C00222000
# last_trade_date:2018-02-06 10:37AM EST
# strike price:222.00
# last price:44.73
# bid price:47.55
# ask price:49.43
# implied volatility:42.68%
# contract name:SPY180329C00223000
# last_trade_date:2018-02-06 10:37AM EST
# strike price:223.00
# last price:43.82
# bid price:46.63
# ask price:48.46
# implied volatility:42.10%
# contract name:SPY180329C00224000
# last_trade_date:2017-07-17 9:46AM EST
# strike price:224.00
# last price:25.61
# bid price:34.77
# ask price:34.99
# implied volatility:0.00%
# contract name:SPY180329C00225000
# last_trade_date:2018-02-06 9:31AM EST
# strike price:225.00
# last price:38.32
# bid price:39.67
# ask price:39.97
# implied volatility:0.00%
# contract name:SPY180329C00226000
# last_trade_date:2018-02-06 10:32AM EST
# strike price:226.00
# last price:41.21
# bid price:43.72
# ask price:45.49
# implied volatility:40.05%
# contract name:SPY180329C00227000
# last_trade_date:2018-02-06 11:34AM EST
# strike price:227.00
# last price:38.84
# bid price:42.74
# ask price:44.60
# implied volatility:39.88%
# contract name:SPY180329C00228000
# last_trade_date:2018-02-06 11:34AM EST
# strike price:228.00
# last price:37.94
# bid price:41.77
# ask price:43.57
# implied volatility:38.99%
# contract name:SPY180329C00229000
# last_trade_date:2018-02-06 11:34AM EST
# strike price:229.00
# last price:37.01
# bid price:40.78
# ask price:42.67
# implied volatility:38.75%
# contract name:SPY180329C00230000
# last_trade_date:2017-06-16 11:57AM EST
# strike price:230.00
# last price:19.63
# bid price:19.80
# ask price:19.93
# implied volatility:0.00%
# contract name:SPY180329C00231000
# last_trade_date:2018-02-06 10:25AM EST
# strike price:231.00
# last price:36.45
# bid price:38.93
# ask price:40.68
# implied volatility:37.31%
# contract name:SPY180329C00232000
# last_trade_date:2018-02-06 2:09PM EST
# strike price:232.00
# last price:34.23
# bid price:38.02
# ask price:39.71
# implied volatility:36.70%
# contract name:SPY180329C00233000
# last_trade_date:2018-02-06 1:50PM EST
# strike price:233.00
# last price:34.20
# bid price:37.02
# ask price:38.77
# implied volatility:36.23%
# contract name:SPY180329C00234000
# last_trade_date:2018-02-06 10:02AM EST
# strike price:234.00
# last price:34.86
# bid price:36.11
# ask price:37.88
# implied volatility:35.99%
# contract name:SPY180329C00235000
# last_trade_date:2018-02-06 11:07AM EST
# strike price:235.00
# last price:33.14
# bid price:35.14
# ask price:36.85
# implied volatility:35.10%
# contract name:SPY180329C00236000
# last_trade_date:2018-02-06 11:07AM EST
# strike price:236.00
# last price:32.26
# bid price:34.21
# ask price:35.97
# implied volatility:34.86%
# contract name:SPY180329C00237000
# last_trade_date:2018-02-06 9:41AM EST
# strike price:237.00
# last price:30.43
# bid price:33.22
# ask price:35.02
# implied volatility:34.31%
# contract name:SPY180329C00238000
# last_trade_date:2018-02-06 9:40AM EST
# strike price:238.00
# last price:29.65
# bid price:32.30
# ask price:34.07
# implied volatility:33.77%
# contract name:SPY180329C00239000
# last_trade_date:2018-02-06 2:54PM EST
# strike price:239.00
# last price:29.79
# bid price:31.57
# ask price:33.12
# implied volatility:33.20%
# contract name:SPY180329C00240000
# last_trade_date:2018-02-06 2:54PM EST
# strike price:240.00
# last price:28.87
# bid price:30.51
# ask price:32.11
# implied volatility:32.39%
# contract name:SPY180329C00241000
# last_trade_date:2018-02-05 3:57PM EST
# strike price:241.00
# last price:27.23
# bid price:29.75
# ask price:31.23
# implied volatility:32.09%
# contract name:SPY180329C00242000
# last_trade_date:2018-02-06 3:33PM EST
# strike price:242.00
# last price:29.32
# bid price:28.82
# ask price:30.22
# implied volatility:31.28%
# contract name:SPY180329C00243000
# last_trade_date:2018-02-06 3:38PM EST
# strike price:243.00
# last price:28.98
# bid price:27.90
# ask price:29.35
# implied volatility:30.99%
# contract name:SPY180329C00244000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:244.00
# last price:28.28
# bid price:27.47
# ask price:27.75
# implied volatility:27.87%
# contract name:SPY180329C00245000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:245.00
# last price:26.98
# bid price:26.57
# ask price:26.82
# implied volatility:27.38%
# contract name:SPY180329C00246000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:246.00
# last price:26.07
# bid price:25.62
# ask price:25.90
# implied volatility:26.93%
# contract name:SPY180329C00247000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:247.00
# last price:25.51
# bid price:24.70
# ask price:24.98
# implied volatility:26.45%
# contract name:SPY180329C00248000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:248.00
# last price:24.10
# bid price:23.79
# ask price:24.07
# implied volatility:26.00%
# contract name:SPY180329C00249000
# last_trade_date:2018-02-06 3:33PM EST
# strike price:249.00
# last price:23.07
# bid price:22.88
# ask price:23.16
# implied volatility:25.54%
# contract name:SPY180329C00250000
# last_trade_date:2018-02-06 3:10PM EST
# strike price:250.00
# last price:22.10
# bid price:21.98
# ask price:22.26
# implied volatility:25.09%
# contract name:SPY180329C00251000
# last_trade_date:2018-02-06 3:11PM EST
# strike price:251.00
# last price:20.91
# bid price:21.08
# ask price:21.36
# implied volatility:24.62%
# contract name:SPY180329C00252000
# last_trade_date:2018-02-06 3:10PM EST
# strike price:252.00
# last price:20.31
# bid price:20.19
# ask price:20.47
# implied volatility:24.17%
# contract name:SPY180329C00253000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:253.00
# last price:19.52
# bid price:19.31
# ask price:19.59
# implied volatility:23.74%
# contract name:SPY180329C00254000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:254.00
# last price:18.65
# bid price:18.44
# ask price:18.71
# implied volatility:23.28%
# contract name:SPY180329C00255000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:255.00
# last price:17.80
# bid price:17.59
# ask price:17.85
# implied volatility:22.86%
# contract name:SPY180329C00256000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:256.00
# last price:16.96
# bid price:16.75
# ask price:16.99
# implied volatility:22.42%
# contract name:SPY180329C00257000
# last_trade_date:2018-02-06 3:35PM EST
# strike price:257.00
# last price:15.99
# bid price:15.88
# ask price:16.15
# implied volatility:22.01%
# contract name:SPY180329C00258000
# last_trade_date:2018-02-06 3:34PM EST
# strike price:258.00
# last price:15.30
# bid price:15.05
# ask price:15.31
# implied volatility:21.58%
# contract name:SPY180329C00259000
# last_trade_date:2018-02-06 3:35PM EST
# strike price:259.00
# last price:14.36
# bid price:14.27
# ask price:14.49
# implied volatility:21.17%
# contract name:SPY180329C00260000
# last_trade_date:2018-02-06 2:35PM EST
# strike price:260.00
# last price:11.31
# bid price:13.46
# ask price:13.68
# implied volatility:20.76%
# contract name:SPY180329C00261000
# last_trade_date:2018-02-06 10:11AM EST
# strike price:261.00
# last price:11.39
# bid price:12.67
# ask price:12.89
# implied volatility:20.38%
# contract name:SPY180329C00262000
# last_trade_date:2018-02-06 12:17PM EST
# strike price:262.00
# last price:9.70
# bid price:11.89
# ask price:12.12
# implied volatility:20.01%
# contract name:SPY180329C00263000
# last_trade_date:2018-02-06 1:02PM EST
# strike price:263.00
# last price:9.65
# bid price:11.14
# ask price:11.36
# implied volatility:19.64%
# contract name:SPY180329C00264000
# last_trade_date:2018-02-06 3:35PM EST
# strike price:264.00
# last price:10.68
# bid price:10.40
# ask price:10.62
# implied volatility:19.27%
# contract name:SPY180329C00265000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:265.00
# last price:9.36
# bid price:9.68
# ask price:9.90
# implied volatility:18.92%
# contract name:SPY180329C00266000
# last_trade_date:2018-02-06 4:01PM EST
# strike price:266.00
# last price:9.65
# bid price:8.98
# ask price:9.20
# implied volatility:18.57%
# contract name:SPY180329C00267000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:267.00
# last price:8.41
# bid price:8.29
# ask price:8.52
# implied volatility:18.24%
# contract name:SPY180329C00268000
# last_trade_date:2018-02-06 3:55PM EST
# strike price:268.00
# last price:7.72
# bid price:7.65
# ask price:7.89
# implied volatility:17.97%
# contract name:SPY180329C00269000
# last_trade_date:2018-02-06 3:41PM EST
# strike price:269.00
# last price:7.90
# bid price:7.02
# ask price:7.24
# implied volatility:17.60%
# contract name:SPY180329C00270000
# last_trade_date:2018-02-06 4:00PM EST
# strike price:270.00
# last price:6.82
# bid price:6.42
# ask price:6.66
# implied volatility:17.36%
# contract name:SPY180329C00271000
# last_trade_date:2018-02-06 3:21PM EST
# strike price:271.00
# last price:5.39
# bid price:5.84
# ask price:6.09
# implied volatility:17.08%
# contract name:SPY180329C00272000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:272.00
# last price:5.72
# bid price:5.32
# ask price:5.53
# implied volatility:16.77%
# contract name:SPY180329C00273000
# last_trade_date:2018-02-06 4:14PM EST
# strike price:273.00
# last price:5.15
# bid price:4.80
# ask price:5.03
# implied volatility:16.55%
# contract name:SPY180329C00274000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:274.00
# last price:4.70
# bid price:4.33
# ask price:4.56
# implied volatility:16.34%
# contract name:SPY180329C00275000
# last_trade_date:2018-02-06 4:01PM EST
# strike price:275.00
# last price:4.48
# bid price:3.90
# ask price:4.11
# implied volatility:16.12%
# contract name:SPY180329C00276000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:276.00
# last price:3.80
# bid price:3.51
# ask price:3.73
# implied volatility:16.02%
# contract name:SPY180329C00277000
# last_trade_date:2018-02-06 3:27PM EST
# strike price:277.00
# last price:2.96
# bid price:3.15
# ask price:3.37
# implied volatility:15.90%
# contract name:SPY180329C00278000
# last_trade_date:2018-02-06 3:41PM EST
# strike price:278.00
# last price:3.62
# bid price:2.83
# ask price:3.04
# implied volatility:15.81%
# contract name:SPY180329C00279000
# last_trade_date:2018-02-06 1:45PM EST
# strike price:279.00
# last price:1.77
# bid price:2.54
# ask price:2.74
# implied volatility:15.74%
# contract name:SPY180329C00280000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:280.00
# last price:2.92
# bid price:2.28
# ask price:2.46
# implied volatility:15.66%
# contract name:SPY180329C00281000
# last_trade_date:2018-02-06 3:49PM EST
# strike price:281.00
# last price:2.65
# bid price:2.10
# ask price:2.24
# implied volatility:15.71%
# contract name:SPY180329C00282000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:282.00
# last price:2.48
# bid price:1.91
# ask price:2.05
# implied volatility:15.79%
# contract name:SPY180329C00283000
# last_trade_date:2018-02-06 3:49PM EST
# strike price:283.00
# last price:2.30
# bid price:1.73
# ask price:1.88
# implied volatility:15.90%
# contract name:SPY180329C00284000
# last_trade_date:2018-02-06 3:49PM EST
# strike price:284.00
# last price:2.14
# bid price:1.58
# ask price:1.72
# implied volatility:15.99%
# contract name:SPY180329C00285000
# last_trade_date:2018-02-06 4:12PM EST
# strike price:285.00
# last price:1.60
# bid price:1.44
# ask price:1.60
# implied volatility:16.19%
# contract name:SPY180329C00286000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:286.00
# last price:1.64
# bid price:1.32
# ask price:1.48
# implied volatility:16.35%
# contract name:SPY180329C00287000
# last_trade_date:2018-02-06 3:50PM EST
# strike price:287.00
# last price:1.79
# bid price:1.21
# ask price:1.37
# implied volatility:16.50%
# contract name:SPY180329C00288000
# last_trade_date:2018-02-06 3:55PM EST
# strike price:288.00
# last price:1.58
# bid price:1.11
# ask price:1.28
# implied volatility:16.71%
# contract name:SPY180329C00289000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:289.00
# last price:1.57
# bid price:1.02
# ask price:1.20
# implied volatility:16.93%
# contract name:SPY180329C00290000
# last_trade_date:2018-02-06 4:09PM EST
# strike price:290.00
# last price:1.20
# bid price:0.94
# ask price:1.12
# implied volatility:17.13%
# contract name:SPY180329C00291000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:291.00
# last price:1.38
# bid price:0.87
# ask price:1.04
# implied volatility:17.29%
# contract name:SPY180329C00292000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:292.00
# last price:1.20
# bid price:0.80
# ask price:0.99
# implied volatility:17.57%
# contract name:SPY180329C00293000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:293.00
# last price:1.23
# bid price:0.74
# ask price:0.92
# implied volatility:17.73%
# contract name:SPY180329C00294000
# last_trade_date:2018-02-06 3:53PM EST
# strike price:294.00
# last price:1.16
# bid price:0.68
# ask price:0.87
# implied volatility:17.96%
# contract name:SPY180329C00295000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:295.00
# last price:0.91
# bid price:0.63
# ask price:0.82
# implied volatility:18.18%
# contract name:SPY180329C00296000
# last_trade_date:2018-02-06 3:52PM EST
# strike price:296.00
# last price:0.96
# bid price:0.58
# ask price:0.78
# implied volatility:18.43%
# contract name:SPY180329C00297000
# last_trade_date:2018-02-06 2:40PM EST
# strike price:297.00
# last price:0.38
# bid price:0.53
# ask price:0.73
# implied volatility:18.60%
# contract name:SPY180329C00299000
# last_trade_date:2018-02-06 10:47AM EST
# strike price:299.00
# last price:0.04
# bid price:0.45
# ask price:0.65
# implied volatility:19.02%
# contract name:SPY180329C00300000
# last_trade_date:2018-02-06 3:56PM EST
# strike price:300.00
# last price:0.72
# bid price:0.42
# ask price:0.62
# implied volatility:19.26%
# contract name:SPY180329C00301000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:301.00
# last price:0.77
# bid price:0.39
# ask price:0.58
# implied volatility:19.41%
# contract name:SPY180329C00302000
# last_trade_date:2018-02-06 3:33PM EST
# strike price:302.00
# last price:0.44
# bid price:0.36
# ask price:0.55
# implied volatility:19.63%
# contract name:SPY180329C00303000
# last_trade_date:2018-02-02 11:20AM EST
# strike price:303.00
# last price:0.10
# bid price:0.05
# ask price:0.08
# implied volatility:14.36%
# contract name:SPY180329C00304000
# last_trade_date:2018-01-26 11:45PM EST
# strike price:304.00
# last price:0.33
# bid price:0.31
# ask price:0.33
# implied volatility:18.48%
# contract name:SPY180329C00305000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:305.00
# last price:0.55
# bid price:0.28
# ask price:0.46
# implied volatility:20.15%
# contract name:SPY180329C00306000
# last_trade_date:2018-02-02 11:45PM EST
# strike price:306.00
# last price:0.13
# bid price:0.04
# ask price:0.07
# implied volatility:15.09%
# contract name:SPY180329C00307000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:307.00
# last price:0.20
# bid price:0.23
# ask price:0.41
# implied volatility:20.51%
# contract name:SPY180329C00308000
# last_trade_date:2018-02-06 3:09PM EST
# strike price:308.00
# last price:0.18
# bid price:0.21
# ask price:0.39
# implied volatility:20.70%
# contract name:SPY180329C00309000
# last_trade_date:2018-01-30 9:55AM EST
# strike price:309.00
# last price:0.11
# bid price:0.02
# ask price:0.06
# implied volatility:15.77%
# contract name:SPY180329C00310000
# last_trade_date:2018-02-02 11:45PM EST
# strike price:310.00
# last price:0.08
# bid price:0.02
# ask price:0.06
# implied volatility:16.11%

# %%
filename='SPYputoptk-iv3-29.csv'
f=open(filename,'w')
f.write(headers)
# Out:
# 93

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price,implied_volatility\n'

# %%
for container in containers:
    for put in puts:
        
        title_container=put.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=put.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=put.findAll('td',{'class':'data-col2 Ta(end) Pstart(7px)'})
        strike_price=strike_price2[0].text
    
        lp=put.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=put.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=put.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
        
        iv=put.findAll('td',{'class':'data-col10 Ta(end) Pstart(7px) Pend(6px)'})
        iv2=iv[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
        print('implied volatility:'+iv2)
        f.write(contract_name+','+last_trade_date+','+strike_price.replace(',','')+','+last_price+','+bid_price+','+ask_price+','+iv2+'\n')

f.close()
# Out:
# contract name:SPY180329P00166000
# last_trade_date:2018-02-06 2:46PM EST
# strike price:166.00
# last price:0.35
# bid price:0.25
# ask price:0.41
# implied volatility:61.47%
# contract name:SPY180329P00167000
# last_trade_date:2018-02-05 1:22PM EST
# strike price:167.00
# last price:0.10
# bid price:0.42
# ask price:0.59
# implied volatility:64.99%
# contract name:SPY180329P00168000
# last_trade_date:2018-02-05 1:12PM EST
# strike price:168.00
# last price:0.10
# bid price:0.43
# ask price:0.60
# implied volatility:64.45%
# contract name:SPY180329P00169000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:169.00
# last price:0.27
# bid price:0.45
# ask price:0.62
# implied volatility:64.16%
# contract name:SPY180329P00170000
# last_trade_date:2018-02-05 1:18PM EST
# strike price:170.00
# last price:0.10
# bid price:0.49
# ask price:0.64
# implied volatility:64.01%
# contract name:SPY180329P00171000
# last_trade_date:2018-02-05 9:45AM EST
# strike price:171.00
# last price:0.08
# bid price:0.51
# ask price:0.66
# implied volatility:63.67%
# contract name:SPY180329P00172000
# last_trade_date:2018-02-05 11:54AM EST
# strike price:172.00
# last price:0.06
# bid price:0.52
# ask price:0.68
# implied volatility:63.23%
# contract name:SPY180329P00173000
# last_trade_date:2018-02-05 1:17PM EST
# strike price:173.00
# last price:0.10
# bid price:0.00
# ask price:0.00
# implied volatility:25.00%
# contract name:SPY180329P00174000
# last_trade_date:2018-02-06 11:43AM EST
# strike price:174.00
# last price:0.78
# bid price:0.33
# ask price:0.51
# implied volatility:58.30%
# contract name:SPY180329P00175000
# last_trade_date:2018-02-06 10:50AM EST
# strike price:175.00
# last price:0.85
# bid price:0.34
# ask price:0.52
# implied volatility:57.81%
# contract name:SPY180329P00176000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:176.00
# last price:0.79
# bid price:0.00
# ask price:0.00
# implied volatility:25.00%
# contract name:SPY180329P00177000
# last_trade_date:2018-02-06 10:35AM EST
# strike price:177.00
# last price:1.00
# bid price:0.37
# ask price:0.56
# implied volatility:57.23%
# contract name:SPY180329P00178000
# last_trade_date:2018-02-06 9:42AM EST
# strike price:178.00
# last price:0.30
# bid price:0.38
# ask price:0.57
# implied volatility:56.74%
# contract name:SPY180329P00179000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:179.00
# last price:0.86
# bid price:0.70
# ask price:0.86
# implied volatility:61.16%
# contract name:SPY180329P00180000
# last_trade_date:2018-02-06 3:06PM EST
# strike price:180.00
# last price:0.41
# bid price:0.41
# ask price:0.60
# implied volatility:55.98%
# contract name:SPY180329P00181000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:181.00
# last price:0.91
# bid price:0.77
# ask price:0.55
# implied volatility:57.93%
# contract name:SPY180329P00182000
# last_trade_date:2018-02-06 2:29PM EST
# strike price:182.00
# last price:0.80
# bid price:0.44
# ask price:0.63
# implied volatility:55.18%
# contract name:SPY180329P00183000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:183.00
# last price:0.96
# bid price:0.83
# ask price:0.59
# implied volatility:57.32%
# contract name:SPY180329P00184000
# last_trade_date:2018-02-06 11:34AM EST
# strike price:184.00
# last price:1.10
# bid price:0.47
# ask price:0.67
# implied volatility:54.44%
# contract name:SPY180329P00185000
# last_trade_date:2018-02-06 12:30PM EST
# strike price:185.00
# last price:0.55
# bid price:0.48
# ask price:0.67
# implied volatility:53.86%
# contract name:SPY180329P00186000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:186.00
# last price:1.06
# bid price:0.91
# ask price:0.64
# implied volatility:56.15%
# contract name:SPY180329P00187000
# last_trade_date:2018-02-06 10:32AM EST
# strike price:187.00
# last price:1.27
# bid price:0.51
# ask price:0.72
# implied volatility:53.17%
# contract name:SPY180329P00188000
# last_trade_date:2018-02-06 10:54AM EST
# strike price:188.00
# last price:0.79
# bid price:0.53
# ask price:0.74
# implied volatility:52.81%
# contract name:SPY180329P00189000
# last_trade_date:2018-02-06 11:07AM EST
# strike price:189.00
# last price:1.05
# bid price:0.55
# ask price:0.76
# implied volatility:52.44%
# contract name:SPY180329P00190000
# last_trade_date:2018-02-06 2:09PM EST
# strike price:190.00
# last price:1.13
# bid price:0.56
# ask price:0.78
# implied volatility:51.98%
# contract name:SPY180329P00191000
# last_trade_date:2018-02-05 4:11PM EST
# strike price:191.00
# last price:1.12
# bid price:0.59
# ask price:0.78
# implied volatility:51.51%
# contract name:SPY180329P00192000
# last_trade_date:2018-02-05 4:11PM EST
# strike price:192.00
# last price:1.15
# bid price:1.02
# ask price:1.39
# implied volatility:56.93%
# contract name:SPY180329P00193000
# last_trade_date:2018-02-06 12:07PM EST
# strike price:193.00
# last price:1.00
# bid price:0.62
# ask price:0.84
# implied volatility:50.81%
# contract name:SPY180329P00194000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:194.00
# last price:1.36
# bid price:1.20
# ask price:1.42
# implied volatility:56.52%
# contract name:SPY180329P00195000
# last_trade_date:2018-02-06 3:31PM EST
# strike price:195.00
# last price:0.62
# bid price:0.65
# ask price:0.88
# implied volatility:51.32%
# contract name:SPY180329P00196000
# last_trade_date:2018-02-06 9:39AM EST
# strike price:196.00
# last price:0.90
# bid price:0.67
# ask price:0.90
# implied volatility:50.85%
# contract name:SPY180329P00197000
# last_trade_date:2018-02-06 3:30PM EST
# strike price:197.00
# last price:0.67
# bid price:0.69
# ask price:0.92
# implied volatility:50.42%
# contract name:SPY180329P00198000
# last_trade_date:2017-12-15 10:03AM EST
# strike price:198.00
# last price:0.24
# bid price:0.77
# ask price:0.99
# implied volatility:50.49%
# contract name:SPY180329P00199000
# last_trade_date:2018-02-05 1:22PM EST
# strike price:199.00
# last price:0.23
# bid price:1.47
# ask price:1.70
# implied volatility:55.29%
# contract name:SPY180329P00200000
# last_trade_date:2018-02-06 3:39PM EST
# strike price:200.00
# last price:0.72
# bid price:0.75
# ask price:0.99
# implied volatility:49.12%
# contract name:SPY180329P00201000
# last_trade_date:2018-02-05 1:10PM EST
# strike price:201.00
# last price:1.66
# bid price:0.77
# ask price:1.01
# implied volatility:48.65%
# contract name:SPY180329P00202000
# last_trade_date:2018-02-06 12:07PM EST
# strike price:202.00
# last price:1.30
# bid price:0.80
# ask price:1.03
# implied volatility:48.17%
# contract name:SPY180329P00203000
# last_trade_date:2018-02-06 11:09AM EST
# strike price:203.00
# last price:1.74
# bid price:0.82
# ask price:1.06
# implied volatility:47.78%
# contract name:SPY180329P00204000
# last_trade_date:2018-02-06 11:11AM EST
# strike price:204.00
# last price:2.11
# bid price:0.84
# ask price:1.08
# implied volatility:47.29%
# contract name:SPY180329P00205000
# last_trade_date:2018-02-06 3:31PM EST
# strike price:205.00
# last price:0.83
# bid price:0.86
# ask price:1.11
# implied volatility:46.90%
# contract name:SPY180329P00206000
# last_trade_date:2018-02-06 12:34PM EST
# strike price:206.00
# last price:1.07
# bid price:0.89
# ask price:1.13
# implied volatility:46.40%
# contract name:SPY180329P00207000
# last_trade_date:2018-02-06 3:47PM EST
# strike price:207.00
# last price:0.88
# bid price:0.91
# ask price:1.16
# implied volatility:45.98%
# contract name:SPY180329P00208000
# last_trade_date:2018-02-06 10:16AM EST
# strike price:208.00
# last price:1.06
# bid price:0.94
# ask price:1.19
# implied volatility:45.57%
# contract name:SPY180329P00209000
# last_trade_date:2018-02-06 12:56PM EST
# strike price:209.00
# last price:1.80
# bid price:0.96
# ask price:1.21
# implied volatility:45.06%
# contract name:SPY180329P00210000
# last_trade_date:2018-02-06 3:43PM EST
# strike price:210.00
# last price:0.91
# bid price:1.00
# ask price:1.24
# implied volatility:44.63%
# contract name:SPY180329P00211000
# last_trade_date:2018-02-06 12:56PM EST
# strike price:211.00
# last price:1.90
# bid price:1.01
# ask price:1.27
# implied volatility:44.19%
# contract name:SPY180329P00212000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:212.00
# last price:0.95
# bid price:1.04
# ask price:1.30
# implied volatility:43.75%
# contract name:SPY180329P00213000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:213.00
# last price:0.98
# bid price:1.07
# ask price:1.34
# implied volatility:43.37%
# contract name:SPY180329P00214000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:214.00
# last price:1.00
# bid price:1.09
# ask price:1.36
# implied volatility:42.85%
# contract name:SPY180329P00215000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:215.00
# last price:1.22
# bid price:1.12
# ask price:1.39
# implied volatility:42.38%
# contract name:SPY180329P00216000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:216.00
# last price:1.09
# bid price:1.15
# ask price:1.43
# implied volatility:41.98%
# contract name:SPY180329P00217000
# last_trade_date:2018-02-06 3:28PM EST
# strike price:217.00
# last price:1.18
# bid price:1.19
# ask price:1.45
# implied volatility:41.43%
# contract name:SPY180329P00219000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:219.00
# last price:1.17
# bid price:1.26
# ask price:1.52
# implied volatility:40.54%
# contract name:SPY180329P00220000
# last_trade_date:2018-02-06 3:17PM EST
# strike price:220.00
# last price:1.24
# bid price:1.29
# ask price:1.55
# implied volatility:40.05%
# contract name:SPY180329P00221000
# last_trade_date:2018-02-06 11:49AM EST
# strike price:221.00
# last price:2.95
# bid price:1.33
# ask price:1.59
# implied volatility:39.62%
# contract name:SPY180329P00222000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:222.00
# last price:2.74
# bid price:1.36
# ask price:1.63
# implied volatility:39.19%
# contract name:SPY180329P00223000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:223.00
# last price:2.78
# bid price:1.40
# ask price:1.66
# implied volatility:38.67%
# contract name:SPY180329P00224000
# last_trade_date:2018-02-06 11:32AM EST
# strike price:224.00
# last price:3.58
# bid price:1.44
# ask price:1.70
# implied volatility:38.22%
# contract name:SPY180329P00225000
# last_trade_date:2018-02-06 2:19PM EST
# strike price:225.00
# last price:2.75
# bid price:1.48
# ask price:1.76
# implied volatility:37.88%
# contract name:SPY180329P00226000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:226.00
# last price:2.99
# bid price:1.52
# ask price:1.75
# implied volatility:37.12%
# contract name:SPY180329P00227000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:227.00
# last price:3.07
# bid price:1.56
# ask price:1.84
# implied volatility:36.94%
# contract name:SPY180329P00228000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:228.00
# last price:3.16
# bid price:1.60
# ask price:1.89
# implied volatility:36.51%
# contract name:SPY180329P00229000
# last_trade_date:2018-02-06 11:52AM EST
# strike price:229.00
# last price:3.53
# bid price:1.65
# ask price:1.93
# implied volatility:36.02%
# contract name:SPY180329P00230000
# last_trade_date:2018-02-06 3:47PM EST
# strike price:230.00
# last price:1.86
# bid price:1.70
# ask price:1.96
# implied volatility:35.47%
# contract name:SPY180329P00231000
# last_trade_date:2018-02-06 4:09PM EST
# strike price:231.00
# last price:1.85
# bid price:1.74
# ask price:2.02
# implied volatility:35.07%
# contract name:SPY180329P00232000
# last_trade_date:2018-02-06 3:28PM EST
# strike price:232.00
# last price:1.83
# bid price:1.79
# ask price:2.06
# implied volatility:34.56%
# contract name:SPY180329P00233000
# last_trade_date:2018-02-06 3:43PM EST
# strike price:233.00
# last price:1.85
# bid price:1.84
# ask price:2.10
# implied volatility:34.03%
# contract name:SPY180329P00234000
# last_trade_date:2018-02-06 10:52AM EST
# strike price:234.00
# last price:3.74
# bid price:1.89
# ask price:2.15
# implied volatility:33.56%
# contract name:SPY180329P00235000
# last_trade_date:2018-02-06 3:04PM EST
# strike price:235.00
# last price:2.05
# bid price:1.93
# ask price:2.10
# implied volatility:32.59%
# contract name:SPY180329P00236000
# last_trade_date:2018-02-06 11:11AM EST
# strike price:236.00
# last price:4.36
# bid price:1.98
# ask price:2.20
# implied volatility:32.35%
# contract name:SPY180329P00237000
# last_trade_date:2018-02-06 3:26PM EST
# strike price:237.00
# last price:2.17
# bid price:2.03
# ask price:2.26
# implied volatility:31.90%
# contract name:SPY180329P00238000
# last_trade_date:2018-02-06 3:37PM EST
# strike price:238.00
# last price:2.16
# bid price:2.09
# ask price:2.31
# implied volatility:31.38%
# contract name:SPY180329P00239000
# last_trade_date:2018-02-06 3:43PM EST
# strike price:239.00
# last price:2.20
# bid price:2.16
# ask price:2.39
# implied volatility:31.01%
# contract name:SPY180329P00240000
# last_trade_date:2018-02-06 4:07PM EST
# strike price:240.00
# last price:2.25
# bid price:2.20
# ask price:2.43
# implied volatility:30.43%
# contract name:SPY180329P00241000
# last_trade_date:2018-02-06 4:05PM EST
# strike price:241.00
# last price:2.44
# bid price:2.29
# ask price:2.50
# implied volatility:29.98%
# contract name:SPY180329P00242000
# last_trade_date:2018-02-06 3:09PM EST
# strike price:242.00
# last price:2.40
# bid price:2.35
# ask price:2.65
# implied volatility:29.85%
# contract name:SPY180329P00243000
# last_trade_date:2018-02-06 3:37PM EST
# strike price:243.00
# last price:2.52
# bid price:2.43
# ask price:2.65
# implied volatility:29.08%
# contract name:SPY180329P00244000
# last_trade_date:2018-02-06 1:33PM EST
# strike price:244.00
# last price:4.20
# bid price:2.49
# ask price:2.78
# implied volatility:28.83%
# contract name:SPY180329P00245000
# last_trade_date:2018-02-06 3:37PM EST
# strike price:245.00
# last price:2.70
# bid price:2.57
# ask price:2.78
# implied volatility:28.06%
# contract name:SPY180329P00246000
# last_trade_date:2018-02-06 11:14AM EST
# strike price:246.00
# last price:6.00
# bid price:2.65
# ask price:2.91
# implied volatility:27.77%
# contract name:SPY180329P00247000
# last_trade_date:2018-02-06 3:56PM EST
# strike price:247.00
# last price:3.02
# bid price:2.74
# ask price:3.03
# implied volatility:27.43%
# contract name:SPY180329P00248000
# last_trade_date:2018-02-06 3:01PM EST
# strike price:248.00
# last price:3.17
# bid price:2.82
# ask price:3.09
# implied volatility:26.84%
# contract name:SPY180329P00249000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:249.00
# last price:3.44
# bid price:2.92
# ask price:3.19
# implied volatility:26.40%
# contract name:SPY180329P00250000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:250.00
# last price:3.43
# bid price:3.02
# ask price:3.31
# implied volatility:26.00%
# contract name:SPY180329P00251000
# last_trade_date:2018-02-06 3:16PM EST
# strike price:251.00
# last price:3.30
# bid price:3.14
# ask price:3.43
# implied volatility:25.57%
# contract name:SPY180329P00252000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:252.00
# last price:3.81
# bid price:3.25
# ask price:3.56
# implied volatility:25.17%
# contract name:SPY180329P00253000
# last_trade_date:2018-02-06 3:16PM EST
# strike price:253.00
# last price:3.56
# bid price:3.38
# ask price:3.70
# implied volatility:24.77%
# contract name:SPY180329P00254000
# last_trade_date:2018-02-06 3:05PM EST
# strike price:254.00
# last price:3.75
# bid price:3.51
# ask price:3.85
# implied volatility:24.38%
# contract name:SPY180329P00255000
# last_trade_date:2018-02-06 4:00PM EST
# strike price:255.00
# last price:3.87
# bid price:3.67
# ask price:3.99
# implied volatility:23.94%
# contract name:SPY180329P00256000
# last_trade_date:2018-02-06 4:05PM EST
# strike price:256.00
# last price:3.93
# bid price:3.83
# ask price:4.16
# implied volatility:23.57%
# contract name:SPY180329P00257000
# last_trade_date:2018-02-06 3:06PM EST
# strike price:257.00
# last price:4.08
# bid price:4.00
# ask price:4.31
# implied volatility:23.10%
# contract name:SPY180329P00258000
# last_trade_date:2018-02-06 3:48PM EST
# strike price:258.00
# last price:4.70
# bid price:4.18
# ask price:4.48
# implied volatility:22.68%
# contract name:SPY180329P00259000
# last_trade_date:2018-02-06 3:33PM EST
# strike price:259.00
# last price:4.85
# bid price:4.37
# ask price:4.70
# implied volatility:22.36%
# contract name:SPY180329P00260000
# last_trade_date:2018-02-06 3:58PM EST
# strike price:260.00
# last price:4.79
# bid price:4.67
# ask price:4.88
# implied volatility:21.90%
# contract name:SPY180329P00261000
# last_trade_date:2018-02-06 3:56PM EST
# strike price:261.00
# last price:5.17
# bid price:4.79
# ask price:5.11
# implied volatility:21.55%
# contract name:SPY180329P00262000
# last_trade_date:2018-02-06 3:40PM EST
# strike price:262.00
# last price:5.06
# bid price:5.03
# ask price:5.34
# implied volatility:21.17%
# contract name:SPY180329P00263000
# last_trade_date:2018-02-06 2:46PM EST
# strike price:263.00
# last price:7.26
# bid price:5.27
# ask price:5.57
# implied volatility:20.75%
# contract name:SPY180329P00264000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:264.00
# last price:5.89
# bid price:5.52
# ask price:5.84
# implied volatility:20.39%
# contract name:SPY180329P00265000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:265.00
# last price:6.25
# bid price:5.83
# ask price:6.20
# implied volatility:20.23%
# contract name:SPY180329P00266000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:266.00
# last price:6.53
# bid price:6.15
# ask price:6.52
# implied volatility:19.92%
# contract name:SPY180329P00267000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:267.00
# last price:7.07
# bid price:6.49
# ask price:6.75
# implied volatility:19.34%
# contract name:SPY180329P00268000
# last_trade_date:2018-02-06 4:01PM EST
# strike price:268.00
# last price:6.85
# bid price:6.85
# ask price:7.20
# implied volatility:19.27%
# contract name:SPY180329P00269000
# last_trade_date:2018-02-06 4:12PM EST
# strike price:269.00
# last price:7.18
# bid price:7.24
# ask price:7.51
# implied volatility:18.80%
# contract name:SPY180329P00270000
# last_trade_date:2018-02-06 4:12PM EST
# strike price:270.00
# last price:7.61
# bid price:7.68
# ask price:8.00
# implied volatility:18.73%
# contract name:SPY180329P00271000
# last_trade_date:2018-02-06 4:13PM EST
# strike price:271.00
# last price:8.00
# bid price:8.06
# ask price:8.47
# implied volatility:18.55%
# contract name:SPY180329P00272000
# last_trade_date:2018-02-06 3:44PM EST
# strike price:272.00
# last price:8.80
# bid price:8.61
# ask price:8.94
# implied volatility:18.32%
# contract name:SPY180329P00273000
# last_trade_date:2018-02-06 3:12PM EST
# strike price:273.00
# last price:9.07
# bid price:9.03
# ask price:9.45
# implied volatility:18.14%
# contract name:SPY180329P00274000
# last_trade_date:2018-02-06 3:11PM EST
# strike price:274.00
# last price:9.67
# bid price:9.57
# ask price:9.99
# implied volatility:17.98%
# contract name:SPY180329P00275000
# last_trade_date:2018-02-06 3:08PM EST
# strike price:275.00
# last price:10.00
# bid price:10.15
# ask price:10.58
# implied volatility:17.88%
# contract name:SPY180329P00276000
# last_trade_date:2018-02-06 2:43PM EST
# strike price:276.00
# last price:14.69
# bid price:10.76
# ask price:11.16
# implied volatility:17.71%
# contract name:SPY180329P00277000
# last_trade_date:2018-02-06 12:46PM EST
# strike price:277.00
# last price:13.84
# bid price:11.42
# ask price:11.81
# implied volatility:17.66%
# contract name:SPY180329P00278000
# last_trade_date:2018-02-06 2:20PM EST
# strike price:278.00
# last price:17.55
# bid price:12.15
# ask price:12.51
# implied volatility:17.70%
# contract name:SPY180329P00279000
# last_trade_date:2018-02-06 12:39PM EST
# strike price:279.00
# last price:14.81
# bid price:12.88
# ask price:13.26
# implied volatility:17.82%
# contract name:SPY180329P00280000
# last_trade_date:2018-02-06 3:49PM EST
# strike price:280.00
# last price:14.75
# bid price:13.65
# ask price:14.02
# implied volatility:17.93%
# contract name:SPY180329P00281000
# last_trade_date:2018-02-06 4:12PM EST
# strike price:281.00
# last price:14.42
# bid price:14.44
# ask price:14.81
# implied volatility:18.08%
# contract name:SPY180329P00282000
# last_trade_date:2018-02-06 1:19PM EST
# strike price:282.00
# last price:17.96
# bid price:15.25
# ask price:15.66
# implied volatility:18.37%
# contract name:SPY180329P00283000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:283.00
# last price:16.00
# bid price:16.09
# ask price:16.47
# implied volatility:18.51%
# contract name:SPY180329P00284000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:284.00
# last price:19.36
# bid price:23.10
# ask price:25.73
# implied volatility:41.69%
# contract name:SPY180329P00285000
# last_trade_date:2018-02-05 2:37PM EST
# strike price:285.00
# last price:15.14
# bid price:24.11
# ask price:27.00
# implied volatility:43.24%
# contract name:SPY180329P00286000
# last_trade_date:2018-02-05 2:04PM EST
# strike price:286.00
# last price:14.60
# bid price:25.00
# ask price:26.95
# implied volatility:41.38%
# contract name:SPY180329P00287000
# last_trade_date:2018-02-06 12:51PM EST
# strike price:287.00
# last price:23.27
# bid price:18.62
# ask price:20.60
# implied volatility:21.66%
# contract name:SPY180329P00288000
# last_trade_date:2018-02-06 9:44AM EST
# strike price:288.00
# last price:22.96
# bid price:19.58
# ask price:21.45
# implied volatility:21.82%
# contract name:SPY180329P00289000
# last_trade_date:2018-02-02 1:28PM EST
# strike price:289.00
# last price:12.13
# bid price:14.42
# ask price:14.77
# implied volatility:0.00%
# contract name:SPY180329P00290000
# last_trade_date:2018-02-02 3:48PM EST
# strike price:290.00
# last price:14.80
# bid price:15.30
# ask price:15.66
# implied volatility:0.00%
# contract name:SPY180329P00291000
# last_trade_date:2018-02-02 9:42AM EST
# strike price:291.00
# last price:12.23
# bid price:16.21
# ask price:16.57
# implied volatility:0.00%
# contract name:SPY180329P00292000
# last_trade_date:2018-02-01 3:50PM EST
# strike price:292.00
# last price:11.60
# bid price:17.14
# ask price:17.51
# implied volatility:0.00%
# contract name:SPY180329P00293000
# last_trade_date:2018-02-05 12:19PM EST
# strike price:293.00
# last price:20.17
# bid price:31.62
# ask price:33.63
# implied volatility:46.08%
# contract name:SPY180329P00294000
# last_trade_date:2018-01-31 10:34AM EST
# strike price:294.00
# last price:12.35
# bid price:19.03
# ask price:19.41
# implied volatility:0.00%
# contract name:SPY180329P00295000
# last_trade_date:2018-02-06 1:39PM EST
# strike price:295.00
# last price:31.24
# bid price:25.95
# ask price:27.99
# implied volatility:24.46%
# contract name:SPY180329P00298000
# last_trade_date:2018-02-02 11:50PM EST
# strike price:298.00
# last price:20.50
# bid price:22.92
# ask price:23.31
# implied volatility:0.00%
# contract name:SPY180329P00300000
# last_trade_date:2018-02-06 12:35PM EST
# strike price:300.00
# last price:35.03
# bid price:30.72
# ask price:32.80
# implied volatility:26.49%
# contract name:SPY180329P00302000
# last_trade_date:2018-02-02 11:50PM EST
# strike price:302.00
# last price:24.33
# bid price:26.87
# ask price:27.27
# implied volatility:0.00%
# contract name:SPY180329P00310000
# last_trade_date:2018-02-02 11:50PM EST
# strike price:310.00
# last price:24.50
# bid price:34.82
# ask price:35.22
# implied volatility:0.00%
# contract name:SPY180329P00166000
# last_trade_date:2018-02-06 2:46PM EST
# strike price:166.00
# last price:0.35
# bid price:0.25
# ask price:0.41
# implied volatility:61.47%
# contract name:SPY180329P00167000
# last_trade_date:2018-02-05 1:22PM EST
# strike price:167.00
# last price:0.10
# bid price:0.42
# ask price:0.59
# implied volatility:64.99%
# contract name:SPY180329P00168000
# last_trade_date:2018-02-05 1:12PM EST
# strike price:168.00
# last price:0.10
# bid price:0.43
# ask price:0.60
# implied volatility:64.45%
# contract name:SPY180329P00169000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:169.00
# last price:0.27
# bid price:0.45
# ask price:0.62
# implied volatility:64.16%
# contract name:SPY180329P00170000
# last_trade_date:2018-02-05 1:18PM EST
# strike price:170.00
# last price:0.10
# bid price:0.49
# ask price:0.64
# implied volatility:64.01%
# contract name:SPY180329P00171000
# last_trade_date:2018-02-05 9:45AM EST
# strike price:171.00
# last price:0.08
# bid price:0.51
# ask price:0.66
# implied volatility:63.67%
# contract name:SPY180329P00172000
# last_trade_date:2018-02-05 11:54AM EST
# strike price:172.00
# last price:0.06
# bid price:0.52
# ask price:0.68
# implied volatility:63.23%
# contract name:SPY180329P00173000
# last_trade_date:2018-02-05 1:17PM EST
# strike price:173.00
# last price:0.10
# bid price:0.00
# ask price:0.00
# implied volatility:25.00%
# contract name:SPY180329P00174000
# last_trade_date:2018-02-06 11:43AM EST
# strike price:174.00
# last price:0.78
# bid price:0.33
# ask price:0.51
# implied volatility:58.30%
# contract name:SPY180329P00175000
# last_trade_date:2018-02-06 10:50AM EST
# strike price:175.00
# last price:0.85
# bid price:0.34
# ask price:0.52
# implied volatility:57.81%
# contract name:SPY180329P00176000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:176.00
# last price:0.79
# bid price:0.00
# ask price:0.00
# implied volatility:25.00%
# contract name:SPY180329P00177000
# last_trade_date:2018-02-06 10:35AM EST
# strike price:177.00
# last price:1.00
# bid price:0.37
# ask price:0.56
# implied volatility:57.23%
# contract name:SPY180329P00178000
# last_trade_date:2018-02-06 9:42AM EST
# strike price:178.00
# last price:0.30
# bid price:0.38
# ask price:0.57
# implied volatility:56.74%
# contract name:SPY180329P00179000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:179.00
# last price:0.86
# bid price:0.70
# ask price:0.86
# implied volatility:61.16%
# contract name:SPY180329P00180000
# last_trade_date:2018-02-06 3:06PM EST
# strike price:180.00
# last price:0.41
# bid price:0.41
# ask price:0.60
# implied volatility:55.98%
# contract name:SPY180329P00181000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:181.00
# last price:0.91
# bid price:0.77
# ask price:0.55
# implied volatility:57.93%
# contract name:SPY180329P00182000
# last_trade_date:2018-02-06 2:29PM EST
# strike price:182.00
# last price:0.80
# bid price:0.44
# ask price:0.63
# implied volatility:55.18%
# contract name:SPY180329P00183000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:183.00
# last price:0.96
# bid price:0.83
# ask price:0.59
# implied volatility:57.32%
# contract name:SPY180329P00184000
# last_trade_date:2018-02-06 11:34AM EST
# strike price:184.00
# last price:1.10
# bid price:0.47
# ask price:0.67
# implied volatility:54.44%
# contract name:SPY180329P00185000
# last_trade_date:2018-02-06 12:30PM EST
# strike price:185.00
# last price:0.55
# bid price:0.48
# ask price:0.67
# implied volatility:53.86%
# contract name:SPY180329P00186000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:186.00
# last price:1.06
# bid price:0.91
# ask price:0.64
# implied volatility:56.15%
# contract name:SPY180329P00187000
# last_trade_date:2018-02-06 10:32AM EST
# strike price:187.00
# last price:1.27
# bid price:0.51
# ask price:0.72
# implied volatility:53.17%
# contract name:SPY180329P00188000
# last_trade_date:2018-02-06 10:54AM EST
# strike price:188.00
# last price:0.79
# bid price:0.53
# ask price:0.74
# implied volatility:52.81%
# contract name:SPY180329P00189000
# last_trade_date:2018-02-06 11:07AM EST
# strike price:189.00
# last price:1.05
# bid price:0.55
# ask price:0.76
# implied volatility:52.44%
# contract name:SPY180329P00190000
# last_trade_date:2018-02-06 2:09PM EST
# strike price:190.00
# last price:1.13
# bid price:0.56
# ask price:0.78
# implied volatility:51.98%
# contract name:SPY180329P00191000
# last_trade_date:2018-02-05 4:11PM EST
# strike price:191.00
# last price:1.12
# bid price:0.59
# ask price:0.78
# implied volatility:51.51%
# contract name:SPY180329P00192000
# last_trade_date:2018-02-05 4:11PM EST
# strike price:192.00
# last price:1.15
# bid price:1.02
# ask price:1.39
# implied volatility:56.93%
# contract name:SPY180329P00193000
# last_trade_date:2018-02-06 12:07PM EST
# strike price:193.00
# last price:1.00
# bid price:0.62
# ask price:0.84
# implied volatility:50.81%
# contract name:SPY180329P00194000
# last_trade_date:2018-02-05 4:10PM EST
# strike price:194.00
# last price:1.36
# bid price:1.20
# ask price:1.42
# implied volatility:56.52%
# contract name:SPY180329P00195000
# last_trade_date:2018-02-06 3:31PM EST
# strike price:195.00
# last price:0.62
# bid price:0.65
# ask price:0.88
# implied volatility:51.32%
# contract name:SPY180329P00196000
# last_trade_date:2018-02-06 9:39AM EST
# strike price:196.00
# last price:0.90
# bid price:0.67
# ask price:0.90
# implied volatility:50.85%
# contract name:SPY180329P00197000
# last_trade_date:2018-02-06 3:30PM EST
# strike price:197.00
# last price:0.67
# bid price:0.69
# ask price:0.92
# implied volatility:50.42%
# contract name:SPY180329P00198000
# last_trade_date:2017-12-15 10:03AM EST
# strike price:198.00
# last price:0.24
# bid price:0.77
# ask price:0.99
# implied volatility:50.49%
# contract name:SPY180329P00199000
# last_trade_date:2018-02-05 1:22PM EST
# strike price:199.00
# last price:0.23
# bid price:1.47
# ask price:1.70
# implied volatility:55.29%
# contract name:SPY180329P00200000
# last_trade_date:2018-02-06 3:39PM EST
# strike price:200.00
# last price:0.72
# bid price:0.75
# ask price:0.99
# implied volatility:49.12%
# contract name:SPY180329P00201000
# last_trade_date:2018-02-05 1:10PM EST
# strike price:201.00
# last price:1.66
# bid price:0.77
# ask price:1.01
# implied volatility:48.65%
# contract name:SPY180329P00202000
# last_trade_date:2018-02-06 12:07PM EST
# strike price:202.00
# last price:1.30
# bid price:0.80
# ask price:1.03
# implied volatility:48.17%
# contract name:SPY180329P00203000
# last_trade_date:2018-02-06 11:09AM EST
# strike price:203.00
# last price:1.74
# bid price:0.82
# ask price:1.06
# implied volatility:47.78%
# contract name:SPY180329P00204000
# last_trade_date:2018-02-06 11:11AM EST
# strike price:204.00
# last price:2.11
# bid price:0.84
# ask price:1.08
# implied volatility:47.29%
# contract name:SPY180329P00205000
# last_trade_date:2018-02-06 3:31PM EST
# strike price:205.00
# last price:0.83
# bid price:0.86
# ask price:1.11
# implied volatility:46.90%
# contract name:SPY180329P00206000
# last_trade_date:2018-02-06 12:34PM EST
# strike price:206.00
# last price:1.07
# bid price:0.89
# ask price:1.13
# implied volatility:46.40%
# contract name:SPY180329P00207000
# last_trade_date:2018-02-06 3:47PM EST
# strike price:207.00
# last price:0.88
# bid price:0.91
# ask price:1.16
# implied volatility:45.98%
# contract name:SPY180329P00208000
# last_trade_date:2018-02-06 10:16AM EST
# strike price:208.00
# last price:1.06
# bid price:0.94
# ask price:1.19
# implied volatility:45.57%
# contract name:SPY180329P00209000
# last_trade_date:2018-02-06 12:56PM EST
# strike price:209.00
# last price:1.80
# bid price:0.96
# ask price:1.21
# implied volatility:45.06%
# contract name:SPY180329P00210000
# last_trade_date:2018-02-06 3:43PM EST
# strike price:210.00
# last price:0.91
# bid price:1.00
# ask price:1.24
# implied volatility:44.63%
# contract name:SPY180329P00211000
# last_trade_date:2018-02-06 12:56PM EST
# strike price:211.00
# last price:1.90
# bid price:1.01
# ask price:1.27
# implied volatility:44.19%
# contract name:SPY180329P00212000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:212.00
# last price:0.95
# bid price:1.04
# ask price:1.30
# implied volatility:43.75%
# contract name:SPY180329P00213000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:213.00
# last price:0.98
# bid price:1.07
# ask price:1.34
# implied volatility:43.37%
# contract name:SPY180329P00214000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:214.00
# last price:1.00
# bid price:1.09
# ask price:1.36
# implied volatility:42.85%
# contract name:SPY180329P00215000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:215.00
# last price:1.22
# bid price:1.12
# ask price:1.39
# implied volatility:42.38%
# contract name:SPY180329P00216000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:216.00
# last price:1.09
# bid price:1.15
# ask price:1.43
# implied volatility:41.98%
# contract name:SPY180329P00217000
# last_trade_date:2018-02-06 3:28PM EST
# strike price:217.00
# last price:1.18
# bid price:1.19
# ask price:1.45
# implied volatility:41.43%
# contract name:SPY180329P00219000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:219.00
# last price:1.17
# bid price:1.26
# ask price:1.52
# implied volatility:40.54%
# contract name:SPY180329P00220000
# last_trade_date:2018-02-06 3:17PM EST
# strike price:220.00
# last price:1.24
# bid price:1.29
# ask price:1.55
# implied volatility:40.05%
# contract name:SPY180329P00221000
# last_trade_date:2018-02-06 11:49AM EST
# strike price:221.00
# last price:2.95
# bid price:1.33
# ask price:1.59
# implied volatility:39.62%
# contract name:SPY180329P00222000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:222.00
# last price:2.74
# bid price:1.36
# ask price:1.63
# implied volatility:39.19%
# contract name:SPY180329P00223000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:223.00
# last price:2.78
# bid price:1.40
# ask price:1.66
# implied volatility:38.67%
# contract name:SPY180329P00224000
# last_trade_date:2018-02-06 11:32AM EST
# strike price:224.00
# last price:3.58
# bid price:1.44
# ask price:1.70
# implied volatility:38.22%
# contract name:SPY180329P00225000
# last_trade_date:2018-02-06 2:19PM EST
# strike price:225.00
# last price:2.75
# bid price:1.48
# ask price:1.76
# implied volatility:37.88%
# contract name:SPY180329P00226000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:226.00
# last price:2.99
# bid price:1.52
# ask price:1.75
# implied volatility:37.12%
# contract name:SPY180329P00227000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:227.00
# last price:3.07
# bid price:1.56
# ask price:1.84
# implied volatility:36.94%
# contract name:SPY180329P00228000
# last_trade_date:2018-02-06 1:08PM EST
# strike price:228.00
# last price:3.16
# bid price:1.60
# ask price:1.89
# implied volatility:36.51%
# contract name:SPY180329P00229000
# last_trade_date:2018-02-06 11:52AM EST
# strike price:229.00
# last price:3.53
# bid price:1.65
# ask price:1.93
# implied volatility:36.02%
# contract name:SPY180329P00230000
# last_trade_date:2018-02-06 3:47PM EST
# strike price:230.00
# last price:1.86
# bid price:1.70
# ask price:1.96
# implied volatility:35.47%
# contract name:SPY180329P00231000
# last_trade_date:2018-02-06 4:09PM EST
# strike price:231.00
# last price:1.85
# bid price:1.74
# ask price:2.02
# implied volatility:35.07%
# contract name:SPY180329P00232000
# last_trade_date:2018-02-06 3:28PM EST
# strike price:232.00
# last price:1.83
# bid price:1.79
# ask price:2.06
# implied volatility:34.56%
# contract name:SPY180329P00233000
# last_trade_date:2018-02-06 3:43PM EST
# strike price:233.00
# last price:1.85
# bid price:1.84
# ask price:2.10
# implied volatility:34.03%
# contract name:SPY180329P00234000
# last_trade_date:2018-02-06 10:52AM EST
# strike price:234.00
# last price:3.74
# bid price:1.89
# ask price:2.15
# implied volatility:33.56%
# contract name:SPY180329P00235000
# last_trade_date:2018-02-06 3:04PM EST
# strike price:235.00
# last price:2.05
# bid price:1.93
# ask price:2.10
# implied volatility:32.59%
# contract name:SPY180329P00236000
# last_trade_date:2018-02-06 11:11AM EST
# strike price:236.00
# last price:4.36
# bid price:1.98
# ask price:2.20
# implied volatility:32.35%
# contract name:SPY180329P00237000
# last_trade_date:2018-02-06 3:26PM EST
# strike price:237.00
# last price:2.17
# bid price:2.03
# ask price:2.26
# implied volatility:31.90%
# contract name:SPY180329P00238000
# last_trade_date:2018-02-06 3:37PM EST
# strike price:238.00
# last price:2.16
# bid price:2.09
# ask price:2.31
# implied volatility:31.38%
# contract name:SPY180329P00239000
# last_trade_date:2018-02-06 3:43PM EST
# strike price:239.00
# last price:2.20
# bid price:2.16
# ask price:2.39
# implied volatility:31.01%
# contract name:SPY180329P00240000
# last_trade_date:2018-02-06 4:07PM EST
# strike price:240.00
# last price:2.25
# bid price:2.20
# ask price:2.43
# implied volatility:30.43%
# contract name:SPY180329P00241000
# last_trade_date:2018-02-06 4:05PM EST
# strike price:241.00
# last price:2.44
# bid price:2.29
# ask price:2.50
# implied volatility:29.98%
# contract name:SPY180329P00242000
# last_trade_date:2018-02-06 3:09PM EST
# strike price:242.00
# last price:2.40
# bid price:2.35
# ask price:2.65
# implied volatility:29.85%
# contract name:SPY180329P00243000
# last_trade_date:2018-02-06 3:37PM EST
# strike price:243.00
# last price:2.52
# bid price:2.43
# ask price:2.65
# implied volatility:29.08%
# contract name:SPY180329P00244000
# last_trade_date:2018-02-06 1:33PM EST
# strike price:244.00
# last price:4.20
# bid price:2.49
# ask price:2.78
# implied volatility:28.83%
# contract name:SPY180329P00245000
# last_trade_date:2018-02-06 3:37PM EST
# strike price:245.00
# last price:2.70
# bid price:2.57
# ask price:2.78
# implied volatility:28.06%
# contract name:SPY180329P00246000
# last_trade_date:2018-02-06 11:14AM EST
# strike price:246.00
# last price:6.00
# bid price:2.65
# ask price:2.91
# implied volatility:27.77%
# contract name:SPY180329P00247000
# last_trade_date:2018-02-06 3:56PM EST
# strike price:247.00
# last price:3.02
# bid price:2.74
# ask price:3.03
# implied volatility:27.43%
# contract name:SPY180329P00248000
# last_trade_date:2018-02-06 3:01PM EST
# strike price:248.00
# last price:3.17
# bid price:2.82
# ask price:3.09
# implied volatility:26.84%
# contract name:SPY180329P00249000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:249.00
# last price:3.44
# bid price:2.92
# ask price:3.19
# implied volatility:26.40%
# contract name:SPY180329P00250000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:250.00
# last price:3.43
# bid price:3.02
# ask price:3.31
# implied volatility:26.00%
# contract name:SPY180329P00251000
# last_trade_date:2018-02-06 3:16PM EST
# strike price:251.00
# last price:3.30
# bid price:3.14
# ask price:3.43
# implied volatility:25.57%
# contract name:SPY180329P00252000
# last_trade_date:2018-02-06 3:51PM EST
# strike price:252.00
# last price:3.81
# bid price:3.25
# ask price:3.56
# implied volatility:25.17%
# contract name:SPY180329P00253000
# last_trade_date:2018-02-06 3:16PM EST
# strike price:253.00
# last price:3.56
# bid price:3.38
# ask price:3.70
# implied volatility:24.77%
# contract name:SPY180329P00254000
# last_trade_date:2018-02-06 3:05PM EST
# strike price:254.00
# last price:3.75
# bid price:3.51
# ask price:3.85
# implied volatility:24.38%
# contract name:SPY180329P00255000
# last_trade_date:2018-02-06 4:00PM EST
# strike price:255.00
# last price:3.87
# bid price:3.67
# ask price:3.99
# implied volatility:23.94%
# contract name:SPY180329P00256000
# last_trade_date:2018-02-06 4:05PM EST
# strike price:256.00
# last price:3.93
# bid price:3.83
# ask price:4.16
# implied volatility:23.57%
# contract name:SPY180329P00257000
# last_trade_date:2018-02-06 3:06PM EST
# strike price:257.00
# last price:4.08
# bid price:4.00
# ask price:4.31
# implied volatility:23.10%
# contract name:SPY180329P00258000
# last_trade_date:2018-02-06 3:48PM EST
# strike price:258.00
# last price:4.70
# bid price:4.18
# ask price:4.48
# implied volatility:22.68%
# contract name:SPY180329P00259000
# last_trade_date:2018-02-06 3:33PM EST
# strike price:259.00
# last price:4.85
# bid price:4.37
# ask price:4.70
# implied volatility:22.36%
# contract name:SPY180329P00260000
# last_trade_date:2018-02-06 3:58PM EST
# strike price:260.00
# last price:4.79
# bid price:4.67
# ask price:4.88
# implied volatility:21.90%
# contract name:SPY180329P00261000
# last_trade_date:2018-02-06 3:56PM EST
# strike price:261.00
# last price:5.17
# bid price:4.79
# ask price:5.11
# implied volatility:21.55%
# contract name:SPY180329P00262000
# last_trade_date:2018-02-06 3:40PM EST
# strike price:262.00
# last price:5.06
# bid price:5.03
# ask price:5.34
# implied volatility:21.17%
# contract name:SPY180329P00263000
# last_trade_date:2018-02-06 2:46PM EST
# strike price:263.00
# last price:7.26
# bid price:5.27
# ask price:5.57
# implied volatility:20.75%
# contract name:SPY180329P00264000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:264.00
# last price:5.89
# bid price:5.52
# ask price:5.84
# implied volatility:20.39%
# contract name:SPY180329P00265000
# last_trade_date:2018-02-06 3:57PM EST
# strike price:265.00
# last price:6.25
# bid price:5.83
# ask price:6.20
# implied volatility:20.23%
# contract name:SPY180329P00266000
# last_trade_date:2018-02-06 3:59PM EST
# strike price:266.00
# last price:6.53
# bid price:6.15
# ask price:6.52
# implied volatility:19.92%
# contract name:SPY180329P00267000
# last_trade_date:2018-02-06 3:36PM EST
# strike price:267.00
# last price:7.07
# bid price:6.49
# ask price:6.75
# implied volatility:19.34%
# contract name:SPY180329P00268000
# last_trade_date:2018-02-06 4:01PM EST
# strike price:268.00
# last price:6.85
# bid price:6.85
# ask price:7.20
# implied volatility:19.27%
# contract name:SPY180329P00269000
# last_trade_date:2018-02-06 4:12PM EST
# strike price:269.00
# last price:7.18
# bid price:7.24
# ask price:7.51
# implied volatility:18.80%
# contract name:SPY180329P00270000
# last_trade_date:2018-02-06 4:12PM EST
# strike price:270.00
# last price:7.61
# bid price:7.68
# ask price:8.00
# implied volatility:18.73%
# contract name:SPY180329P00271000
# last_trade_date:2018-02-06 4:13PM EST
# strike price:271.00
# last price:8.00
# bid price:8.06
# ask price:8.47
# implied volatility:18.55%
# contract name:SPY180329P00272000
# last_trade_date:2018-02-06 3:44PM EST
# strike price:272.00
# last price:8.80
# bid price:8.61
# ask price:8.94
# implied volatility:18.32%
# contract name:SPY180329P00273000
# last_trade_date:2018-02-06 3:12PM EST
# strike price:273.00
# last price:9.07
# bid price:9.03
# ask price:9.45
# implied volatility:18.14%
# contract name:SPY180329P00274000
# last_trade_date:2018-02-06 3:11PM EST
# strike price:274.00
# last price:9.67
# bid price:9.57
# ask price:9.99
# implied volatility:17.98%
# contract name:SPY180329P00275000
# last_trade_date:2018-02-06 3:08PM EST
# strike price:275.00
# last price:10.00
# bid price:10.15
# ask price:10.58
# implied volatility:17.88%
# contract name:SPY180329P00276000
# last_trade_date:2018-02-06 2:43PM EST
# strike price:276.00
# last price:14.69
# bid price:10.76
# ask price:11.16
# implied volatility:17.71%
# contract name:SPY180329P00277000
# last_trade_date:2018-02-06 12:46PM EST
# strike price:277.00
# last price:13.84
# bid price:11.42
# ask price:11.81
# implied volatility:17.66%
# contract name:SPY180329P00278000
# last_trade_date:2018-02-06 2:20PM EST
# strike price:278.00
# last price:17.55
# bid price:12.15
# ask price:12.51
# implied volatility:17.70%
# contract name:SPY180329P00279000
# last_trade_date:2018-02-06 12:39PM EST
# strike price:279.00
# last price:14.81
# bid price:12.88
# ask price:13.26
# implied volatility:17.82%
# contract name:SPY180329P00280000
# last_trade_date:2018-02-06 3:49PM EST
# strike price:280.00
# last price:14.75
# bid price:13.65
# ask price:14.02
# implied volatility:17.93%
# contract name:SPY180329P00281000
# last_trade_date:2018-02-06 4:12PM EST
# strike price:281.00
# last price:14.42
# bid price:14.44
# ask price:14.81
# implied volatility:18.08%
# contract name:SPY180329P00282000
# last_trade_date:2018-02-06 1:19PM EST
# strike price:282.00
# last price:17.96
# bid price:15.25
# ask price:15.66
# implied volatility:18.37%
# contract name:SPY180329P00283000
# last_trade_date:2018-02-06 3:07PM EST
# strike price:283.00
# last price:16.00
# bid price:16.09
# ask price:16.47
# implied volatility:18.51%
# contract name:SPY180329P00284000
# last_trade_date:2018-02-05 3:58PM EST
# strike price:284.00
# last price:19.36
# bid price:23.10
# ask price:25.73
# implied volatility:41.69%
# contract name:SPY180329P00285000
# last_trade_date:2018-02-05 2:37PM EST
# strike price:285.00
# last price:15.14
# bid price:24.11
# ask price:27.00
# implied volatility:43.24%
# contract name:SPY180329P00286000
# last_trade_date:2018-02-05 2:04PM EST
# strike price:286.00
# last price:14.60
# bid price:25.00
# ask price:26.95
# implied volatility:41.38%
# contract name:SPY180329P00287000
# last_trade_date:2018-02-06 12:51PM EST
# strike price:287.00
# last price:23.27
# bid price:18.62
# ask price:20.60
# implied volatility:21.66%
# contract name:SPY180329P00288000
# last_trade_date:2018-02-06 9:44AM EST
# strike price:288.00
# last price:22.96
# bid price:19.58
# ask price:21.45
# implied volatility:21.82%
# contract name:SPY180329P00289000
# last_trade_date:2018-02-02 1:28PM EST
# strike price:289.00
# last price:12.13
# bid price:14.42
# ask price:14.77
# implied volatility:0.00%
# contract name:SPY180329P00290000
# last_trade_date:2018-02-02 3:48PM EST
# strike price:290.00
# last price:14.80
# bid price:15.30
# ask price:15.66
# implied volatility:0.00%
# contract name:SPY180329P00291000
# last_trade_date:2018-02-02 9:42AM EST
# strike price:291.00
# last price:12.23
# bid price:16.21
# ask price:16.57
# implied volatility:0.00%
# contract name:SPY180329P00292000
# last_trade_date:2018-02-01 3:50PM EST
# strike price:292.00
# last price:11.60
# bid price:17.14
# ask price:17.51
# implied volatility:0.00%
# contract name:SPY180329P00293000
# last_trade_date:2018-02-05 12:19PM EST
# strike price:293.00
# last price:20.17
# bid price:31.62
# ask price:33.63
# implied volatility:46.08%
# contract name:SPY180329P00294000
# last_trade_date:2018-01-31 10:34AM EST
# strike price:294.00
# last price:12.35
# bid price:19.03
# ask price:19.41
# implied volatility:0.00%
# contract name:SPY180329P00295000
# last_trade_date:2018-02-06 1:39PM EST
# strike price:295.00
# last price:31.24
# bid price:25.95
# ask price:27.99
# implied volatility:24.46%
# contract name:SPY180329P00298000
# last_trade_date:2018-02-02 11:50PM EST
# strike price:298.00
# last price:20.50
# bid price:22.92
# ask price:23.31
# implied volatility:0.00%
# contract name:SPY180329P00300000
# last_trade_date:2018-02-06 12:35PM EST
# strike price:300.00
# last price:35.03
# bid price:30.72
# ask price:32.80
# implied volatility:26.49%
# contract name:SPY180329P00302000
# last_trade_date:2018-02-02 11:50PM EST
# strike price:302.00
# last price:24.33
# bid price:26.87
# ask price:27.27
# implied volatility:0.00%
# contract name:SPY180329P00310000
# last_trade_date:2018-02-02 11:50PM EST
# strike price:310.00
# last price:24.50
# bid price:34.82
# ask price:35.22
# implied volatility:0.00%

# %%
# Out:
# '900.00'

# %%
# Out:
# '519.25'
