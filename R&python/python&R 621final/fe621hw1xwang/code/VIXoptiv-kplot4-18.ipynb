# %%
from bs4 import BeautifulSoup as soup

# %%
from urllib.request import urlopen as uReq

# %%
my_url = 'https://finance.yahoo.com/quote/%5EVIX/options?p=%5EVIX&date=1524009600'

# %%
uClient = uReq(my_url)

# %%
page_html = uClient.read()

# %%
uClient.close()

# %%
page_soup = soup(page_html,'lxml')

# %%
page_soup.body.span
# Out:
# <span data-reactid="7">Summary</span>

# %%
containers=page_soup.findAll('tbody')

# %%
calls=containers[0]

# %%
puts=containers[1]

# %%
len(containers)
# Out:
# 2

# %%
filename='VIXcalloptk-iv4-18.csv'
f=open(filename,'w')

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price,implied_volatility\n'

# %%
f.write(headers)
# Out:
# 93

# %%
for container in containers:
    for call in calls:
        
        title_container=call.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=call.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=call.findAll('td',{'class':'data-col2 Ta(end) Pstart(7px)'})
        strike_price=strike_price2[0].text
    
        lp=call.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=call.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=call.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
        
        iv=call.findAll('td',{'class':'data-col10 Ta(end) Pstart(7px) Pend(6px)'})
        iv2=iv[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
        print('implied volatility:'+iv2)
    
        f.write(contract_name+','+last_trade_date+','+strike_price.replace(',','')+','+last_price+','+bid_price+','+ask_price+','+iv2+'\n')

f.close()
# Out:
# contract name:VIX180418C00009000
# last_trade_date:2018-02-12 9:36AM EST
# strike price:9.00
# last price:10.00
# bid price:10.20
# ask price:10.50
# implied volatility:0.00%
# contract name:VIX180418C00010000
# last_trade_date:2018-02-12 10:48AM EST
# strike price:10.00
# last price:9.44
# bid price:9.20
# ask price:9.60
# implied volatility:0.00%
# contract name:VIX180418C00011000
# last_trade_date:2018-02-12 11:19AM EST
# strike price:11.00
# last price:8.50
# bid price:8.20
# ask price:8.60
# implied volatility:0.00%
# contract name:VIX180418C00012000
# last_trade_date:2018-02-12 2:44PM EST
# strike price:12.00
# last price:7.50
# bid price:7.40
# ask price:7.70
# implied volatility:0.00%
# contract name:VIX180418C00013000
# last_trade_date:2018-02-12 1:54PM EST
# strike price:13.00
# last price:6.50
# bid price:6.60
# ask price:6.80
# implied volatility:0.00%
# contract name:VIX180418C00014000
# last_trade_date:2018-02-12 9:58AM EST
# strike price:14.00
# last price:6.08
# bid price:5.80
# ask price:6.10
# implied volatility:0.00%
# contract name:VIX180418C00015000
# last_trade_date:2018-02-12 11:49AM EST
# strike price:15.00
# last price:5.30
# bid price:5.20
# ask price:5.50
# implied volatility:0.00%
# contract name:VIX180418C00016000
# last_trade_date:2018-02-12 12:17PM EST
# strike price:16.00
# last price:4.70
# bid price:4.70
# ask price:4.90
# implied volatility:0.00%
# contract name:VIX180418C00017000
# last_trade_date:2018-02-12 11:26AM EST
# strike price:17.00
# last price:4.36
# bid price:4.20
# ask price:4.40
# implied volatility:0.00%
# contract name:VIX180418C00018000
# last_trade_date:2018-02-12 1:01PM EST
# strike price:18.00
# last price:3.90
# bid price:3.80
# ask price:4.00
# implied volatility:0.00%
# contract name:VIX180418C00019000
# last_trade_date:2018-02-12 2:08PM EST
# strike price:19.00
# last price:3.60
# bid price:3.50
# ask price:3.70
# implied volatility:0.00%
# contract name:VIX180418C00020000
# last_trade_date:2018-02-12 2:12PM EST
# strike price:20.00
# last price:3.30
# bid price:3.20
# ask price:3.40
# implied volatility:0.00%
# contract name:VIX180418C00021000
# last_trade_date:2018-02-12 1:03PM EST
# strike price:21.00
# last price:3.10
# bid price:3.00
# ask price:3.10
# implied volatility:0.00%
# contract name:VIX180418C00022000
# last_trade_date:2018-02-12 1:11PM EST
# strike price:22.00
# last price:2.90
# bid price:2.75
# ask price:2.85
# implied volatility:0.00%
# contract name:VIX180418C00023000
# last_trade_date:2018-02-12 2:41PM EST
# strike price:23.00
# last price:2.65
# bid price:2.55
# ask price:2.65
# implied volatility:0.00%
# contract name:VIX180418C00024000
# last_trade_date:2018-02-12 2:29PM EST
# strike price:24.00
# last price:2.50
# bid price:2.35
# ask price:2.50
# implied volatility:32.32%
# contract name:VIX180418C00025000
# last_trade_date:2018-02-12 2:32PM EST
# strike price:25.00
# last price:2.30
# bid price:2.20
# ask price:2.30
# implied volatility:42.53%
# contract name:VIX180418C00026000
# last_trade_date:2018-02-12 2:54PM EST
# strike price:26.00
# last price:2.12
# bid price:2.05
# ask price:2.15
# implied volatility:50.44%
# contract name:VIX180418C00027000
# last_trade_date:2018-02-12 1:58PM EST
# strike price:27.00
# last price:1.95
# bid price:1.90
# ask price:2.00
# implied volatility:55.32%
# contract name:VIX180418C00028000
# last_trade_date:2018-02-09 1:55PM EST
# strike price:28.00
# last price:3.00
# bid price:1.80
# ask price:1.90
# implied volatility:61.18%
# contract name:VIX180418C00029000
# last_trade_date:2018-02-12 1:02PM EST
# strike price:29.00
# last price:1.75
# bid price:1.65
# ask price:1.75
# implied volatility:64.94%
# contract name:VIX180418C00030000
# last_trade_date:2018-02-12 2:29PM EST
# strike price:30.00
# last price:1.62
# bid price:1.55
# ask price:1.65
# implied volatility:69.09%
# contract name:VIX180418C00032500
# last_trade_date:2018-02-12 2:31PM EST
# strike price:32.50
# last price:1.37
# bid price:1.30
# ask price:1.40
# implied volatility:76.90%
# contract name:VIX180418C00035000
# last_trade_date:2018-02-12 2:28PM EST
# strike price:35.00
# last price:1.10
# bid price:1.10
# ask price:1.20
# implied volatility:83.20%
# contract name:VIX180418C00037500
# last_trade_date:2018-02-12 12:41PM EST
# strike price:37.50
# last price:1.01
# bid price:0.95
# ask price:1.05
# implied volatility:88.77%
# contract name:VIX180418C00040000
# last_trade_date:2018-02-12 12:41PM EST
# strike price:40.00
# last price:0.90
# bid price:0.80
# ask price:0.90
# implied volatility:92.68%
# contract name:VIX180418C00042500
# last_trade_date:2018-02-12 1:43PM EST
# strike price:42.50
# last price:0.79
# bid price:0.70
# ask price:0.80
# implied volatility:96.97%
# contract name:VIX180418C00045000
# last_trade_date:2018-02-09 12:49PM EST
# strike price:45.00
# last price:1.30
# bid price:0.60
# ask price:0.70
# implied volatility:100.10%
# contract name:VIX180418C00047500
# last_trade_date:2018-02-09 3:45PM EST
# strike price:47.50
# last price:0.80
# bid price:0.50
# ask price:0.60
# implied volatility:102.15%
# contract name:VIX180418C00050000
# last_trade_date:2018-02-12 1:58PM EST
# strike price:50.00
# last price:0.50
# bid price:0.45
# ask price:0.55
# implied volatility:105.57%
# contract name:VIX180418C00055000
# last_trade_date:2018-02-12 2:28PM EST
# strike price:55.00
# last price:0.40
# bid price:0.35
# ask price:0.45
# implied volatility:110.55%
# contract name:VIX180418C00060000
# last_trade_date:2018-02-09 12:23PM EST
# strike price:60.00
# last price:0.55
# bid price:0.25
# ask price:0.35
# implied volatility:113.09%
# contract name:VIX180418C00065000
# last_trade_date:2018-02-12 11:46AM EST
# strike price:65.00
# last price:0.20
# bid price:0.20
# ask price:0.25
# implied volatility:114.84%
# contract name:VIX180418C00070000
# last_trade_date:2018-02-12 1:56PM EST
# strike price:70.00
# last price:0.20
# bid price:0.15
# ask price:0.20
# implied volatility:116.99%
# contract name:VIX180418C00075000
# last_trade_date:2018-02-09 10:01AM EST
# strike price:75.00
# last price:0.20
# bid price:0.15
# ask price:0.20
# implied volatility:123.24%
# contract name:VIX180418C00009000
# last_trade_date:2018-02-12 9:36AM EST
# strike price:9.00
# last price:10.00
# bid price:10.20
# ask price:10.50
# implied volatility:0.00%
# contract name:VIX180418C00010000
# last_trade_date:2018-02-12 10:48AM EST
# strike price:10.00
# last price:9.44
# bid price:9.20
# ask price:9.60
# implied volatility:0.00%
# contract name:VIX180418C00011000
# last_trade_date:2018-02-12 11:19AM EST
# strike price:11.00
# last price:8.50
# bid price:8.20
# ask price:8.60
# implied volatility:0.00%
# contract name:VIX180418C00012000
# last_trade_date:2018-02-12 2:44PM EST
# strike price:12.00
# last price:7.50
# bid price:7.40
# ask price:7.70
# implied volatility:0.00%
# contract name:VIX180418C00013000
# last_trade_date:2018-02-12 1:54PM EST
# strike price:13.00
# last price:6.50
# bid price:6.60
# ask price:6.80
# implied volatility:0.00%
# contract name:VIX180418C00014000
# last_trade_date:2018-02-12 9:58AM EST
# strike price:14.00
# last price:6.08
# bid price:5.80
# ask price:6.10
# implied volatility:0.00%
# contract name:VIX180418C00015000
# last_trade_date:2018-02-12 11:49AM EST
# strike price:15.00
# last price:5.30
# bid price:5.20
# ask price:5.50
# implied volatility:0.00%
# contract name:VIX180418C00016000
# last_trade_date:2018-02-12 12:17PM EST
# strike price:16.00
# last price:4.70
# bid price:4.70
# ask price:4.90
# implied volatility:0.00%
# contract name:VIX180418C00017000
# last_trade_date:2018-02-12 11:26AM EST
# strike price:17.00
# last price:4.36
# bid price:4.20
# ask price:4.40
# implied volatility:0.00%
# contract name:VIX180418C00018000
# last_trade_date:2018-02-12 1:01PM EST
# strike price:18.00
# last price:3.90
# bid price:3.80
# ask price:4.00
# implied volatility:0.00%
# contract name:VIX180418C00019000
# last_trade_date:2018-02-12 2:08PM EST
# strike price:19.00
# last price:3.60
# bid price:3.50
# ask price:3.70
# implied volatility:0.00%
# contract name:VIX180418C00020000
# last_trade_date:2018-02-12 2:12PM EST
# strike price:20.00
# last price:3.30
# bid price:3.20
# ask price:3.40
# implied volatility:0.00%
# contract name:VIX180418C00021000
# last_trade_date:2018-02-12 1:03PM EST
# strike price:21.00
# last price:3.10
# bid price:3.00
# ask price:3.10
# implied volatility:0.00%
# contract name:VIX180418C00022000
# last_trade_date:2018-02-12 1:11PM EST
# strike price:22.00
# last price:2.90
# bid price:2.75
# ask price:2.85
# implied volatility:0.00%
# contract name:VIX180418C00023000
# last_trade_date:2018-02-12 2:41PM EST
# strike price:23.00
# last price:2.65
# bid price:2.55
# ask price:2.65
# implied volatility:0.00%
# contract name:VIX180418C00024000
# last_trade_date:2018-02-12 2:29PM EST
# strike price:24.00
# last price:2.50
# bid price:2.35
# ask price:2.50
# implied volatility:32.32%
# contract name:VIX180418C00025000
# last_trade_date:2018-02-12 2:32PM EST
# strike price:25.00
# last price:2.30
# bid price:2.20
# ask price:2.30
# implied volatility:42.53%
# contract name:VIX180418C00026000
# last_trade_date:2018-02-12 2:54PM EST
# strike price:26.00
# last price:2.12
# bid price:2.05
# ask price:2.15
# implied volatility:50.44%
# contract name:VIX180418C00027000
# last_trade_date:2018-02-12 1:58PM EST
# strike price:27.00
# last price:1.95
# bid price:1.90
# ask price:2.00
# implied volatility:55.32%
# contract name:VIX180418C00028000
# last_trade_date:2018-02-09 1:55PM EST
# strike price:28.00
# last price:3.00
# bid price:1.80
# ask price:1.90
# implied volatility:61.18%
# contract name:VIX180418C00029000
# last_trade_date:2018-02-12 1:02PM EST
# strike price:29.00
# last price:1.75
# bid price:1.65
# ask price:1.75
# implied volatility:64.94%
# contract name:VIX180418C00030000
# last_trade_date:2018-02-12 2:29PM EST
# strike price:30.00
# last price:1.62
# bid price:1.55
# ask price:1.65
# implied volatility:69.09%
# contract name:VIX180418C00032500
# last_trade_date:2018-02-12 2:31PM EST
# strike price:32.50
# last price:1.37
# bid price:1.30
# ask price:1.40
# implied volatility:76.90%
# contract name:VIX180418C00035000
# last_trade_date:2018-02-12 2:28PM EST
# strike price:35.00
# last price:1.10
# bid price:1.10
# ask price:1.20
# implied volatility:83.20%
# contract name:VIX180418C00037500
# last_trade_date:2018-02-12 12:41PM EST
# strike price:37.50
# last price:1.01
# bid price:0.95
# ask price:1.05
# implied volatility:88.77%
# contract name:VIX180418C00040000
# last_trade_date:2018-02-12 12:41PM EST
# strike price:40.00
# last price:0.90
# bid price:0.80
# ask price:0.90
# implied volatility:92.68%
# contract name:VIX180418C00042500
# last_trade_date:2018-02-12 1:43PM EST
# strike price:42.50
# last price:0.79
# bid price:0.70
# ask price:0.80
# implied volatility:96.97%
# contract name:VIX180418C00045000
# last_trade_date:2018-02-09 12:49PM EST
# strike price:45.00
# last price:1.30
# bid price:0.60
# ask price:0.70
# implied volatility:100.10%
# contract name:VIX180418C00047500
# last_trade_date:2018-02-09 3:45PM EST
# strike price:47.50
# last price:0.80
# bid price:0.50
# ask price:0.60
# implied volatility:102.15%
# contract name:VIX180418C00050000
# last_trade_date:2018-02-12 1:58PM EST
# strike price:50.00
# last price:0.50
# bid price:0.45
# ask price:0.55
# implied volatility:105.57%
# contract name:VIX180418C00055000
# last_trade_date:2018-02-12 2:28PM EST
# strike price:55.00
# last price:0.40
# bid price:0.35
# ask price:0.45
# implied volatility:110.55%
# contract name:VIX180418C00060000
# last_trade_date:2018-02-09 12:23PM EST
# strike price:60.00
# last price:0.55
# bid price:0.25
# ask price:0.35
# implied volatility:113.09%
# contract name:VIX180418C00065000
# last_trade_date:2018-02-12 11:46AM EST
# strike price:65.00
# last price:0.20
# bid price:0.20
# ask price:0.25
# implied volatility:114.84%
# contract name:VIX180418C00070000
# last_trade_date:2018-02-12 1:56PM EST
# strike price:70.00
# last price:0.20
# bid price:0.15
# ask price:0.20
# implied volatility:116.99%
# contract name:VIX180418C00075000
# last_trade_date:2018-02-09 10:01AM EST
# strike price:75.00
# last price:0.20
# bid price:0.15
# ask price:0.20
# implied volatility:123.24%

# %%
filename='VIXputoptk-iv4-18.csv'
f=open(filename,'w')
f.write(headers)
# Out:
# 93

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price,implied_volatility\n'

# %%
for container in containers:
    for put in puts:
        
        title_container=put.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=put.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=put.findAll('td',{'class':'data-col2 Ta(end) Pstart(7px)'})
        strike_price=strike_price2[0].text
    
        lp=put.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=put.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=put.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
        
        iv=put.findAll('td',{'class':'data-col10 Ta(end) Pstart(7px) Pend(6px)'})
        iv2=iv[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
        print('implied volatility:'+iv2)
        f.write(contract_name+','+last_trade_date+','+strike_price.replace(',','')+','+last_price+','+bid_price+','+ask_price+','+iv2+'\n')

f.close()
# Out:
# contract name:VIX180418P00009000
# last_trade_date:2018-02-09 1:48PM EST
# strike price:9.00
# last price:0.05
# bid price:0.00
# ask price:0.05
# implied volatility:106.25%
# contract name:VIX180418P00010000
# last_trade_date:2018-02-12 2:38PM EST
# strike price:10.00
# last price:0.05
# bid price:0.00
# ask price:0.05
# implied volatility:95.31%
# contract name:VIX180418P00011000
# last_trade_date:2018-02-12 1:58PM EST
# strike price:11.00
# last price:0.15
# bid price:0.05
# ask price:0.15
# implied volatility:107.03%
# contract name:VIX180418P00012000
# last_trade_date:2018-02-12 2:08PM EST
# strike price:12.00
# last price:0.20
# bid price:0.15
# ask price:0.20
# implied volatility:108.20%
# contract name:VIX180418P00013000
# last_trade_date:2018-02-12 2:44PM EST
# strike price:13.00
# last price:0.40
# bid price:0.35
# ask price:0.40
# implied volatility:117.19%
# contract name:VIX180418P00014000
# last_trade_date:2018-02-12 2:45PM EST
# strike price:14.00
# last price:0.65
# bid price:0.60
# ask price:0.70
# implied volatility:124.61%
# contract name:VIX180418P00015000
# last_trade_date:2018-02-12 3:06PM EST
# strike price:15.00
# last price:0.98
# bid price:1.00
# ask price:1.05
# implied volatility:132.42%
# contract name:VIX180418P00016000
# last_trade_date:2018-02-12 2:06PM EST
# strike price:16.00
# last price:1.55
# bid price:1.40
# ask price:1.50
# implied volatility:138.48%
# contract name:VIX180418P00017000
# last_trade_date:2018-02-12 2:49PM EST
# strike price:17.00
# last price:2.00
# bid price:1.95
# ask price:2.05
# implied volatility:146.44%
# contract name:VIX180418P00018000
# last_trade_date:2018-02-12 2:00PM EST
# strike price:18.00
# last price:2.80
# bid price:2.55
# ask price:2.65
# implied volatility:153.42%
# contract name:VIX180418P00019000
# last_trade_date:2018-02-12 2:42PM EST
# strike price:19.00
# last price:3.30
# bid price:3.20
# ask price:3.40
# implied volatility:161.52%
# contract name:VIX180418P00020000
# last_trade_date:2018-02-12 2:47PM EST
# strike price:20.00
# last price:4.00
# bid price:3.90
# ask price:4.10
# implied volatility:167.82%
# contract name:VIX180418P00021000
# last_trade_date:2018-02-08 3:36PM EST
# strike price:21.00
# last price:4.55
# bid price:4.70
# ask price:4.90
# implied volatility:175.59%
# contract name:VIX180418P00022000
# last_trade_date:2018-02-12 9:56AM EST
# strike price:22.00
# last price:5.65
# bid price:5.40
# ask price:5.60
# implied volatility:179.35%
# contract name:VIX180418P00023000
# last_trade_date:2018-02-12 1:28PM EST
# strike price:23.00
# last price:6.40
# bid price:6.20
# ask price:6.40
# implied volatility:184.86%
# contract name:VIX180418P00024000
# last_trade_date:2018-02-12 10:50AM EST
# strike price:24.00
# last price:7.20
# bid price:7.00
# ask price:7.20
# implied volatility:189.60%
# contract name:VIX180418P00025000
# last_trade_date:2018-02-12 2:54PM EST
# strike price:25.00
# last price:7.90
# bid price:7.80
# ask price:8.00
# implied volatility:193.60%
# contract name:VIX180418P00026000
# last_trade_date:2018-02-09 2:44PM EST
# strike price:26.00
# last price:8.60
# bid price:8.70
# ask price:8.80
# implied volatility:198.29%
# contract name:VIX180418P00027000
# last_trade_date:2018-02-12 1:29PM EST
# strike price:27.00
# last price:9.80
# bid price:9.50
# ask price:9.70
# implied volatility:202.39%
# contract name:VIX180418P00028000
# last_trade_date:2018-02-12 9:34AM EST
# strike price:28.00
# last price:11.10
# bid price:10.40
# ask price:10.60
# implied volatility:207.28%
# contract name:VIX180418P00029000
# last_trade_date:2018-02-09 1:37PM EST
# strike price:29.00
# last price:10.80
# bid price:11.30
# ask price:11.50
# implied volatility:211.67%
# contract name:VIX180418P00030000
# last_trade_date:2018-02-12 12:27PM EST
# strike price:30.00
# last price:12.40
# bid price:12.10
# ask price:12.30
# implied volatility:213.28%
# contract name:VIX180418P00032500
# last_trade_date:2018-02-12 9:49AM EST
# strike price:32.50
# last price:14.60
# bid price:14.40
# ask price:14.60
# implied volatility:223.14%
# contract name:VIX180418P00035000
# last_trade_date:2018-02-09 3:58PM EST
# strike price:35.00
# last price:16.60
# bid price:16.70
# ask price:16.90
# implied volatility:231.27%
# contract name:VIX180418P00037500
# last_trade_date:2018-02-08 12:00PM EST
# strike price:37.50
# last price:18.60
# bid price:18.60
# ask price:18.90
# implied volatility:229.83%
# contract name:VIX180418P00040000
# last_trade_date:2018-02-09 2:25PM EST
# strike price:40.00
# last price:21.15
# bid price:21.30
# ask price:21.50
# implied volatility:243.65%
# contract name:VIX180418P00042500
# last_trade_date:2018-02-06 10:46AM EST
# strike price:42.50
# last price:23.80
# bid price:23.20
# ask price:23.50
# implied volatility:240.23%
# contract name:VIX180418P00045000
# last_trade_date:2018-02-09 10:22AM EST
# strike price:45.00
# last price:25.70
# bid price:26.10
# ask price:26.30
# implied volatility:256.98%
# contract name:VIX180418P00047500
# last_trade_date:2018-02-06 3:53PM EST
# strike price:47.50
# last price:29.70
# bid price:27.90
# ask price:28.30
# implied volatility:250.88%
# contract name:VIX180418P00050000
# last_trade_date:2018-02-06 11:11AM EST
# strike price:50.00
# last price:30.50
# bid price:30.30
# ask price:30.70
# implied volatility:255.86%
# contract name:VIX180418P00055000
# last_trade_date:2018-02-09 2:07PM EST
# strike price:55.00
# last price:34.90
# bid price:35.70
# ask price:36.00
# implied volatility:277.30%
# contract name:VIX180418P00070000
# last_trade_date:2018-02-07 9:30AM EST
# strike price:70.00
# last price:51.20
# bid price:49.70
# ask price:50.30
# implied volatility:288.57%
# contract name:VIX180418P00009000
# last_trade_date:2018-02-09 1:48PM EST
# strike price:9.00
# last price:0.05
# bid price:0.00
# ask price:0.05
# implied volatility:106.25%
# contract name:VIX180418P00010000
# last_trade_date:2018-02-12 2:38PM EST
# strike price:10.00
# last price:0.05
# bid price:0.00
# ask price:0.05
# implied volatility:95.31%
# contract name:VIX180418P00011000
# last_trade_date:2018-02-12 1:58PM EST
# strike price:11.00
# last price:0.15
# bid price:0.05
# ask price:0.15
# implied volatility:107.03%
# contract name:VIX180418P00012000
# last_trade_date:2018-02-12 2:08PM EST
# strike price:12.00
# last price:0.20
# bid price:0.15
# ask price:0.20
# implied volatility:108.20%
# contract name:VIX180418P00013000
# last_trade_date:2018-02-12 2:44PM EST
# strike price:13.00
# last price:0.40
# bid price:0.35
# ask price:0.40
# implied volatility:117.19%
# contract name:VIX180418P00014000
# last_trade_date:2018-02-12 2:45PM EST
# strike price:14.00
# last price:0.65
# bid price:0.60
# ask price:0.70
# implied volatility:124.61%
# contract name:VIX180418P00015000
# last_trade_date:2018-02-12 3:06PM EST
# strike price:15.00
# last price:0.98
# bid price:1.00
# ask price:1.05
# implied volatility:132.42%
# contract name:VIX180418P00016000
# last_trade_date:2018-02-12 2:06PM EST
# strike price:16.00
# last price:1.55
# bid price:1.40
# ask price:1.50
# implied volatility:138.48%
# contract name:VIX180418P00017000
# last_trade_date:2018-02-12 2:49PM EST
# strike price:17.00
# last price:2.00
# bid price:1.95
# ask price:2.05
# implied volatility:146.44%
# contract name:VIX180418P00018000
# last_trade_date:2018-02-12 2:00PM EST
# strike price:18.00
# last price:2.80
# bid price:2.55
# ask price:2.65
# implied volatility:153.42%
# contract name:VIX180418P00019000
# last_trade_date:2018-02-12 2:42PM EST
# strike price:19.00
# last price:3.30
# bid price:3.20
# ask price:3.40
# implied volatility:161.52%
# contract name:VIX180418P00020000
# last_trade_date:2018-02-12 2:47PM EST
# strike price:20.00
# last price:4.00
# bid price:3.90
# ask price:4.10
# implied volatility:167.82%
# contract name:VIX180418P00021000
# last_trade_date:2018-02-08 3:36PM EST
# strike price:21.00
# last price:4.55
# bid price:4.70
# ask price:4.90
# implied volatility:175.59%
# contract name:VIX180418P00022000
# last_trade_date:2018-02-12 9:56AM EST
# strike price:22.00
# last price:5.65
# bid price:5.40
# ask price:5.60
# implied volatility:179.35%
# contract name:VIX180418P00023000
# last_trade_date:2018-02-12 1:28PM EST
# strike price:23.00
# last price:6.40
# bid price:6.20
# ask price:6.40
# implied volatility:184.86%
# contract name:VIX180418P00024000
# last_trade_date:2018-02-12 10:50AM EST
# strike price:24.00
# last price:7.20
# bid price:7.00
# ask price:7.20
# implied volatility:189.60%
# contract name:VIX180418P00025000
# last_trade_date:2018-02-12 2:54PM EST
# strike price:25.00
# last price:7.90
# bid price:7.80
# ask price:8.00
# implied volatility:193.60%
# contract name:VIX180418P00026000
# last_trade_date:2018-02-09 2:44PM EST
# strike price:26.00
# last price:8.60
# bid price:8.70
# ask price:8.80
# implied volatility:198.29%
# contract name:VIX180418P00027000
# last_trade_date:2018-02-12 1:29PM EST
# strike price:27.00
# last price:9.80
# bid price:9.50
# ask price:9.70
# implied volatility:202.39%
# contract name:VIX180418P00028000
# last_trade_date:2018-02-12 9:34AM EST
# strike price:28.00
# last price:11.10
# bid price:10.40
# ask price:10.60
# implied volatility:207.28%
# contract name:VIX180418P00029000
# last_trade_date:2018-02-09 1:37PM EST
# strike price:29.00
# last price:10.80
# bid price:11.30
# ask price:11.50
# implied volatility:211.67%
# contract name:VIX180418P00030000
# last_trade_date:2018-02-12 12:27PM EST
# strike price:30.00
# last price:12.40
# bid price:12.10
# ask price:12.30
# implied volatility:213.28%
# contract name:VIX180418P00032500
# last_trade_date:2018-02-12 9:49AM EST
# strike price:32.50
# last price:14.60
# bid price:14.40
# ask price:14.60
# implied volatility:223.14%
# contract name:VIX180418P00035000
# last_trade_date:2018-02-09 3:58PM EST
# strike price:35.00
# last price:16.60
# bid price:16.70
# ask price:16.90
# implied volatility:231.27%
# contract name:VIX180418P00037500
# last_trade_date:2018-02-08 12:00PM EST
# strike price:37.50
# last price:18.60
# bid price:18.60
# ask price:18.90
# implied volatility:229.83%
# contract name:VIX180418P00040000
# last_trade_date:2018-02-09 2:25PM EST
# strike price:40.00
# last price:21.15
# bid price:21.30
# ask price:21.50
# implied volatility:243.65%
# contract name:VIX180418P00042500
# last_trade_date:2018-02-06 10:46AM EST
# strike price:42.50
# last price:23.80
# bid price:23.20
# ask price:23.50
# implied volatility:240.23%
# contract name:VIX180418P00045000
# last_trade_date:2018-02-09 10:22AM EST
# strike price:45.00
# last price:25.70
# bid price:26.10
# ask price:26.30
# implied volatility:256.98%
# contract name:VIX180418P00047500
# last_trade_date:2018-02-06 3:53PM EST
# strike price:47.50
# last price:29.70
# bid price:27.90
# ask price:28.30
# implied volatility:250.88%
# contract name:VIX180418P00050000
# last_trade_date:2018-02-06 11:11AM EST
# strike price:50.00
# last price:30.50
# bid price:30.30
# ask price:30.70
# implied volatility:255.86%
# contract name:VIX180418P00055000
# last_trade_date:2018-02-09 2:07PM EST
# strike price:55.00
# last price:34.90
# bid price:35.70
# ask price:36.00
# implied volatility:277.30%
# contract name:VIX180418P00070000
# last_trade_date:2018-02-07 9:30AM EST
# strike price:70.00
# last price:51.20
# bid price:49.70
# ask price:50.30
# implied volatility:288.57%

# %%
# Out:
# '900.00'

# %%
# Out:
# '519.25'
