# %%
from bs4 import BeautifulSoup as soup

# %%
from urllib.request import urlopen as uReq

# %%
my_url = 'https://finance.yahoo.com/quote/AMZN/options?p=AMZN&date=1521763200'

# %%
uClient = uReq(my_url)

# %%
page_html = uClient.read()

# %%
uClient.close()

# %%
page_soup = soup(page_html,'lxml')

# %%
page_soup.body.span
# Out:
# <span data-reactid="7">Summary</span>

# %%
containers=page_soup.findAll('tbody')

# %%
calls=containers[0]

# %%
puts=containers[1]

# %%
len(containers)
# Out:
# 2

# %%
filename='AMZNcalloptk-iv3-23.csv'
f=open(filename,'w')

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price,implied_volatility\n'

# %%
f.write(headers)
# Out:
# 93

# %%
for container in containers:
    for call in calls:
        
        title_container=call.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=call.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=call.findAll('a',{'href':'/quote/AMZN/options?strike=false&straddle=false'})
        strike_price=strike_price2[0].text
    
        lp=call.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=call.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=call.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
        
        iv=call.findAll('td',{'class':'data-col10 Ta(end) Pstart(7px) Pend(6px)'})
        iv2=iv[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
        print('implied volatility:'+iv2)
    
        f.write(contract_name+','+last_trade_date+','+strike_price.replace(',','')+','+last_price+','+bid_price+','+ask_price+','+iv2+'\n')

f.close()
# Out:
# contract name:AMZN180323C01060000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,060.00
# last price:385.90
# bid price:373.70
# ask price:378.70
# implied volatility:92.12%
# contract name:AMZN180323C01070000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,070.00
# last price:396.30
# bid price:363.85
# ask price:368.85
# implied volatility:90.16%
# contract name:AMZN180323C01100000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,100.00
# last price:379.70
# bid price:334.45
# ask price:339.45
# implied volatility:84.42%
# contract name:AMZN180323C01170000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,170.00
# last price:261.55
# bid price:266.90
# ask price:271.90
# implied volatility:71.89%
# contract name:AMZN180323C01190000
# last_trade_date:2018-02-05 12:22PM EST
# strike price:1,190.00
# last price:258.05
# bid price:226.20
# ask price:231.20
# implied volatility:53.17%
# contract name:AMZN180323C01200000
# last_trade_date:2018-02-05 9:32AM EST
# strike price:1,200.00
# last price:214.75
# bid price:218.60
# ask price:223.55
# implied volatility:53.13%
# contract name:AMZN180323C01240000
# last_trade_date:2018-02-05 10:10AM EST
# strike price:1,240.00
# last price:212.00
# bid price:182.80
# ask price:187.60
# implied volatility:50.16%
# contract name:AMZN180323C01250000
# last_trade_date:2018-02-05 2:58PM EST
# strike price:1,250.00
# last price:179.65
# bid price:174.90
# ask price:179.90
# implied volatility:49.71%
# contract name:AMZN180323C01270000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:1,270.00
# last price:173.70
# bid price:157.90
# ask price:162.90
# implied volatility:47.63%
# contract name:AMZN180323C01290000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,290.00
# last price:178.50
# bid price:159.85
# ask price:164.20
# implied volatility:54.58%
# contract name:AMZN180323C01310000
# last_trade_date:2018-02-05 9:43AM EST
# strike price:1,310.00
# last price:127.70
# bid price:128.85
# ask price:133.65
# implied volatility:45.55%
# contract name:AMZN180323C01340000
# last_trade_date:2018-02-05 1:37PM EST
# strike price:1,340.00
# last price:129.75
# bid price:109.90
# ask price:113.85
# implied volatility:44.34%
# contract name:AMZN180323C01350000
# last_trade_date:2018-02-05 11:40AM EST
# strike price:1,350.00
# last price:122.33
# bid price:103.65
# ask price:107.00
# implied volatility:43.65%
# contract name:AMZN180323C01360000
# last_trade_date:2018-02-05 12:34PM EST
# strike price:1,360.00
# last price:120.20
# bid price:97.95
# ask price:102.30
# implied volatility:43.97%
# contract name:AMZN180323C01370000
# last_trade_date:2018-02-05 1:31PM EST
# strike price:1,370.00
# last price:108.10
# bid price:90.95
# ask price:95.50
# implied volatility:43.13%
# contract name:AMZN180323C01400000
# last_trade_date:2018-02-05 1:44PM EST
# strike price:1,400.00
# last price:90.44
# bid price:74.65
# ask price:78.20
# implied volatility:41.65%
# contract name:AMZN180323C01415000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:1,415.00
# last price:70.00
# bid price:67.30
# ask price:71.25
# implied volatility:41.45%
# contract name:AMZN180323C01425000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:1,425.00
# last price:71.40
# bid price:62.65
# ask price:66.80
# implied volatility:41.29%
# contract name:AMZN180323C01430000
# last_trade_date:2018-02-05 2:48PM EST
# strike price:1,430.00
# last price:69.77
# bid price:60.60
# ask price:64.90
# implied volatility:41.34%
# contract name:AMZN180323C01432500
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,432.50
# last price:61.50
# bid price:59.40
# ask price:63.70
# implied volatility:41.23%
# contract name:AMZN180323C01435000
# last_trade_date:2018-02-05 2:53PM EST
# strike price:1,435.00
# last price:62.80
# bid price:58.30
# ask price:62.45
# implied volatility:41.09%
# contract name:AMZN180323C01437500
# last_trade_date:2018-02-05 11:00AM EST
# strike price:1,437.50
# last price:74.45
# bid price:57.55
# ask price:61.45
# implied volatility:41.07%
# contract name:AMZN180323C01440000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,440.00
# last price:58.50
# bid price:56.50
# ask price:60.60
# implied volatility:41.12%
# contract name:AMZN180323C01442500
# last_trade_date:2018-02-05 11:41AM EST
# strike price:1,442.50
# last price:66.41
# bid price:55.40
# ask price:59.50
# implied volatility:41.04%
# contract name:AMZN180323C01445000
# last_trade_date:2018-02-05 11:44AM EST
# strike price:1,445.00
# last price:64.61
# bid price:54.45
# ask price:58.45
# implied volatility:40.97%
# contract name:AMZN180323C01450000
# last_trade_date:2018-02-05 2:44PM EST
# strike price:1,450.00
# last price:64.95
# bid price:52.40
# ask price:56.35
# implied volatility:40.83%
# contract name:AMZN180323C01455000
# last_trade_date:2018-02-05 11:12AM EST
# strike price:1,455.00
# last price:65.86
# bid price:50.45
# ask price:54.60
# implied volatility:40.84%
# contract name:AMZN180323C01460000
# last_trade_date:2018-02-05 11:48AM EST
# strike price:1,460.00
# last price:57.15
# bid price:48.40
# ask price:52.80
# implied volatility:40.80%
# contract name:AMZN180323C01462500
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,462.50
# last price:50.25
# bid price:47.45
# ask price:51.65
# implied volatility:40.65%
# contract name:AMZN180323C01465000
# last_trade_date:2018-02-05 12:50PM EST
# strike price:1,465.00
# last price:62.00
# bid price:46.55
# ask price:50.70
# implied volatility:40.59%
# contract name:AMZN180323C01467500
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,467.50
# last price:65.00
# bid price:49.95
# ask price:53.55
# implied volatility:42.51%
# contract name:AMZN180323C01470000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,470.00
# last price:47.65
# bid price:44.60
# ask price:48.80
# implied volatility:40.45%
# contract name:AMZN180323C01472500
# last_trade_date:2018-02-05 12:31PM EST
# strike price:1,472.50
# last price:56.40
# bid price:43.95
# ask price:48.50
# implied volatility:40.72%
# contract name:AMZN180323C01475000
# last_trade_date:2018-02-05 2:28PM EST
# strike price:1,475.00
# last price:52.45
# bid price:43.35
# ask price:47.30
# implied volatility:40.50%
# contract name:AMZN180323C01477500
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,477.50
# last price:48.00
# bid price:46.25
# ask price:49.35
# implied volatility:42.01%
# contract name:AMZN180323C01480000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,480.00
# last price:41.25
# bid price:41.25
# ask price:45.85
# implied volatility:40.56%
# contract name:AMZN180323C01482500
# last_trade_date:2018-02-05 10:09AM EST
# strike price:1,482.50
# last price:45.36
# bid price:40.85
# ask price:45.50
# implied volatility:40.78%
# contract name:AMZN180323C01485000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,485.00
# last price:54.60
# bid price:43.35
# ask price:46.55
# implied volatility:41.75%
# contract name:AMZN180323C01487500
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,487.50
# last price:66.42
# bid price:42.35
# ask price:45.80
# implied volatility:41.75%
# contract name:AMZN180323C01490000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,490.00
# last price:45.08
# bid price:41.25
# ask price:44.90
# implied volatility:41.67%
# contract name:AMZN180323C01495000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,495.00
# last price:48.90
# bid price:39.75
# ask price:43.00
# implied volatility:41.42%
# contract name:AMZN180323C01500000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,500.00
# last price:43.00
# bid price:35.15
# ask price:39.80
# implied volatility:40.43%
# contract name:AMZN180323C01502500
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,502.50
# last price:42.16
# bid price:37.10
# ask price:40.90
# implied volatility:41.43%
# contract name:AMZN180323C01520000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,520.00
# last price:33.54
# bid price:30.20
# ask price:34.40
# implied volatility:40.32%
# contract name:AMZN180323C01530000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,530.00
# last price:32.87
# bid price:29.30
# ask price:32.30
# implied volatility:40.48%
# contract name:AMZN180323C01535000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,535.00
# last price:38.80
# bid price:28.10
# ask price:31.00
# implied volatility:40.39%
# contract name:AMZN180323C01540000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,540.00
# last price:31.18
# bid price:25.25
# ask price:29.90
# implied volatility:40.39%
# contract name:AMZN180323C01545000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,545.00
# last price:41.75
# bid price:25.85
# ask price:28.45
# implied volatility:40.16%
# contract name:AMZN180323C01550000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,550.00
# last price:28.69
# bid price:23.55
# ask price:27.65
# implied volatility:40.31%
# contract name:AMZN180323C01555000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,555.00
# last price:30.95
# bid price:23.40
# ask price:26.35
# implied volatility:40.12%
# contract name:AMZN180323C01560000
# last_trade_date:2018-02-05 11:14AM EST
# strike price:1,560.00
# last price:26.80
# bid price:21.45
# ask price:26.40
# implied volatility:40.78%
# contract name:AMZN180323C01565000
# last_trade_date:2018-02-05 12:50PM EST
# strike price:1,565.00
# last price:27.45
# bid price:10.00
# ask price:30.00
# implied volatility:43.72%
# contract name:AMZN180323C01575000
# last_trade_date:2018-02-05 10:42AM EST
# strike price:1,575.00
# last price:23.30
# bid price:18.25
# ask price:22.10
# implied volatility:39.74%
# contract name:AMZN180323C01580000
# last_trade_date:2018-02-05 11:56AM EST
# strike price:1,580.00
# last price:21.50
# bid price:17.70
# ask price:21.50
# implied volatility:39.91%
# contract name:AMZN180323C01595000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,595.00
# last price:26.70
# bid price:16.25
# ask price:18.80
# implied volatility:39.68%
# contract name:AMZN180323C01600000
# last_trade_date:2018-02-05 10:53AM EST
# strike price:1,600.00
# last price:20.13
# bid price:14.95
# ask price:18.55
# implied volatility:40.05%
# contract name:AMZN180323C01605000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,605.00
# last price:18.50
# bid price:14.60
# ask price:17.25
# implied volatility:39.60%
# contract name:AMZN180323C01615000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:1,615.00
# last price:16.70
# bid price:12.85
# ask price:16.55
# implied volatility:40.12%
# contract name:AMZN180323C01620000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,620.00
# last price:16.44
# bid price:12.85
# ask price:15.10
# implied volatility:39.46%
# contract name:AMZN180323C01625000
# last_trade_date:2018-02-05 2:24PM EST
# strike price:1,625.00
# last price:15.32
# bid price:11.95
# ask price:15.75
# implied volatility:40.52%
# contract name:AMZN180323C01630000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,630.00
# last price:15.06
# bid price:11.70
# ask price:13.75
# implied volatility:39.33%
# contract name:AMZN180323C01635000
# last_trade_date:2018-02-05 2:24PM EST
# strike price:1,635.00
# last price:14.10
# bid price:6.50
# ask price:16.50
# implied volatility:42.18%
# contract name:AMZN180323C01640000
# last_trade_date:2018-02-05 11:34AM EST
# strike price:1,640.00
# last price:12.58
# bid price:10.45
# ask price:14.00
# implied volatility:40.56%
# contract name:AMZN180323C01650000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,650.00
# last price:11.37
# bid price:9.90
# ask price:11.75
# implied volatility:39.47%
# contract name:AMZN180323C01700000
# last_trade_date:2018-02-05 12:55PM EST
# strike price:1,700.00
# last price:8.30
# bid price:6.15
# ask price:9.00
# implied volatility:41.15%
# contract name:AMZN180323C01800000
# last_trade_date:2018-02-05 11:06AM EST
# strike price:1,800.00
# last price:3.90
# bid price:2.71
# ask price:5.20
# implied volatility:43.82%
# contract name:AMZN180323C01870000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,870.00
# last price:2.28
# bid price:1.90
# ask price:3.55
# implied volatility:45.40%
# contract name:AMZN180323C01880000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,880.00
# last price:3.00
# bid price:2.01
# ask price:3.45
# implied volatility:45.82%
# contract name:AMZN180323C01890000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,890.00
# last price:3.00
# bid price:0.28
# ask price:3.00
# implied volatility:45.35%
# contract name:AMZN180323C01910000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,910.00
# last price:2.24
# bid price:1.67
# ask price:3.15
# implied volatility:46.99%
# contract name:AMZN180323C01930000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,930.00
# last price:1.98
# bid price:1.47
# ask price:3.05
# implied volatility:47.96%
# contract name:AMZN180323C01950000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,950.00
# last price:1.84
# bid price:1.10
# ask price:2.89
# implied volatility:48.73%
# contract name:AMZN180323C01960000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,960.00
# last price:2.01
# bid price:1.02
# ask price:2.83
# implied volatility:49.16%
# contract name:AMZN180323C01970000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,970.00
# last price:1.66
# bid price:0.92
# ask price:2.78
# implied volatility:49.60%
# contract name:AMZN180323C01980000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,980.00
# last price:1.82
# bid price:0.93
# ask price:2.73
# implied volatility:50.04%
# contract name:AMZN180323C01990000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,990.00
# last price:1.51
# bid price:0.84
# ask price:2.68
# implied volatility:50.47%
# contract name:AMZN180323C02040000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:2,040.00
# last price:1.36
# bid price:0.72
# ask price:2.45
# implied volatility:52.55%
# contract name:AMZN180323C02050000
# last_trade_date:2018-02-05 1:43PM EST
# strike price:2,050.00
# last price:0.85
# bid price:0.33
# ask price:2.52
# implied volatility:53.33%
# contract name:AMZN180323C02080000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:2,080.00
# last price:1.11
# bid price:0.66
# ask price:2.40
# implied volatility:51.11%
# contract name:AMZN180323C01060000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,060.00
# last price:385.90
# bid price:373.70
# ask price:378.70
# implied volatility:92.12%
# contract name:AMZN180323C01070000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,070.00
# last price:396.30
# bid price:363.85
# ask price:368.85
# implied volatility:90.16%
# contract name:AMZN180323C01100000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,100.00
# last price:379.70
# bid price:334.45
# ask price:339.45
# implied volatility:84.42%
# contract name:AMZN180323C01170000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,170.00
# last price:261.55
# bid price:266.90
# ask price:271.90
# implied volatility:71.89%
# contract name:AMZN180323C01190000
# last_trade_date:2018-02-05 12:22PM EST
# strike price:1,190.00
# last price:258.05
# bid price:226.20
# ask price:231.20
# implied volatility:53.17%
# contract name:AMZN180323C01200000
# last_trade_date:2018-02-05 9:32AM EST
# strike price:1,200.00
# last price:214.75
# bid price:218.60
# ask price:223.55
# implied volatility:53.13%
# contract name:AMZN180323C01240000
# last_trade_date:2018-02-05 10:10AM EST
# strike price:1,240.00
# last price:212.00
# bid price:182.80
# ask price:187.60
# implied volatility:50.16%
# contract name:AMZN180323C01250000
# last_trade_date:2018-02-05 2:58PM EST
# strike price:1,250.00
# last price:179.65
# bid price:174.90
# ask price:179.90
# implied volatility:49.71%
# contract name:AMZN180323C01270000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:1,270.00
# last price:173.70
# bid price:157.90
# ask price:162.90
# implied volatility:47.63%
# contract name:AMZN180323C01290000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,290.00
# last price:178.50
# bid price:159.85
# ask price:164.20
# implied volatility:54.58%
# contract name:AMZN180323C01310000
# last_trade_date:2018-02-05 9:43AM EST
# strike price:1,310.00
# last price:127.70
# bid price:128.85
# ask price:133.65
# implied volatility:45.55%
# contract name:AMZN180323C01340000
# last_trade_date:2018-02-05 1:37PM EST
# strike price:1,340.00
# last price:129.75
# bid price:109.90
# ask price:113.85
# implied volatility:44.34%
# contract name:AMZN180323C01350000
# last_trade_date:2018-02-05 11:40AM EST
# strike price:1,350.00
# last price:122.33
# bid price:103.65
# ask price:107.00
# implied volatility:43.65%
# contract name:AMZN180323C01360000
# last_trade_date:2018-02-05 12:34PM EST
# strike price:1,360.00
# last price:120.20
# bid price:97.95
# ask price:102.30
# implied volatility:43.97%
# contract name:AMZN180323C01370000
# last_trade_date:2018-02-05 1:31PM EST
# strike price:1,370.00
# last price:108.10
# bid price:90.95
# ask price:95.50
# implied volatility:43.13%
# contract name:AMZN180323C01400000
# last_trade_date:2018-02-05 1:44PM EST
# strike price:1,400.00
# last price:90.44
# bid price:74.65
# ask price:78.20
# implied volatility:41.65%
# contract name:AMZN180323C01415000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:1,415.00
# last price:70.00
# bid price:67.30
# ask price:71.25
# implied volatility:41.45%
# contract name:AMZN180323C01425000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:1,425.00
# last price:71.40
# bid price:62.65
# ask price:66.80
# implied volatility:41.29%
# contract name:AMZN180323C01430000
# last_trade_date:2018-02-05 2:48PM EST
# strike price:1,430.00
# last price:69.77
# bid price:60.60
# ask price:64.90
# implied volatility:41.34%
# contract name:AMZN180323C01432500
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,432.50
# last price:61.50
# bid price:59.40
# ask price:63.70
# implied volatility:41.23%
# contract name:AMZN180323C01435000
# last_trade_date:2018-02-05 2:53PM EST
# strike price:1,435.00
# last price:62.80
# bid price:58.30
# ask price:62.45
# implied volatility:41.09%
# contract name:AMZN180323C01437500
# last_trade_date:2018-02-05 11:00AM EST
# strike price:1,437.50
# last price:74.45
# bid price:57.55
# ask price:61.45
# implied volatility:41.07%
# contract name:AMZN180323C01440000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,440.00
# last price:58.50
# bid price:56.50
# ask price:60.60
# implied volatility:41.12%
# contract name:AMZN180323C01442500
# last_trade_date:2018-02-05 11:41AM EST
# strike price:1,442.50
# last price:66.41
# bid price:55.40
# ask price:59.50
# implied volatility:41.04%
# contract name:AMZN180323C01445000
# last_trade_date:2018-02-05 11:44AM EST
# strike price:1,445.00
# last price:64.61
# bid price:54.45
# ask price:58.45
# implied volatility:40.97%
# contract name:AMZN180323C01450000
# last_trade_date:2018-02-05 2:44PM EST
# strike price:1,450.00
# last price:64.95
# bid price:52.40
# ask price:56.35
# implied volatility:40.83%
# contract name:AMZN180323C01455000
# last_trade_date:2018-02-05 11:12AM EST
# strike price:1,455.00
# last price:65.86
# bid price:50.45
# ask price:54.60
# implied volatility:40.84%
# contract name:AMZN180323C01460000
# last_trade_date:2018-02-05 11:48AM EST
# strike price:1,460.00
# last price:57.15
# bid price:48.40
# ask price:52.80
# implied volatility:40.80%
# contract name:AMZN180323C01462500
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,462.50
# last price:50.25
# bid price:47.45
# ask price:51.65
# implied volatility:40.65%
# contract name:AMZN180323C01465000
# last_trade_date:2018-02-05 12:50PM EST
# strike price:1,465.00
# last price:62.00
# bid price:46.55
# ask price:50.70
# implied volatility:40.59%
# contract name:AMZN180323C01467500
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,467.50
# last price:65.00
# bid price:49.95
# ask price:53.55
# implied volatility:42.51%
# contract name:AMZN180323C01470000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,470.00
# last price:47.65
# bid price:44.60
# ask price:48.80
# implied volatility:40.45%
# contract name:AMZN180323C01472500
# last_trade_date:2018-02-05 12:31PM EST
# strike price:1,472.50
# last price:56.40
# bid price:43.95
# ask price:48.50
# implied volatility:40.72%
# contract name:AMZN180323C01475000
# last_trade_date:2018-02-05 2:28PM EST
# strike price:1,475.00
# last price:52.45
# bid price:43.35
# ask price:47.30
# implied volatility:40.50%
# contract name:AMZN180323C01477500
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,477.50
# last price:48.00
# bid price:46.25
# ask price:49.35
# implied volatility:42.01%
# contract name:AMZN180323C01480000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,480.00
# last price:41.25
# bid price:41.25
# ask price:45.85
# implied volatility:40.56%
# contract name:AMZN180323C01482500
# last_trade_date:2018-02-05 10:09AM EST
# strike price:1,482.50
# last price:45.36
# bid price:40.85
# ask price:45.50
# implied volatility:40.78%
# contract name:AMZN180323C01485000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,485.00
# last price:54.60
# bid price:43.35
# ask price:46.55
# implied volatility:41.75%
# contract name:AMZN180323C01487500
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,487.50
# last price:66.42
# bid price:42.35
# ask price:45.80
# implied volatility:41.75%
# contract name:AMZN180323C01490000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,490.00
# last price:45.08
# bid price:41.25
# ask price:44.90
# implied volatility:41.67%
# contract name:AMZN180323C01495000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,495.00
# last price:48.90
# bid price:39.75
# ask price:43.00
# implied volatility:41.42%
# contract name:AMZN180323C01500000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,500.00
# last price:43.00
# bid price:35.15
# ask price:39.80
# implied volatility:40.43%
# contract name:AMZN180323C01502500
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,502.50
# last price:42.16
# bid price:37.10
# ask price:40.90
# implied volatility:41.43%
# contract name:AMZN180323C01520000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,520.00
# last price:33.54
# bid price:30.20
# ask price:34.40
# implied volatility:40.32%
# contract name:AMZN180323C01530000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,530.00
# last price:32.87
# bid price:29.30
# ask price:32.30
# implied volatility:40.48%
# contract name:AMZN180323C01535000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,535.00
# last price:38.80
# bid price:28.10
# ask price:31.00
# implied volatility:40.39%
# contract name:AMZN180323C01540000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,540.00
# last price:31.18
# bid price:25.25
# ask price:29.90
# implied volatility:40.39%
# contract name:AMZN180323C01545000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,545.00
# last price:41.75
# bid price:25.85
# ask price:28.45
# implied volatility:40.16%
# contract name:AMZN180323C01550000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,550.00
# last price:28.69
# bid price:23.55
# ask price:27.65
# implied volatility:40.31%
# contract name:AMZN180323C01555000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,555.00
# last price:30.95
# bid price:23.40
# ask price:26.35
# implied volatility:40.12%
# contract name:AMZN180323C01560000
# last_trade_date:2018-02-05 11:14AM EST
# strike price:1,560.00
# last price:26.80
# bid price:21.45
# ask price:26.40
# implied volatility:40.78%
# contract name:AMZN180323C01565000
# last_trade_date:2018-02-05 12:50PM EST
# strike price:1,565.00
# last price:27.45
# bid price:10.00
# ask price:30.00
# implied volatility:43.72%
# contract name:AMZN180323C01575000
# last_trade_date:2018-02-05 10:42AM EST
# strike price:1,575.00
# last price:23.30
# bid price:18.25
# ask price:22.10
# implied volatility:39.74%
# contract name:AMZN180323C01580000
# last_trade_date:2018-02-05 11:56AM EST
# strike price:1,580.00
# last price:21.50
# bid price:17.70
# ask price:21.50
# implied volatility:39.91%
# contract name:AMZN180323C01595000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,595.00
# last price:26.70
# bid price:16.25
# ask price:18.80
# implied volatility:39.68%
# contract name:AMZN180323C01600000
# last_trade_date:2018-02-05 10:53AM EST
# strike price:1,600.00
# last price:20.13
# bid price:14.95
# ask price:18.55
# implied volatility:40.05%
# contract name:AMZN180323C01605000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,605.00
# last price:18.50
# bid price:14.60
# ask price:17.25
# implied volatility:39.60%
# contract name:AMZN180323C01615000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:1,615.00
# last price:16.70
# bid price:12.85
# ask price:16.55
# implied volatility:40.12%
# contract name:AMZN180323C01620000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,620.00
# last price:16.44
# bid price:12.85
# ask price:15.10
# implied volatility:39.46%
# contract name:AMZN180323C01625000
# last_trade_date:2018-02-05 2:24PM EST
# strike price:1,625.00
# last price:15.32
# bid price:11.95
# ask price:15.75
# implied volatility:40.52%
# contract name:AMZN180323C01630000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,630.00
# last price:15.06
# bid price:11.70
# ask price:13.75
# implied volatility:39.33%
# contract name:AMZN180323C01635000
# last_trade_date:2018-02-05 2:24PM EST
# strike price:1,635.00
# last price:14.10
# bid price:6.50
# ask price:16.50
# implied volatility:42.18%
# contract name:AMZN180323C01640000
# last_trade_date:2018-02-05 11:34AM EST
# strike price:1,640.00
# last price:12.58
# bid price:10.45
# ask price:14.00
# implied volatility:40.56%
# contract name:AMZN180323C01650000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,650.00
# last price:11.37
# bid price:9.90
# ask price:11.75
# implied volatility:39.47%
# contract name:AMZN180323C01700000
# last_trade_date:2018-02-05 12:55PM EST
# strike price:1,700.00
# last price:8.30
# bid price:6.15
# ask price:9.00
# implied volatility:41.15%
# contract name:AMZN180323C01800000
# last_trade_date:2018-02-05 11:06AM EST
# strike price:1,800.00
# last price:3.90
# bid price:2.71
# ask price:5.20
# implied volatility:43.82%
# contract name:AMZN180323C01870000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,870.00
# last price:2.28
# bid price:1.90
# ask price:3.55
# implied volatility:45.40%
# contract name:AMZN180323C01880000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,880.00
# last price:3.00
# bid price:2.01
# ask price:3.45
# implied volatility:45.82%
# contract name:AMZN180323C01890000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,890.00
# last price:3.00
# bid price:0.28
# ask price:3.00
# implied volatility:45.35%
# contract name:AMZN180323C01910000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,910.00
# last price:2.24
# bid price:1.67
# ask price:3.15
# implied volatility:46.99%
# contract name:AMZN180323C01930000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,930.00
# last price:1.98
# bid price:1.47
# ask price:3.05
# implied volatility:47.96%
# contract name:AMZN180323C01950000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,950.00
# last price:1.84
# bid price:1.10
# ask price:2.89
# implied volatility:48.73%
# contract name:AMZN180323C01960000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,960.00
# last price:2.01
# bid price:1.02
# ask price:2.83
# implied volatility:49.16%
# contract name:AMZN180323C01970000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,970.00
# last price:1.66
# bid price:0.92
# ask price:2.78
# implied volatility:49.60%
# contract name:AMZN180323C01980000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,980.00
# last price:1.82
# bid price:0.93
# ask price:2.73
# implied volatility:50.04%
# contract name:AMZN180323C01990000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:1,990.00
# last price:1.51
# bid price:0.84
# ask price:2.68
# implied volatility:50.47%
# contract name:AMZN180323C02040000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:2,040.00
# last price:1.36
# bid price:0.72
# ask price:2.45
# implied volatility:52.55%
# contract name:AMZN180323C02050000
# last_trade_date:2018-02-05 1:43PM EST
# strike price:2,050.00
# last price:0.85
# bid price:0.33
# ask price:2.52
# implied volatility:53.33%
# contract name:AMZN180323C02080000
# last_trade_date:2018-02-02 11:46PM EST
# strike price:2,080.00
# last price:1.11
# bid price:0.66
# ask price:2.40
# implied volatility:51.11%

# %%
filename='AMZNputoptk-iv3-23.csv'
f=open(filename,'w')
f.write(headers)
# Out:
# 93

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price,implied_volatility\n'

# %%
for container in containers:
    for put in puts:
        
        title_container=put.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=put.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=put.findAll('a',{'href':'/quote/AMZN/options?strike=false&straddle=false'})
        strike_price=strike_price2[0].text
    
        lp=put.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=put.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=put.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
        
        iv=put.findAll('td',{'class':'data-col10 Ta(end) Pstart(7px) Pend(6px)'})
        iv2=iv[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
        print('implied volatility:'+iv2)
        f.write(contract_name+','+last_trade_date+','+strike_price.replace(',','')+','+last_price+','+bid_price+','+ask_price+','+iv2+'\n')

f.close()
# Out:
# contract name:AMZN180323P01060000
# last_trade_date:2018-02-05 2:18PM EST
# strike price:1,060.00
# last price:1.99
# bid price:2.21
# ask price:3.85
# implied volatility:45.19%
# contract name:AMZN180323P01130000
# last_trade_date:2018-02-05 11:40AM EST
# strike price:1,130.00
# last price:2.80
# bid price:5.10
# ask price:6.75
# implied volatility:41.17%
# contract name:AMZN180323P01170000
# last_trade_date:2018-02-05 12:55PM EST
# strike price:1,170.00
# last price:4.24
# bid price:7.45
# ask price:9.80
# implied volatility:39.50%
# contract name:AMZN180323P01180000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,180.00
# last price:5.67
# bid price:5.25
# ask price:6.20
# implied volatility:33.61%
# contract name:AMZN180323P01190000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,190.00
# last price:4.50
# bid price:5.40
# ask price:6.90
# implied volatility:33.19%
# contract name:AMZN180323P01200000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:1,200.00
# last price:8.50
# bid price:10.20
# ask price:13.55
# implied volatility:38.91%
# contract name:AMZN180323P01240000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,240.00
# last price:17.95
# bid price:16.00
# ask price:20.30
# implied volatility:38.15%
# contract name:AMZN180323P01250000
# last_trade_date:2018-02-05 2:07PM EST
# strike price:1,250.00
# last price:11.00
# bid price:17.50
# ask price:22.00
# implied volatility:37.71%
# contract name:AMZN180323P01260000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,260.00
# last price:17.78
# bid price:19.20
# ask price:23.50
# implied volatility:37.05%
# contract name:AMZN180323P01270000
# last_trade_date:2018-02-05 2:24PM EST
# strike price:1,270.00
# last price:15.20
# bid price:21.15
# ask price:25.95
# implied volatility:36.95%
# contract name:AMZN180323P01280000
# last_trade_date:2018-02-05 9:43AM EST
# strike price:1,280.00
# last price:21.82
# bid price:23.30
# ask price:28.05
# implied volatility:36.50%
# contract name:AMZN180323P01300000
# last_trade_date:2018-02-05 1:19PM EST
# strike price:1,300.00
# last price:20.35
# bid price:28.15
# ask price:32.90
# implied volatility:35.74%
# contract name:AMZN180323P01310000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,310.00
# last price:21.90
# bid price:30.95
# ask price:35.70
# implied volatility:35.42%
# contract name:AMZN180323P01320000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,320.00
# last price:24.55
# bid price:33.70
# ask price:38.50
# implied volatility:35.00%
# contract name:AMZN180323P01330000
# last_trade_date:2018-02-05 10:54AM EST
# strike price:1,330.00
# last price:20.93
# bid price:36.90
# ask price:41.65
# implied volatility:34.67%
# contract name:AMZN180323P01340000
# last_trade_date:2018-02-05 9:43AM EST
# strike price:1,340.00
# last price:38.50
# bid price:40.80
# ask price:45.15
# implied volatility:34.42%
# contract name:AMZN180323P01350000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,350.00
# last price:32.92
# bid price:43.85
# ask price:48.60
# implied volatility:34.04%
# contract name:AMZN180323P01360000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,360.00
# last price:36.00
# bid price:47.85
# ask price:52.65
# implied volatility:33.85%
# contract name:AMZN180323P01370000
# last_trade_date:2018-02-05 10:03AM EST
# strike price:1,370.00
# last price:41.60
# bid price:51.55
# ask price:56.30
# implied volatility:33.34%
# contract name:AMZN180323P01380000
# last_trade_date:2018-02-05 11:34AM EST
# strike price:1,380.00
# last price:35.13
# bid price:56.75
# ask price:61.10
# implied volatility:33.30%
# contract name:AMZN180323P01390000
# last_trade_date:2018-02-05 1:44PM EST
# strike price:1,390.00
# last price:45.91
# bid price:60.50
# ask price:65.30
# implied volatility:32.84%
# contract name:AMZN180323P01400000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,400.00
# last price:65.00
# bid price:65.70
# ask price:70.25
# implied volatility:32.64%
# contract name:AMZN180323P01410000
# last_trade_date:2018-02-05 10:23AM EST
# strike price:1,410.00
# last price:45.21
# bid price:70.25
# ask price:75.15
# implied volatility:32.29%
# contract name:AMZN180323P01415000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:1,415.00
# last price:58.15
# bid price:73.05
# ask price:78.10
# implied volatility:32.32%
# contract name:AMZN180323P01420000
# last_trade_date:2018-02-05 10:40AM EST
# strike price:1,420.00
# last price:50.98
# bid price:76.40
# ask price:80.50
# implied volatility:32.04%
# contract name:AMZN180323P01425000
# last_trade_date:2018-02-05 3:02PM EST
# strike price:1,425.00
# last price:75.00
# bid price:79.15
# ask price:83.60
# implied volatility:32.08%
# contract name:AMZN180323P01430000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,430.00
# last price:65.30
# bid price:62.95
# ask price:66.40
# implied volatility:21.57%
# contract name:AMZN180323P01432500
# last_trade_date:2018-02-05 1:19PM EST
# strike price:1,432.50
# last price:65.90
# bid price:82.35
# ask price:87.25
# implied volatility:31.58%
# contract name:AMZN180323P01435000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,435.00
# last price:83.97
# bid price:83.20
# ask price:88.80
# implied volatility:31.57%
# contract name:AMZN180323P01440000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,440.00
# last price:86.34
# bid price:86.60
# ask price:91.45
# implied volatility:31.29%
# contract name:AMZN180323P01442500
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,442.50
# last price:58.10
# bid price:70.15
# ask price:72.65
# implied volatility:20.33%
# contract name:AMZN180323P01445000
# last_trade_date:2018-02-05 2:49PM EST
# strike price:1,445.00
# last price:73.70
# bid price:90.15
# ask price:94.70
# implied volatility:31.29%
# contract name:AMZN180323P01450000
# last_trade_date:2018-02-05 12:00PM EST
# strike price:1,450.00
# last price:65.00
# bid price:92.35
# ask price:96.65
# implied volatility:30.57%
# contract name:AMZN180323P01455000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,455.00
# last price:62.76
# bid price:76.00
# ask price:80.25
# implied volatility:19.43%
# contract name:AMZN180323P01460000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,460.00
# last price:56.76
# bid price:78.70
# ask price:82.15
# implied volatility:18.21%
# contract name:AMZN180323P01462500
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,462.50
# last price:59.05
# bid price:80.00
# ask price:83.65
# implied volatility:17.90%
# contract name:AMZN180323P01465000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,465.00
# last price:86.55
# bid price:81.40
# ask price:85.25
# implied volatility:17.62%
# contract name:AMZN180323P01470000
# last_trade_date:2018-02-05 10:11AM EST
# strike price:1,470.00
# last price:80.52
# bid price:105.05
# ask price:110.05
# implied volatility:30.32%
# contract name:AMZN180323P01475000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,475.00
# last price:74.95
# bid price:88.60
# ask price:91.15
# implied volatility:15.79%
# contract name:AMZN180323P01477500
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,477.50
# last price:110.00
# bid price:109.95
# ask price:114.75
# implied volatility:29.91%
# contract name:AMZN180323P01487500
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,487.50
# last price:83.82
# bid price:95.25
# ask price:99.95
# implied volatility:13.38%
# contract name:AMZN180323P01490000
# last_trade_date:2018-02-05 9:35AM EST
# strike price:1,490.00
# last price:117.74
# bid price:118.55
# ask price:123.40
# implied volatility:29.51%
# contract name:AMZN180323P01492500
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,492.50
# last price:104.20
# bid price:98.70
# ask price:102.10
# implied volatility:0.00%
# contract name:AMZN180323P01495000
# last_trade_date:2018-02-05 12:17PM EST
# strike price:1,495.00
# last price:95.40
# bid price:122.00
# ask price:127.00
# implied volatility:29.36%
# contract name:AMZN180323P01500000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,500.00
# last price:130.10
# bid price:125.40
# ask price:130.10
# implied volatility:28.87%
# contract name:AMZN180323P01510000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,510.00
# last price:85.85
# bid price:111.20
# ask price:113.90
# implied volatility:0.00%
# contract name:AMZN180323P01520000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,520.00
# last price:105.35
# bid price:117.15
# ask price:121.50
# implied volatility:0.00%
# contract name:AMZN180323P01535000
# last_trade_date:2018-02-05 2:01PM EST
# strike price:1,535.00
# last price:119.85
# bid price:152.50
# ask price:157.50
# implied volatility:28.01%
# contract name:AMZN180323P01545000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,545.00
# last price:109.40
# bid price:136.35
# ask price:139.95
# implied volatility:0.00%
# contract name:AMZN180323P01555000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,555.00
# last price:116.60
# bid price:143.80
# ask price:147.80
# implied volatility:0.00%
# contract name:AMZN180323P01595000
# last_trade_date:2018-02-05 2:49PM EST
# strike price:1,595.00
# last price:183.45
# bid price:201.00
# ask price:205.95
# implied volatility:19.51%
# contract name:AMZN180323P01600000
# last_trade_date:2018-02-05 2:49PM EST
# strike price:1,600.00
# last price:187.65
# bid price:205.20
# ask price:209.25
# implied volatility:0.00%
# contract name:AMZN180323P01660000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,660.00
# last price:225.80
# bid price:234.35
# ask price:238.35
# implied volatility:0.00%
# contract name:AMZN180323P01680000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,680.00
# last price:219.65
# bid price:252.85
# ask price:257.85
# implied volatility:0.00%
# contract name:AMZN180323P01690000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,690.00
# last price:240.40
# bid price:262.25
# ask price:267.25
# implied volatility:0.00%
# contract name:AMZN180323P02010000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:2,010.00
# last price:547.00
# bid price:577.60
# ask price:582.60
# implied volatility:0.00%
# contract name:AMZN180323P01060000
# last_trade_date:2018-02-05 2:18PM EST
# strike price:1,060.00
# last price:1.99
# bid price:2.21
# ask price:3.85
# implied volatility:45.19%
# contract name:AMZN180323P01130000
# last_trade_date:2018-02-05 11:40AM EST
# strike price:1,130.00
# last price:2.80
# bid price:5.10
# ask price:6.75
# implied volatility:41.17%
# contract name:AMZN180323P01170000
# last_trade_date:2018-02-05 12:55PM EST
# strike price:1,170.00
# last price:4.24
# bid price:7.45
# ask price:9.80
# implied volatility:39.50%
# contract name:AMZN180323P01180000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,180.00
# last price:5.67
# bid price:5.25
# ask price:6.20
# implied volatility:33.61%
# contract name:AMZN180323P01190000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,190.00
# last price:4.50
# bid price:5.40
# ask price:6.90
# implied volatility:33.19%
# contract name:AMZN180323P01200000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:1,200.00
# last price:8.50
# bid price:10.20
# ask price:13.55
# implied volatility:38.91%
# contract name:AMZN180323P01240000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,240.00
# last price:17.95
# bid price:16.00
# ask price:20.30
# implied volatility:38.15%
# contract name:AMZN180323P01250000
# last_trade_date:2018-02-05 2:07PM EST
# strike price:1,250.00
# last price:11.00
# bid price:17.50
# ask price:22.00
# implied volatility:37.71%
# contract name:AMZN180323P01260000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:1,260.00
# last price:17.78
# bid price:19.20
# ask price:23.50
# implied volatility:37.05%
# contract name:AMZN180323P01270000
# last_trade_date:2018-02-05 2:24PM EST
# strike price:1,270.00
# last price:15.20
# bid price:21.15
# ask price:25.95
# implied volatility:36.95%
# contract name:AMZN180323P01280000
# last_trade_date:2018-02-05 9:43AM EST
# strike price:1,280.00
# last price:21.82
# bid price:23.30
# ask price:28.05
# implied volatility:36.50%
# contract name:AMZN180323P01300000
# last_trade_date:2018-02-05 1:19PM EST
# strike price:1,300.00
# last price:20.35
# bid price:28.15
# ask price:32.90
# implied volatility:35.74%
# contract name:AMZN180323P01310000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,310.00
# last price:21.90
# bid price:30.95
# ask price:35.70
# implied volatility:35.42%
# contract name:AMZN180323P01320000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,320.00
# last price:24.55
# bid price:33.70
# ask price:38.50
# implied volatility:35.00%
# contract name:AMZN180323P01330000
# last_trade_date:2018-02-05 10:54AM EST
# strike price:1,330.00
# last price:20.93
# bid price:36.90
# ask price:41.65
# implied volatility:34.67%
# contract name:AMZN180323P01340000
# last_trade_date:2018-02-05 9:43AM EST
# strike price:1,340.00
# last price:38.50
# bid price:40.80
# ask price:45.15
# implied volatility:34.42%
# contract name:AMZN180323P01350000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,350.00
# last price:32.92
# bid price:43.85
# ask price:48.60
# implied volatility:34.04%
# contract name:AMZN180323P01360000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:1,360.00
# last price:36.00
# bid price:47.85
# ask price:52.65
# implied volatility:33.85%
# contract name:AMZN180323P01370000
# last_trade_date:2018-02-05 10:03AM EST
# strike price:1,370.00
# last price:41.60
# bid price:51.55
# ask price:56.30
# implied volatility:33.34%
# contract name:AMZN180323P01380000
# last_trade_date:2018-02-05 11:34AM EST
# strike price:1,380.00
# last price:35.13
# bid price:56.75
# ask price:61.10
# implied volatility:33.30%
# contract name:AMZN180323P01390000
# last_trade_date:2018-02-05 1:44PM EST
# strike price:1,390.00
# last price:45.91
# bid price:60.50
# ask price:65.30
# implied volatility:32.84%
# contract name:AMZN180323P01400000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,400.00
# last price:65.00
# bid price:65.70
# ask price:70.25
# implied volatility:32.64%
# contract name:AMZN180323P01410000
# last_trade_date:2018-02-05 10:23AM EST
# strike price:1,410.00
# last price:45.21
# bid price:70.25
# ask price:75.15
# implied volatility:32.29%
# contract name:AMZN180323P01415000
# last_trade_date:2018-02-05 1:30PM EST
# strike price:1,415.00
# last price:58.15
# bid price:73.05
# ask price:78.10
# implied volatility:32.32%
# contract name:AMZN180323P01420000
# last_trade_date:2018-02-05 10:40AM EST
# strike price:1,420.00
# last price:50.98
# bid price:76.40
# ask price:80.50
# implied volatility:32.04%
# contract name:AMZN180323P01425000
# last_trade_date:2018-02-05 3:02PM EST
# strike price:1,425.00
# last price:75.00
# bid price:79.15
# ask price:83.60
# implied volatility:32.08%
# contract name:AMZN180323P01430000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,430.00
# last price:65.30
# bid price:62.95
# ask price:66.40
# implied volatility:21.57%
# contract name:AMZN180323P01432500
# last_trade_date:2018-02-05 1:19PM EST
# strike price:1,432.50
# last price:65.90
# bid price:82.35
# ask price:87.25
# implied volatility:31.58%
# contract name:AMZN180323P01435000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,435.00
# last price:83.97
# bid price:83.20
# ask price:88.80
# implied volatility:31.57%
# contract name:AMZN180323P01440000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,440.00
# last price:86.34
# bid price:86.60
# ask price:91.45
# implied volatility:31.29%
# contract name:AMZN180323P01442500
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,442.50
# last price:58.10
# bid price:70.15
# ask price:72.65
# implied volatility:20.33%
# contract name:AMZN180323P01445000
# last_trade_date:2018-02-05 2:49PM EST
# strike price:1,445.00
# last price:73.70
# bid price:90.15
# ask price:94.70
# implied volatility:31.29%
# contract name:AMZN180323P01450000
# last_trade_date:2018-02-05 12:00PM EST
# strike price:1,450.00
# last price:65.00
# bid price:92.35
# ask price:96.65
# implied volatility:30.57%
# contract name:AMZN180323P01455000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,455.00
# last price:62.76
# bid price:76.00
# ask price:80.25
# implied volatility:19.43%
# contract name:AMZN180323P01460000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,460.00
# last price:56.76
# bid price:78.70
# ask price:82.15
# implied volatility:18.21%
# contract name:AMZN180323P01462500
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,462.50
# last price:59.05
# bid price:80.00
# ask price:83.65
# implied volatility:17.90%
# contract name:AMZN180323P01465000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,465.00
# last price:86.55
# bid price:81.40
# ask price:85.25
# implied volatility:17.62%
# contract name:AMZN180323P01470000
# last_trade_date:2018-02-05 10:11AM EST
# strike price:1,470.00
# last price:80.52
# bid price:105.05
# ask price:110.05
# implied volatility:30.32%
# contract name:AMZN180323P01475000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,475.00
# last price:74.95
# bid price:88.60
# ask price:91.15
# implied volatility:15.79%
# contract name:AMZN180323P01477500
# last_trade_date:2018-02-05 2:55PM EST
# strike price:1,477.50
# last price:110.00
# bid price:109.95
# ask price:114.75
# implied volatility:29.91%
# contract name:AMZN180323P01487500
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,487.50
# last price:83.82
# bid price:95.25
# ask price:99.95
# implied volatility:13.38%
# contract name:AMZN180323P01490000
# last_trade_date:2018-02-05 9:35AM EST
# strike price:1,490.00
# last price:117.74
# bid price:118.55
# ask price:123.40
# implied volatility:29.51%
# contract name:AMZN180323P01492500
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,492.50
# last price:104.20
# bid price:98.70
# ask price:102.10
# implied volatility:0.00%
# contract name:AMZN180323P01495000
# last_trade_date:2018-02-05 12:17PM EST
# strike price:1,495.00
# last price:95.40
# bid price:122.00
# ask price:127.00
# implied volatility:29.36%
# contract name:AMZN180323P01500000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:1,500.00
# last price:130.10
# bid price:125.40
# ask price:130.10
# implied volatility:28.87%
# contract name:AMZN180323P01510000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,510.00
# last price:85.85
# bid price:111.20
# ask price:113.90
# implied volatility:0.00%
# contract name:AMZN180323P01520000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,520.00
# last price:105.35
# bid price:117.15
# ask price:121.50
# implied volatility:0.00%
# contract name:AMZN180323P01535000
# last_trade_date:2018-02-05 2:01PM EST
# strike price:1,535.00
# last price:119.85
# bid price:152.50
# ask price:157.50
# implied volatility:28.01%
# contract name:AMZN180323P01545000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,545.00
# last price:109.40
# bid price:136.35
# ask price:139.95
# implied volatility:0.00%
# contract name:AMZN180323P01555000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,555.00
# last price:116.60
# bid price:143.80
# ask price:147.80
# implied volatility:0.00%
# contract name:AMZN180323P01595000
# last_trade_date:2018-02-05 2:49PM EST
# strike price:1,595.00
# last price:183.45
# bid price:201.00
# ask price:205.95
# implied volatility:19.51%
# contract name:AMZN180323P01600000
# last_trade_date:2018-02-05 2:49PM EST
# strike price:1,600.00
# last price:187.65
# bid price:205.20
# ask price:209.25
# implied volatility:0.00%
# contract name:AMZN180323P01660000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,660.00
# last price:225.80
# bid price:234.35
# ask price:238.35
# implied volatility:0.00%
# contract name:AMZN180323P01680000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,680.00
# last price:219.65
# bid price:252.85
# ask price:257.85
# implied volatility:0.00%
# contract name:AMZN180323P01690000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:1,690.00
# last price:240.40
# bid price:262.25
# ask price:267.25
# implied volatility:0.00%
# contract name:AMZN180323P02010000
# last_trade_date:2018-02-02 11:48PM EST
# strike price:2,010.00
# last price:547.00
# bid price:577.60
# ask price:582.60
# implied volatility:0.00%

# %%
# Out:
# '900.00'

# %%
# Out:
# '519.25'
