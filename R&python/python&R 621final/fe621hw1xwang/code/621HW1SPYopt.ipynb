# %%
from bs4 import BeautifulSoup as soup

# %%
from urllib.request import urlopen as uReq

# %%
my_url ='https://finance.yahoo.com/quote/SPY/options?p=SPY&date=1524182400'

# %%
uClient = uReq(my_url)

# %%
page_html = uClient.read()

# %%
uClient.close()

# %%
page_soup = soup(page_html,'lxml')

# %%
page_soup.body.span
# Out:
# <span data-reactid="7">Summary</span>

# %%
containers=page_soup.findAll('tbody')

# %%
calls=containers[0]

# %%
puts=containers[1]

# %%
len(containers)
# Out:
# 2

# %%
filename='SPYcallopt.csv'
f=open(filename,'w')

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price\n'

# %%
f.write(headers)
# Out:
# 74

# %%
for container in containers:
    for call in calls:
        title_container=call.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=call.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=call.findAll('a',{'href':'/quote/SPY/options?strike=false&straddle=false'})
        strike_price=strike_price2[0].text
    
        lp=call.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=call.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=call.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
    
        f.write(contract_name+','+last_trade_date+','+strike_price.replace(',','')+','+last_price+','+bid_price+','+ask_price+'\n')

f.close()
# Out:
# contract name:SPY180420C00185000
# last_trade_date:2018-01-23 11:43AM EST
# strike price:185.00
# last price:98.82
# bid price:102.12
# ask price:102.47
# contract name:SPY180420C00190000
# last_trade_date:2018-01-19 9:59AM EST
# strike price:190.00
# last price:90.52
# bid price:90.84
# ask price:91.15
# contract name:SPY180420C00195000
# last_trade_date:2018-01-25 1:57PM EST
# strike price:195.00
# last price:89.50
# bid price:92.17
# ask price:92.49
# contract name:SPY180420C00200000
# last_trade_date:2018-02-02 3:59PM EST
# strike price:200.00
# last price:76.53
# bid price:75.76
# ask price:76.17
# contract name:SPY180420C00205000
# last_trade_date:2018-01-29 11:42AM EST
# strike price:205.00
# last price:81.01
# bid price:70.81
# ask price:71.20
# contract name:SPY180420C00210000
# last_trade_date:2018-01-31 10:25AM EST
# strike price:210.00
# last price:73.79
# bid price:65.86
# ask price:66.25
# contract name:SPY180420C00215000
# last_trade_date:2018-02-02 3:59PM EST
# strike price:215.00
# last price:61.69
# bid price:60.93
# ask price:61.31
# contract name:SPY180420C00220000
# last_trade_date:2018-01-30 11:04AM EST
# strike price:220.00
# last price:63.60
# bid price:56.01
# ask price:56.39
# contract name:SPY180420C00225000
# last_trade_date:2018-02-02 3:59PM EST
# strike price:225.00
# last price:51.87
# bid price:51.12
# ask price:51.50
# contract name:SPY180420C00230000
# last_trade_date:2018-02-01 9:32AM EST
# strike price:230.00
# last price:52.27
# bid price:46.27
# ask price:46.63
# contract name:SPY180420C00235000
# last_trade_date:2018-02-02 3:57PM EST
# strike price:235.00
# last price:41.97
# bid price:41.46
# ask price:41.81
# contract name:SPY180420C00240000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:240.00
# last price:31.21
# bid price:31.12
# ask price:31.52
# contract name:SPY180420C00245000
# last_trade_date:2018-02-05 1:59PM EST
# strike price:245.00
# last price:30.20
# bid price:26.99
# ask price:27.23
# contract name:SPY180420C00250000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:250.00
# last price:22.56
# bid price:22.29
# ask price:22.55
# contract name:SPY180420C00251000
# last_trade_date:2018-02-05 2:32PM EST
# strike price:251.00
# last price:23.54
# bid price:21.46
# ask price:22.05
# contract name:SPY180420C00252000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:252.00
# last price:22.96
# bid price:20.65
# ask price:20.92
# contract name:SPY180420C00253000
# last_trade_date:2018-02-05 2:32PM EST
# strike price:253.00
# last price:21.83
# bid price:20.32
# ask price:20.53
# contract name:SPY180420C00254000
# last_trade_date:2018-02-05 2:44PM EST
# strike price:254.00
# last price:20.65
# bid price:18.20
# ask price:19.90
# contract name:SPY180420C00255000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:255.00
# last price:18.46
# bid price:17.40
# ask price:19.11
# contract name:SPY180420C00256000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:256.00
# last price:17.89
# bid price:16.60
# ask price:18.33
# contract name:SPY180420C00257000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:257.00
# last price:16.97
# bid price:16.71
# ask price:16.97
# contract name:SPY180420C00258000
# last_trade_date:2018-02-05 2:30PM EST
# strike price:258.00
# last price:17.56
# bid price:14.83
# ask price:16.28
# contract name:SPY180420C00259000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:259.00
# last price:15.43
# bid price:15.41
# ask price:15.64
# contract name:SPY180420C00260000
# last_trade_date:2018-02-05 3:03PM EST
# strike price:260.00
# last price:15.43
# bid price:14.86
# ask price:15.05
# contract name:SPY180420C00261000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:261.00
# last price:14.09
# bid price:14.11
# ask price:14.29
# contract name:SPY180420C00262000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:262.00
# last price:13.31
# bid price:12.85
# ask price:13.71
# contract name:SPY180420C00263000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:263.00
# last price:12.61
# bid price:12.64
# ask price:12.80
# contract name:SPY180420C00264000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:264.00
# last price:12.12
# bid price:11.92
# ask price:12.07
# contract name:SPY180420C00265000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:265.00
# last price:11.04
# bid price:11.03
# ask price:11.21
# contract name:SPY180420C00266000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:266.00
# last price:10.53
# bid price:10.01
# ask price:10.83
# contract name:SPY180420C00267000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:267.00
# last price:10.10
# bid price:9.64
# ask price:9.77
# contract name:SPY180420C00268000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:268.00
# last price:9.04
# bid price:8.87
# ask price:8.99
# contract name:SPY180420C00269000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:269.00
# last price:8.32
# bid price:8.26
# ask price:8.42
# contract name:SPY180420C00270000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:270.00
# last price:7.82
# bid price:7.58
# ask price:7.71
# contract name:SPY180420C00271000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:271.00
# last price:7.09
# bid price:6.86
# ask price:7.20
# contract name:SPY180420C00272000
# last_trade_date:2018-02-05 3:00PM EST
# strike price:272.00
# last price:6.70
# bid price:6.15
# ask price:7.10
# contract name:SPY180420C00273000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:273.00
# last price:5.89
# bid price:5.56
# ask price:6.46
# contract name:SPY180420C00274000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:274.00
# last price:5.19
# bid price:5.20
# ask price:5.40
# contract name:SPY180420C00275000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:275.00
# last price:4.82
# bid price:4.65
# ask price:4.85
# contract name:SPY180420C00276000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:276.00
# last price:4.27
# bid price:3.96
# ask price:4.85
# contract name:SPY180420C00277000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:277.00
# last price:3.74
# bid price:3.65
# ask price:3.90
# contract name:SPY180420C00278000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:278.00
# last price:3.28
# bid price:3.18
# ask price:3.30
# contract name:SPY180420C00279000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:279.00
# last price:3.07
# bid price:2.78
# ask price:2.97
# contract name:SPY180420C00280000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:280.00
# last price:2.50
# bid price:2.51
# ask price:2.61
# contract name:SPY180420C00281000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:281.00
# last price:2.19
# bid price:2.02
# ask price:2.25
# contract name:SPY180420C00282000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:282.00
# last price:2.00
# bid price:1.45
# ask price:1.95
# contract name:SPY180420C00283000
# last_trade_date:2018-02-05 3:02PM EST
# strike price:283.00
# last price:1.63
# bid price:1.52
# ask price:1.63
# contract name:SPY180420C00284000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:284.00
# last price:1.35
# bid price:1.21
# ask price:1.38
# contract name:SPY180420C00285000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:285.00
# last price:1.09
# bid price:1.04
# ask price:1.15
# contract name:SPY180420C00286000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:286.00
# last price:0.89
# bid price:0.75
# ask price:0.93
# contract name:SPY180420C00287000
# last_trade_date:2018-02-05 3:02PM EST
# strike price:287.00
# last price:0.77
# bid price:0.66
# ask price:0.80
# contract name:SPY180420C00288000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:288.00
# last price:0.57
# bid price:0.54
# ask price:0.67
# contract name:SPY180420C00289000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:289.00
# last price:0.53
# bid price:0.40
# ask price:0.52
# contract name:SPY180420C00290000
# last_trade_date:2018-02-05 3:03PM EST
# strike price:290.00
# last price:0.43
# bid price:0.40
# ask price:0.43
# contract name:SPY180420C00291000
# last_trade_date:2018-02-05 2:58PM EST
# strike price:291.00
# last price:0.35
# bid price:0.29
# ask price:0.40
# contract name:SPY180420C00292000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:292.00
# last price:0.30
# bid price:0.20
# ask price:0.35
# contract name:SPY180420C00293000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:293.00
# last price:0.22
# bid price:0.15
# ask price:0.31
# contract name:SPY180420C00294000
# last_trade_date:2018-02-05 2:33PM EST
# strike price:294.00
# last price:0.25
# bid price:0.16
# ask price:0.27
# contract name:SPY180420C00295000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:295.00
# last price:0.20
# bid price:0.15
# ask price:0.24
# contract name:SPY180420C00296000
# last_trade_date:2018-02-05 1:57PM EST
# strike price:296.00
# last price:0.19
# bid price:0.11
# ask price:0.25
# contract name:SPY180420C00297000
# last_trade_date:2018-02-05 2:51PM EST
# strike price:297.00
# last price:0.17
# bid price:0.10
# ask price:0.23
# contract name:SPY180420C00298000
# last_trade_date:2018-02-05 1:37PM EST
# strike price:298.00
# last price:0.13
# bid price:0.08
# ask price:0.22
# contract name:SPY180420C00299000
# last_trade_date:2018-02-05 2:33PM EST
# strike price:299.00
# last price:0.14
# bid price:0.07
# ask price:0.23
# contract name:SPY180420C00300000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:300.00
# last price:0.15
# bid price:0.13
# ask price:0.16
# contract name:SPY180420C00301000
# last_trade_date:2018-02-05 2:00PM EST
# strike price:301.00
# last price:0.10
# bid price:0.05
# ask price:0.18
# contract name:SPY180420C00302000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:302.00
# last price:0.11
# bid price:0.00
# ask price:0.17
# contract name:SPY180420C00303000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:303.00
# last price:0.08
# bid price:0.03
# ask price:0.11
# contract name:SPY180420C00304000
# last_trade_date:2018-02-02 11:50AM EST
# strike price:304.00
# last price:0.17
# bid price:0.09
# ask price:0.12
# contract name:SPY180420C00305000
# last_trade_date:2018-02-05 1:38PM EST
# strike price:305.00
# last price:0.05
# bid price:0.05
# ask price:0.12
# contract name:SPY180420C00306000
# last_trade_date:2018-02-05 11:36AM EST
# strike price:306.00
# last price:0.10
# bid price:0.01
# ask price:0.11
# contract name:SPY180420C00307000
# last_trade_date:2018-02-02 3:03PM EST
# strike price:307.00
# last price:0.06
# bid price:0.06
# ask price:0.09
# contract name:SPY180420C00308000
# last_trade_date:2018-02-02 9:35AM EST
# strike price:308.00
# last price:0.12
# bid price:0.05
# ask price:0.08
# contract name:SPY180420C00309000
# last_trade_date:2018-02-05 1:42PM EST
# strike price:309.00
# last price:0.05
# bid price:0.00
# ask price:0.09
# contract name:SPY180420C00310000
# last_trade_date:2018-02-05 2:12PM EST
# strike price:310.00
# last price:0.04
# bid price:0.03
# ask price:0.06
# contract name:SPY180420C00311000
# last_trade_date:2018-02-05 2:17PM EST
# strike price:311.00
# last price:0.04
# bid price:0.00
# ask price:0.09
# contract name:SPY180420C00312000
# last_trade_date:2018-01-29 3:41PM EST
# strike price:312.00
# last price:0.18
# bid price:0.03
# ask price:0.06
# contract name:SPY180420C00313000
# last_trade_date:2018-02-02 1:24PM EST
# strike price:313.00
# last price:0.06
# bid price:0.03
# ask price:0.06
# contract name:SPY180420C00314000
# last_trade_date:2018-02-05 9:58AM EST
# strike price:314.00
# last price:0.05
# bid price:0.00
# ask price:0.55
# contract name:SPY180420C00315000
# last_trade_date:2018-02-05 10:45AM EST
# strike price:315.00
# last price:0.06
# bid price:0.00
# ask price:0.08
# contract name:SPY180420C00316000
# last_trade_date:2018-02-05 9:33AM EST
# strike price:316.00
# last price:0.03
# bid price:0.00
# ask price:0.08
# contract name:SPY180420C00320000
# last_trade_date:2018-02-02 2:43PM EST
# strike price:320.00
# last price:0.03
# bid price:0.01
# ask price:0.04
# contract name:SPY180420C00325000
# last_trade_date:2018-02-05 2:04PM EST
# strike price:325.00
# last price:0.02
# bid price:0.00
# ask price:0.08
# contract name:SPY180420C00330000
# last_trade_date:2018-02-05 10:46AM EST
# strike price:330.00
# last price:0.02
# bid price:0.00
# ask price:0.07
# contract name:SPY180420C00335000
# last_trade_date:2018-02-01 4:14PM EST
# strike price:335.00
# last price:0.02
# bid price:0.00
# ask price:0.03
# contract name:SPY180420C00340000
# last_trade_date:2018-02-02 11:45PM EST
# strike price:340.00
# last price:0.03
# bid price:0.00
# ask price:0.02
# contract name:SPY180420C00185000
# last_trade_date:2018-01-23 11:43AM EST
# strike price:185.00
# last price:98.82
# bid price:102.12
# ask price:102.47
# contract name:SPY180420C00190000
# last_trade_date:2018-01-19 9:59AM EST
# strike price:190.00
# last price:90.52
# bid price:90.84
# ask price:91.15
# contract name:SPY180420C00195000
# last_trade_date:2018-01-25 1:57PM EST
# strike price:195.00
# last price:89.50
# bid price:92.17
# ask price:92.49
# contract name:SPY180420C00200000
# last_trade_date:2018-02-02 3:59PM EST
# strike price:200.00
# last price:76.53
# bid price:75.76
# ask price:76.17
# contract name:SPY180420C00205000
# last_trade_date:2018-01-29 11:42AM EST
# strike price:205.00
# last price:81.01
# bid price:70.81
# ask price:71.20
# contract name:SPY180420C00210000
# last_trade_date:2018-01-31 10:25AM EST
# strike price:210.00
# last price:73.79
# bid price:65.86
# ask price:66.25
# contract name:SPY180420C00215000
# last_trade_date:2018-02-02 3:59PM EST
# strike price:215.00
# last price:61.69
# bid price:60.93
# ask price:61.31
# contract name:SPY180420C00220000
# last_trade_date:2018-01-30 11:04AM EST
# strike price:220.00
# last price:63.60
# bid price:56.01
# ask price:56.39
# contract name:SPY180420C00225000
# last_trade_date:2018-02-02 3:59PM EST
# strike price:225.00
# last price:51.87
# bid price:51.12
# ask price:51.50
# contract name:SPY180420C00230000
# last_trade_date:2018-02-01 9:32AM EST
# strike price:230.00
# last price:52.27
# bid price:46.27
# ask price:46.63
# contract name:SPY180420C00235000
# last_trade_date:2018-02-02 3:57PM EST
# strike price:235.00
# last price:41.97
# bid price:41.46
# ask price:41.81
# contract name:SPY180420C00240000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:240.00
# last price:31.21
# bid price:31.12
# ask price:31.52
# contract name:SPY180420C00245000
# last_trade_date:2018-02-05 1:59PM EST
# strike price:245.00
# last price:30.20
# bid price:26.99
# ask price:27.23
# contract name:SPY180420C00250000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:250.00
# last price:22.56
# bid price:22.29
# ask price:22.55
# contract name:SPY180420C00251000
# last_trade_date:2018-02-05 2:32PM EST
# strike price:251.00
# last price:23.54
# bid price:21.46
# ask price:22.05
# contract name:SPY180420C00252000
# last_trade_date:2018-02-05 2:22PM EST
# strike price:252.00
# last price:22.96
# bid price:20.65
# ask price:20.92
# contract name:SPY180420C00253000
# last_trade_date:2018-02-05 2:32PM EST
# strike price:253.00
# last price:21.83
# bid price:20.32
# ask price:20.53
# contract name:SPY180420C00254000
# last_trade_date:2018-02-05 2:44PM EST
# strike price:254.00
# last price:20.65
# bid price:18.20
# ask price:19.90
# contract name:SPY180420C00255000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:255.00
# last price:18.46
# bid price:17.40
# ask price:19.11
# contract name:SPY180420C00256000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:256.00
# last price:17.89
# bid price:16.60
# ask price:18.33
# contract name:SPY180420C00257000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:257.00
# last price:16.97
# bid price:16.71
# ask price:16.97
# contract name:SPY180420C00258000
# last_trade_date:2018-02-05 2:30PM EST
# strike price:258.00
# last price:17.56
# bid price:14.83
# ask price:16.28
# contract name:SPY180420C00259000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:259.00
# last price:15.43
# bid price:15.41
# ask price:15.64
# contract name:SPY180420C00260000
# last_trade_date:2018-02-05 3:03PM EST
# strike price:260.00
# last price:15.43
# bid price:14.86
# ask price:15.05
# contract name:SPY180420C00261000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:261.00
# last price:14.09
# bid price:14.11
# ask price:14.29
# contract name:SPY180420C00262000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:262.00
# last price:13.31
# bid price:12.85
# ask price:13.71
# contract name:SPY180420C00263000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:263.00
# last price:12.61
# bid price:12.64
# ask price:12.80
# contract name:SPY180420C00264000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:264.00
# last price:12.12
# bid price:11.92
# ask price:12.07
# contract name:SPY180420C00265000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:265.00
# last price:11.04
# bid price:11.03
# ask price:11.21
# contract name:SPY180420C00266000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:266.00
# last price:10.53
# bid price:10.01
# ask price:10.83
# contract name:SPY180420C00267000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:267.00
# last price:10.10
# bid price:9.64
# ask price:9.77
# contract name:SPY180420C00268000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:268.00
# last price:9.04
# bid price:8.87
# ask price:8.99
# contract name:SPY180420C00269000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:269.00
# last price:8.32
# bid price:8.26
# ask price:8.42
# contract name:SPY180420C00270000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:270.00
# last price:7.82
# bid price:7.58
# ask price:7.71
# contract name:SPY180420C00271000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:271.00
# last price:7.09
# bid price:6.86
# ask price:7.20
# contract name:SPY180420C00272000
# last_trade_date:2018-02-05 3:00PM EST
# strike price:272.00
# last price:6.70
# bid price:6.15
# ask price:7.10
# contract name:SPY180420C00273000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:273.00
# last price:5.89
# bid price:5.56
# ask price:6.46
# contract name:SPY180420C00274000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:274.00
# last price:5.19
# bid price:5.20
# ask price:5.40
# contract name:SPY180420C00275000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:275.00
# last price:4.82
# bid price:4.65
# ask price:4.85
# contract name:SPY180420C00276000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:276.00
# last price:4.27
# bid price:3.96
# ask price:4.85
# contract name:SPY180420C00277000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:277.00
# last price:3.74
# bid price:3.65
# ask price:3.90
# contract name:SPY180420C00278000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:278.00
# last price:3.28
# bid price:3.18
# ask price:3.30
# contract name:SPY180420C00279000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:279.00
# last price:3.07
# bid price:2.78
# ask price:2.97
# contract name:SPY180420C00280000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:280.00
# last price:2.50
# bid price:2.51
# ask price:2.61
# contract name:SPY180420C00281000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:281.00
# last price:2.19
# bid price:2.02
# ask price:2.25
# contract name:SPY180420C00282000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:282.00
# last price:2.00
# bid price:1.45
# ask price:1.95
# contract name:SPY180420C00283000
# last_trade_date:2018-02-05 3:02PM EST
# strike price:283.00
# last price:1.63
# bid price:1.52
# ask price:1.63
# contract name:SPY180420C00284000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:284.00
# last price:1.35
# bid price:1.21
# ask price:1.38
# contract name:SPY180420C00285000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:285.00
# last price:1.09
# bid price:1.04
# ask price:1.15
# contract name:SPY180420C00286000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:286.00
# last price:0.89
# bid price:0.75
# ask price:0.93
# contract name:SPY180420C00287000
# last_trade_date:2018-02-05 3:02PM EST
# strike price:287.00
# last price:0.77
# bid price:0.66
# ask price:0.80
# contract name:SPY180420C00288000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:288.00
# last price:0.57
# bid price:0.54
# ask price:0.67
# contract name:SPY180420C00289000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:289.00
# last price:0.53
# bid price:0.40
# ask price:0.52
# contract name:SPY180420C00290000
# last_trade_date:2018-02-05 3:03PM EST
# strike price:290.00
# last price:0.43
# bid price:0.40
# ask price:0.43
# contract name:SPY180420C00291000
# last_trade_date:2018-02-05 2:58PM EST
# strike price:291.00
# last price:0.35
# bid price:0.29
# ask price:0.40
# contract name:SPY180420C00292000
# last_trade_date:2018-02-05 2:54PM EST
# strike price:292.00
# last price:0.30
# bid price:0.20
# ask price:0.35
# contract name:SPY180420C00293000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:293.00
# last price:0.22
# bid price:0.15
# ask price:0.31
# contract name:SPY180420C00294000
# last_trade_date:2018-02-05 2:33PM EST
# strike price:294.00
# last price:0.25
# bid price:0.16
# ask price:0.27
# contract name:SPY180420C00295000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:295.00
# last price:0.20
# bid price:0.15
# ask price:0.24
# contract name:SPY180420C00296000
# last_trade_date:2018-02-05 1:57PM EST
# strike price:296.00
# last price:0.19
# bid price:0.11
# ask price:0.25
# contract name:SPY180420C00297000
# last_trade_date:2018-02-05 2:51PM EST
# strike price:297.00
# last price:0.17
# bid price:0.10
# ask price:0.23
# contract name:SPY180420C00298000
# last_trade_date:2018-02-05 1:37PM EST
# strike price:298.00
# last price:0.13
# bid price:0.08
# ask price:0.22
# contract name:SPY180420C00299000
# last_trade_date:2018-02-05 2:33PM EST
# strike price:299.00
# last price:0.14
# bid price:0.07
# ask price:0.23
# contract name:SPY180420C00300000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:300.00
# last price:0.15
# bid price:0.13
# ask price:0.16
# contract name:SPY180420C00301000
# last_trade_date:2018-02-05 2:00PM EST
# strike price:301.00
# last price:0.10
# bid price:0.05
# ask price:0.18
# contract name:SPY180420C00302000
# last_trade_date:2018-02-05 2:52PM EST
# strike price:302.00
# last price:0.11
# bid price:0.00
# ask price:0.17
# contract name:SPY180420C00303000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:303.00
# last price:0.08
# bid price:0.03
# ask price:0.11
# contract name:SPY180420C00304000
# last_trade_date:2018-02-02 11:50AM EST
# strike price:304.00
# last price:0.17
# bid price:0.09
# ask price:0.12
# contract name:SPY180420C00305000
# last_trade_date:2018-02-05 1:38PM EST
# strike price:305.00
# last price:0.05
# bid price:0.05
# ask price:0.12
# contract name:SPY180420C00306000
# last_trade_date:2018-02-05 11:36AM EST
# strike price:306.00
# last price:0.10
# bid price:0.01
# ask price:0.11
# contract name:SPY180420C00307000
# last_trade_date:2018-02-02 3:03PM EST
# strike price:307.00
# last price:0.06
# bid price:0.06
# ask price:0.09
# contract name:SPY180420C00308000
# last_trade_date:2018-02-02 9:35AM EST
# strike price:308.00
# last price:0.12
# bid price:0.05
# ask price:0.08
# contract name:SPY180420C00309000
# last_trade_date:2018-02-05 1:42PM EST
# strike price:309.00
# last price:0.05
# bid price:0.00
# ask price:0.09
# contract name:SPY180420C00310000
# last_trade_date:2018-02-05 2:12PM EST
# strike price:310.00
# last price:0.04
# bid price:0.03
# ask price:0.06
# contract name:SPY180420C00311000
# last_trade_date:2018-02-05 2:17PM EST
# strike price:311.00
# last price:0.04
# bid price:0.00
# ask price:0.09
# contract name:SPY180420C00312000
# last_trade_date:2018-01-29 3:41PM EST
# strike price:312.00
# last price:0.18
# bid price:0.03
# ask price:0.06
# contract name:SPY180420C00313000
# last_trade_date:2018-02-02 1:24PM EST
# strike price:313.00
# last price:0.06
# bid price:0.03
# ask price:0.06
# contract name:SPY180420C00314000
# last_trade_date:2018-02-05 9:58AM EST
# strike price:314.00
# last price:0.05
# bid price:0.00
# ask price:0.55
# contract name:SPY180420C00315000
# last_trade_date:2018-02-05 10:45AM EST
# strike price:315.00
# last price:0.06
# bid price:0.00
# ask price:0.08
# contract name:SPY180420C00316000
# last_trade_date:2018-02-05 9:33AM EST
# strike price:316.00
# last price:0.03
# bid price:0.00
# ask price:0.08
# contract name:SPY180420C00320000
# last_trade_date:2018-02-02 2:43PM EST
# strike price:320.00
# last price:0.03
# bid price:0.01
# ask price:0.04
# contract name:SPY180420C00325000
# last_trade_date:2018-02-05 2:04PM EST
# strike price:325.00
# last price:0.02
# bid price:0.00
# ask price:0.08
# contract name:SPY180420C00330000
# last_trade_date:2018-02-05 10:46AM EST
# strike price:330.00
# last price:0.02
# bid price:0.00
# ask price:0.07
# contract name:SPY180420C00335000
# last_trade_date:2018-02-01 4:14PM EST
# strike price:335.00
# last price:0.02
# bid price:0.00
# ask price:0.03
# contract name:SPY180420C00340000
# last_trade_date:2018-02-02 11:45PM EST
# strike price:340.00
# last price:0.03
# bid price:0.00
# ask price:0.02

# %%
filename='SPYputopt.csv'
f=open(filename,'w')
f.write(headers)
# Out:
# 74

# %%
headers='contract_name,last_trade_date,strike_price,last_price,bid_price,ask_price\n'

# %%
for container in containers:
    for put in puts:
        title_container=put.findAll('a',{'class':'Fz(s) Ell C($c-fuji-blue-1-b)'})
        contract_name=title_container[0].text
    
        time=put.findAll('td',{'class':'data-col1 Ta(end) Pstart(7px)'})
        last_trade_date=time[0].text
    
        strike_price2=put.findAll('a',{'href':'/quote/SPY/options?strike=false&straddle=false'})
        strike_price=strike_price2[0].text
    
        lp=put.findAll('td',{'class':'data-col3 Ta(end) Pstart(7px)'})
        last_price=lp[0].text
    
        bd=put.findAll('td',{'class':'data-col4 Ta(end) Pstart(7px)'})
        bid_price=bd[0].text
    
        askp=put.findAll('td',{'class':'data-col5 Ta(end) Pstart(7px)'})
        ask_price=askp[0].text
    
        print('contract name:'+contract_name)
        print('last_trade_date:'+last_trade_date)
        print('strike price:'+strike_price)
        print('last price:'+last_price)
        print('bid price:'+bid_price)
        print('ask price:'+ask_price)
    
        f.write(contract_name+','+last_trade_date+','+strike_price.replace(',','')+','+last_price+','+bid_price+','+ask_price+'\n')

f.close()
# Out:
# contract name:SPY180420P00185000
# last_trade_date:2018-02-05 3:00PM EST
# strike price:185.00
# last price:0.51
# bid price:0.56
# ask price:0.64
# contract name:SPY180420P00190000
# last_trade_date:2018-02-05 2:45PM EST
# strike price:190.00
# last price:0.41
# bid price:0.95
# ask price:1.43
# contract name:SPY180420P00195000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:195.00
# last price:0.55
# bid price:0.78
# ask price:0.84
# contract name:SPY180420P00200000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:200.00
# last price:0.82
# bid price:0.95
# ask price:1.03
# contract name:SPY180420P00205000
# last_trade_date:2018-02-05 2:23PM EST
# strike price:205.00
# last price:0.68
# bid price:1.14
# ask price:1.21
# contract name:SPY180420P00210000
# last_trade_date:2018-02-05 2:46PM EST
# strike price:210.00
# last price:0.80
# bid price:1.34
# ask price:1.40
# contract name:SPY180420P00215000
# last_trade_date:2018-02-05 2:36PM EST
# strike price:215.00
# last price:0.94
# bid price:1.60
# ask price:1.72
# contract name:SPY180420P00220000
# last_trade_date:2018-02-05 3:03PM EST
# strike price:220.00
# last price:1.59
# bid price:1.88
# ask price:2.06
# contract name:SPY180420P00225000
# last_trade_date:2018-02-05 3:00PM EST
# strike price:225.00
# last price:1.83
# bid price:2.29
# ask price:2.42
# contract name:SPY180420P00230000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:230.00
# last price:2.60
# bid price:2.56
# ask price:2.69
# contract name:SPY180420P00235000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:235.00
# last price:3.15
# bid price:3.92
# ask price:4.53
# contract name:SPY180420P00240000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:240.00
# last price:3.90
# bid price:3.72
# ask price:4.00
# contract name:SPY180420P00245000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:245.00
# last price:4.22
# bid price:4.45
# ask price:4.57
# contract name:SPY180420P00250000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:250.00
# last price:5.00
# bid price:5.21
# ask price:5.50
# contract name:SPY180420P00251000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:251.00
# last price:4.01
# bid price:5.35
# ask price:5.55
# contract name:SPY180420P00252000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:252.00
# last price:5.56
# bid price:5.60
# ask price:5.73
# contract name:SPY180420P00253000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:253.00
# last price:5.23
# bid price:5.78
# ask price:5.99
# contract name:SPY180420P00254000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:254.00
# last price:5.69
# bid price:5.97
# ask price:6.72
# contract name:SPY180420P00255000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:255.00
# last price:5.99
# bid price:6.21
# ask price:6.40
# contract name:SPY180420P00256000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:256.00
# last price:5.81
# bid price:6.43
# ask price:6.62
# contract name:SPY180420P00257000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:257.00
# last price:5.83
# bid price:6.73
# ask price:6.86
# contract name:SPY180420P00258000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:258.00
# last price:5.67
# bid price:6.82
# ask price:6.96
# contract name:SPY180420P00259000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:259.00
# last price:7.22
# bid price:7.02
# ask price:7.18
# contract name:SPY180420P00260000
# last_trade_date:2018-02-05 3:07PM EST
# strike price:260.00
# last price:7.53
# bid price:7.16
# ask price:7.46
# contract name:SPY180420P00261000
# last_trade_date:2018-02-05 2:59PM EST
# strike price:261.00
# last price:6.50
# bid price:7.30
# ask price:7.50
# contract name:SPY180420P00262000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:262.00
# last price:7.81
# bid price:7.68
# ask price:7.98
# contract name:SPY180420P00263000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:263.00
# last price:8.26
# bid price:8.13
# ask price:8.39
# contract name:SPY180420P00264000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:264.00
# last price:7.55
# bid price:8.45
# ask price:9.17
# contract name:SPY180420P00265000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:265.00
# last price:8.62
# bid price:8.66
# ask price:8.85
# contract name:SPY180420P00266000
# last_trade_date:2018-02-05 3:12PM EST
# strike price:266.00
# last price:11.00
# bid price:9.09
# ask price:9.29
# contract name:SPY180420P00267000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:267.00
# last price:9.32
# bid price:9.28
# ask price:9.39
# contract name:SPY180420P00268000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:268.00
# last price:8.74
# bid price:9.78
# ask price:10.04
# contract name:SPY180420P00269000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:269.00
# last price:9.02
# bid price:9.99
# ask price:10.27
# contract name:SPY180420P00270000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:270.00
# last price:10.58
# bid price:9.61
# ask price:11.00
# contract name:SPY180420P00271000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:271.00
# last price:10.98
# bid price:10.90
# ask price:10.96
# contract name:SPY180420P00272000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:272.00
# last price:10.77
# bid price:11.09
# ask price:11.26
# contract name:SPY180420P00273000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:273.00
# last price:11.24
# bid price:11.65
# ask price:11.97
# contract name:SPY180420P00274000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:274.00
# last price:10.04
# bid price:11.89
# ask price:12.18
# contract name:SPY180420P00275000
# last_trade_date:2018-02-05 3:07PM EST
# strike price:275.00
# last price:12.77
# bid price:12.42
# ask price:12.72
# contract name:SPY180420P00276000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:276.00
# last price:12.50
# bid price:12.50
# ask price:13.88
# contract name:SPY180420P00277000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:277.00
# last price:12.70
# bid price:13.44
# ask price:13.75
# contract name:SPY180420P00278000
# last_trade_date:2018-02-05 2:51PM EST
# strike price:278.00
# last price:11.88
# bid price:14.18
# ask price:14.48
# contract name:SPY180420P00279000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:279.00
# last price:13.50
# bid price:14.10
# ask price:15.59
# contract name:SPY180420P00280000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:280.00
# last price:14.40
# bid price:15.25
# ask price:15.55
# contract name:SPY180420P00281000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:281.00
# last price:14.29
# bid price:15.90
# ask price:16.22
# contract name:SPY180420P00282000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:282.00
# last price:15.49
# bid price:16.83
# ask price:17.17
# contract name:SPY180420P00283000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:283.00
# last price:16.97
# bid price:17.58
# ask price:17.93
# contract name:SPY180420P00284000
# last_trade_date:2018-02-05 2:44PM EST
# strike price:284.00
# last price:15.42
# bid price:20.07
# ask price:18.76
# contract name:SPY180420P00285000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:285.00
# last price:18.79
# bid price:18.49
# ask price:19.21
# contract name:SPY180420P00286000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:286.00
# last price:17.58
# bid price:19.59
# ask price:20.47
# contract name:SPY180420P00287000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:287.00
# last price:18.97
# bid price:20.46
# ask price:21.36
# contract name:SPY180420P00288000
# last_trade_date:2018-02-05 1:52PM EST
# strike price:288.00
# last price:17.15
# bid price:21.34
# ask price:22.23
# contract name:SPY180420P00289000
# last_trade_date:2018-02-05 1:34PM EST
# strike price:289.00
# last price:18.13
# bid price:22.25
# ask price:23.16
# contract name:SPY180420P00290000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:290.00
# last price:23.27
# bid price:23.18
# ask price:24.11
# contract name:SPY180420P00291000
# last_trade_date:2018-02-05 2:43PM EST
# strike price:291.00
# last price:21.10
# bid price:24.13
# ask price:29.24
# contract name:SPY180420P00292000
# last_trade_date:2018-02-05 1:58PM EST
# strike price:292.00
# last price:20.00
# bid price:25.08
# ask price:26.04
# contract name:SPY180420P00293000
# last_trade_date:2018-02-05 12:13PM EST
# strike price:293.00
# last price:19.70
# bid price:26.04
# ask price:27.00
# contract name:SPY180420P00294000
# last_trade_date:2018-02-05 11:31AM EST
# strike price:294.00
# last price:20.00
# bid price:27.01
# ask price:28.03
# contract name:SPY180420P00295000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:295.00
# last price:28.02
# bid price:27.58
# ask price:28.51
# contract name:SPY180420P00296000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:296.00
# last price:27.80
# bid price:28.99
# ask price:29.99
# contract name:SPY180420P00297000
# last_trade_date:2018-01-29 4:00PM EST
# strike price:297.00
# last price:13.66
# bid price:22.03
# ask price:22.42
# contract name:SPY180420P00298000
# last_trade_date:2018-01-31 2:54PM EST
# strike price:298.00
# last price:20.27
# bid price:22.99
# ask price:23.39
# contract name:SPY180420P00299000
# last_trade_date:2018-02-05 1:57PM EST
# strike price:299.00
# last price:26.96
# bid price:31.93
# ask price:32.96
# contract name:SPY180420P00300000
# last_trade_date:2018-02-02 2:11PM EST
# strike price:300.00
# last price:23.09
# bid price:24.94
# ask price:25.34
# contract name:SPY180420P00301000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:301.00
# last price:32.22
# bid price:33.91
# ask price:39.14
# contract name:SPY180420P00305000
# last_trade_date:2018-01-09 12:19PM EST
# strike price:305.00
# last price:30.23
# bid price:26.96
# ask price:27.26
# contract name:SPY180420P00310000
# last_trade_date:2018-01-05 11:50PM EST
# strike price:310.00
# last price:37.74
# bid price:36.37
# ask price:36.65
# contract name:SPY180420P00320000
# last_trade_date:2018-01-26 11:50PM EST
# strike price:320.00
# last price:35.97
# bid price:33.30
# ask price:33.63
# contract name:SPY180420P00325000
# last_trade_date:2018-01-05 11:50PM EST
# strike price:325.00
# last price:52.40
# bid price:51.35
# ask price:51.63
# contract name:SPY180420P00335000
# last_trade_date:2018-01-17 12:31PM EST
# strike price:335.00
# last price:56.28
# bid price:54.54
# ask price:54.88
# contract name:SPY180420P00340000
# last_trade_date:2018-01-30 9:37AM EST
# strike price:340.00
# last price:57.00
# bid price:64.75
# ask price:65.16
# contract name:SPY180420P00185000
# last_trade_date:2018-02-05 3:00PM EST
# strike price:185.00
# last price:0.51
# bid price:0.56
# ask price:0.64
# contract name:SPY180420P00190000
# last_trade_date:2018-02-05 2:45PM EST
# strike price:190.00
# last price:0.41
# bid price:0.95
# ask price:1.43
# contract name:SPY180420P00195000
# last_trade_date:2018-02-05 2:55PM EST
# strike price:195.00
# last price:0.55
# bid price:0.78
# ask price:0.84
# contract name:SPY180420P00200000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:200.00
# last price:0.82
# bid price:0.95
# ask price:1.03
# contract name:SPY180420P00205000
# last_trade_date:2018-02-05 2:23PM EST
# strike price:205.00
# last price:0.68
# bid price:1.14
# ask price:1.21
# contract name:SPY180420P00210000
# last_trade_date:2018-02-05 2:46PM EST
# strike price:210.00
# last price:0.80
# bid price:1.34
# ask price:1.40
# contract name:SPY180420P00215000
# last_trade_date:2018-02-05 2:36PM EST
# strike price:215.00
# last price:0.94
# bid price:1.60
# ask price:1.72
# contract name:SPY180420P00220000
# last_trade_date:2018-02-05 3:03PM EST
# strike price:220.00
# last price:1.59
# bid price:1.88
# ask price:2.06
# contract name:SPY180420P00225000
# last_trade_date:2018-02-05 3:00PM EST
# strike price:225.00
# last price:1.83
# bid price:2.29
# ask price:2.42
# contract name:SPY180420P00230000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:230.00
# last price:2.60
# bid price:2.56
# ask price:2.69
# contract name:SPY180420P00235000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:235.00
# last price:3.15
# bid price:3.92
# ask price:4.53
# contract name:SPY180420P00240000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:240.00
# last price:3.90
# bid price:3.72
# ask price:4.00
# contract name:SPY180420P00245000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:245.00
# last price:4.22
# bid price:4.45
# ask price:4.57
# contract name:SPY180420P00250000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:250.00
# last price:5.00
# bid price:5.21
# ask price:5.50
# contract name:SPY180420P00251000
# last_trade_date:2018-02-05 2:50PM EST
# strike price:251.00
# last price:4.01
# bid price:5.35
# ask price:5.55
# contract name:SPY180420P00252000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:252.00
# last price:5.56
# bid price:5.60
# ask price:5.73
# contract name:SPY180420P00253000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:253.00
# last price:5.23
# bid price:5.78
# ask price:5.99
# contract name:SPY180420P00254000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:254.00
# last price:5.69
# bid price:5.97
# ask price:6.72
# contract name:SPY180420P00255000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:255.00
# last price:5.99
# bid price:6.21
# ask price:6.40
# contract name:SPY180420P00256000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:256.00
# last price:5.81
# bid price:6.43
# ask price:6.62
# contract name:SPY180420P00257000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:257.00
# last price:5.83
# bid price:6.73
# ask price:6.86
# contract name:SPY180420P00258000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:258.00
# last price:5.67
# bid price:6.82
# ask price:6.96
# contract name:SPY180420P00259000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:259.00
# last price:7.22
# bid price:7.02
# ask price:7.18
# contract name:SPY180420P00260000
# last_trade_date:2018-02-05 3:07PM EST
# strike price:260.00
# last price:7.53
# bid price:7.16
# ask price:7.46
# contract name:SPY180420P00261000
# last_trade_date:2018-02-05 2:59PM EST
# strike price:261.00
# last price:6.50
# bid price:7.30
# ask price:7.50
# contract name:SPY180420P00262000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:262.00
# last price:7.81
# bid price:7.68
# ask price:7.98
# contract name:SPY180420P00263000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:263.00
# last price:8.26
# bid price:8.13
# ask price:8.39
# contract name:SPY180420P00264000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:264.00
# last price:7.55
# bid price:8.45
# ask price:9.17
# contract name:SPY180420P00265000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:265.00
# last price:8.62
# bid price:8.66
# ask price:8.85
# contract name:SPY180420P00266000
# last_trade_date:2018-02-05 3:12PM EST
# strike price:266.00
# last price:11.00
# bid price:9.09
# ask price:9.29
# contract name:SPY180420P00267000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:267.00
# last price:9.32
# bid price:9.28
# ask price:9.39
# contract name:SPY180420P00268000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:268.00
# last price:8.74
# bid price:9.78
# ask price:10.04
# contract name:SPY180420P00269000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:269.00
# last price:9.02
# bid price:9.99
# ask price:10.27
# contract name:SPY180420P00270000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:270.00
# last price:10.58
# bid price:9.61
# ask price:11.00
# contract name:SPY180420P00271000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:271.00
# last price:10.98
# bid price:10.90
# ask price:10.96
# contract name:SPY180420P00272000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:272.00
# last price:10.77
# bid price:11.09
# ask price:11.26
# contract name:SPY180420P00273000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:273.00
# last price:11.24
# bid price:11.65
# ask price:11.97
# contract name:SPY180420P00274000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:274.00
# last price:10.04
# bid price:11.89
# ask price:12.18
# contract name:SPY180420P00275000
# last_trade_date:2018-02-05 3:07PM EST
# strike price:275.00
# last price:12.77
# bid price:12.42
# ask price:12.72
# contract name:SPY180420P00276000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:276.00
# last price:12.50
# bid price:12.50
# ask price:13.88
# contract name:SPY180420P00277000
# last_trade_date:2018-02-05 3:04PM EST
# strike price:277.00
# last price:12.70
# bid price:13.44
# ask price:13.75
# contract name:SPY180420P00278000
# last_trade_date:2018-02-05 2:51PM EST
# strike price:278.00
# last price:11.88
# bid price:14.18
# ask price:14.48
# contract name:SPY180420P00279000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:279.00
# last price:13.50
# bid price:14.10
# ask price:15.59
# contract name:SPY180420P00280000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:280.00
# last price:14.40
# bid price:15.25
# ask price:15.55
# contract name:SPY180420P00281000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:281.00
# last price:14.29
# bid price:15.90
# ask price:16.22
# contract name:SPY180420P00282000
# last_trade_date:2018-02-05 3:01PM EST
# strike price:282.00
# last price:15.49
# bid price:16.83
# ask price:17.17
# contract name:SPY180420P00283000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:283.00
# last price:16.97
# bid price:17.58
# ask price:17.93
# contract name:SPY180420P00284000
# last_trade_date:2018-02-05 2:44PM EST
# strike price:284.00
# last price:15.42
# bid price:20.07
# ask price:18.76
# contract name:SPY180420P00285000
# last_trade_date:2018-02-05 3:05PM EST
# strike price:285.00
# last price:18.79
# bid price:18.49
# ask price:19.21
# contract name:SPY180420P00286000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:286.00
# last price:17.58
# bid price:19.59
# ask price:20.47
# contract name:SPY180420P00287000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:287.00
# last price:18.97
# bid price:20.46
# ask price:21.36
# contract name:SPY180420P00288000
# last_trade_date:2018-02-05 1:52PM EST
# strike price:288.00
# last price:17.15
# bid price:21.34
# ask price:22.23
# contract name:SPY180420P00289000
# last_trade_date:2018-02-05 1:34PM EST
# strike price:289.00
# last price:18.13
# bid price:22.25
# ask price:23.16
# contract name:SPY180420P00290000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:290.00
# last price:23.27
# bid price:23.18
# ask price:24.11
# contract name:SPY180420P00291000
# last_trade_date:2018-02-05 2:43PM EST
# strike price:291.00
# last price:21.10
# bid price:24.13
# ask price:29.24
# contract name:SPY180420P00292000
# last_trade_date:2018-02-05 1:58PM EST
# strike price:292.00
# last price:20.00
# bid price:25.08
# ask price:26.04
# contract name:SPY180420P00293000
# last_trade_date:2018-02-05 12:13PM EST
# strike price:293.00
# last price:19.70
# bid price:26.04
# ask price:27.00
# contract name:SPY180420P00294000
# last_trade_date:2018-02-05 11:31AM EST
# strike price:294.00
# last price:20.00
# bid price:27.01
# ask price:28.03
# contract name:SPY180420P00295000
# last_trade_date:2018-02-05 3:06PM EST
# strike price:295.00
# last price:28.02
# bid price:27.58
# ask price:28.51
# contract name:SPY180420P00296000
# last_trade_date:2018-02-05 2:57PM EST
# strike price:296.00
# last price:27.80
# bid price:28.99
# ask price:29.99
# contract name:SPY180420P00297000
# last_trade_date:2018-01-29 4:00PM EST
# strike price:297.00
# last price:13.66
# bid price:22.03
# ask price:22.42
# contract name:SPY180420P00298000
# last_trade_date:2018-01-31 2:54PM EST
# strike price:298.00
# last price:20.27
# bid price:22.99
# ask price:23.39
# contract name:SPY180420P00299000
# last_trade_date:2018-02-05 1:57PM EST
# strike price:299.00
# last price:26.96
# bid price:31.93
# ask price:32.96
# contract name:SPY180420P00300000
# last_trade_date:2018-02-02 2:11PM EST
# strike price:300.00
# last price:23.09
# bid price:24.94
# ask price:25.34
# contract name:SPY180420P00301000
# last_trade_date:2018-02-05 2:56PM EST
# strike price:301.00
# last price:32.22
# bid price:33.91
# ask price:39.14
# contract name:SPY180420P00305000
# last_trade_date:2018-01-09 12:19PM EST
# strike price:305.00
# last price:30.23
# bid price:26.96
# ask price:27.26
# contract name:SPY180420P00310000
# last_trade_date:2018-01-05 11:50PM EST
# strike price:310.00
# last price:37.74
# bid price:36.37
# ask price:36.65
# contract name:SPY180420P00320000
# last_trade_date:2018-01-26 11:50PM EST
# strike price:320.00
# last price:35.97
# bid price:33.30
# ask price:33.63
# contract name:SPY180420P00325000
# last_trade_date:2018-01-05 11:50PM EST
# strike price:325.00
# last price:52.40
# bid price:51.35
# ask price:51.63
# contract name:SPY180420P00335000
# last_trade_date:2018-01-17 12:31PM EST
# strike price:335.00
# last price:56.28
# bid price:54.54
# ask price:54.88
# contract name:SPY180420P00340000
# last_trade_date:2018-01-30 9:37AM EST
# strike price:340.00
# last price:57.00
# bid price:64.75
# ask price:65.16

# %%
import pandas as pd

# %%
file1='SPYcallopt.csv'
file2='SPYputopt.csv'

# %%
merge_file='SPYopt.csv'

# %%
data_email=pd.read_csv(file1)
data_email.head()
# Out:
#         contract_name         last_trade_date  strike_price  last_price  \
# 0  SPY180518C00140000  2018-01-26 11:46PM EST         140.0      143.71
# 1  SPY180518C00145000  2018-01-26 11:46PM EST         145.0      138.70
# 2  SPY180518C00155000  2018-01-26 11:46PM EST         155.0      129.05
# 3  SPY180518C00170000  2018-01-26 11:46PM EST         170.0      113.89
# 4  SPY180518C00190000   2018-01-29 1:00PM EST         190.0       96.60
#
#    bid_price  ask_price
# 0     146.94     147.30
# 1     141.97     142.32
# 2     131.99     132.35
# 3     117.04     117.42
# 4      85.61      86.22

# %%
data_phone=pd.read_csv(file2)
data_phone.head()
# Out:
#         contract_name         last_trade_date  strike_price  last_price  \
# 0  SPY180518P00140000  2018-01-31 12:30PM EST         140.0        0.04
# 1  SPY180518P00145000   2018-01-31 9:33AM EST         145.0        0.05
# 2  SPY180518P00150000   2018-02-02 8:05PM EST         150.0        0.06
# 3  SPY180518P00165000  2018-01-26 11:50PM EST         165.0        0.08
# 4  SPY180518P00170000   2018-02-02 2:41PM EST         170.0        0.14
#
#    bid_price  ask_price
# 0       0.03       0.07
# 1       0.04       0.08
# 2       0.05       0.06
# 3       0.06       0.07
# 4       0.13       0.16

# %%
frames=[data_email,data_phone]

result=pd.concat(frames)
result.to_csv(merge_file,index_label='id')

# %%
# Out:
# '900.00'

# %%
# Out:
# '519.25'
