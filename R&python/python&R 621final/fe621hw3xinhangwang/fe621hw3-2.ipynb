# %%
import scipy.stats as stats
import numpy as np
from time import clock

# %%
from time import time
from math import exp, sqrt, log
from random import gauss, seed

# %%
T=1.
N=300
r=0.0319
div=0.
sigma=0.61
S=100
v=0.010201
kappa=6.21
theta=0.019
rho=-0.7
K=100

dt=T/N

M=1000

sum_CT=0
sum_CT2=0

# %%
start = time()

for j in range(M):
    St=S
    vt=v
    for i in range(N):
        e1= gauss(0.0, 1.0)
        e2=gauss(0.0, 1.0)
        z1=e1
        z2=rho*e1+sqrt(1-rho**2)*e2

        vt=vt*math.exp((kappa*(theta-vt)-sigma**2/2)/vt*dt+sigma*sqrt(dt/vt)*z2)
        if vt==0:
            break
        St=St*math.exp((r-0.5*vt)*dt+sqrt(vt*dt)*z1)
        i=i+1
    CT=max(0,St-K)
    sum_CT=sum_CT+CT
    sum_CT2=sum_CT2+CT*CT
    j=j+1
total_time = time() - start
print ('total time is %.6f seconds'% total_time)
# Out:
# total time is 1.933110 seconds

# %%
call_value=sum_CT/M*math.exp(-r*T)
SD=sqrt((sum_CT2-sum_CT*sum_CT/M)*math.exp(-2*r*T)/(M-1))
SE=SD/sqrt(M)
call_value
# Out:
# 0.6625344524275998

# %%
SD
# Out:
# 1.5205390582511626

# %%
SE
# Out:
# 0.04808366695321118

# %%
sqrt(sum_CT2/M)
# Out:
# 1.7116540713533814

# %%
T=1.
N=300
r=0.0319
div=0.
sigma=0.61
S=100
v=0.010201
kappa=6.21
theta=0.019
rho=-0.7
K=100

dt=T/N

M=1000

sum_CT=0
sum_CT2=0

# %%
math.log(v)+1/v*(kappa*(theta-v)-0.5*sigma**2)*dt+sigma/sqrt(v)*sqrt(dt)*z2
# Out:
# -4.569371040460434

# %%
#E-M

from time import time
start = time()
for j in range(M):
    lnvt=math.log(v)
    lnSt=math.log(S)
    vt=v
    for i in range(N):
        e1=np.random.standard_normal()
        e2=np.random.standard_normal()
        z1=e1
        z2=rho*e1+sqrt(1-rho**2)*e2

        lnvt=lnvt+1/vt*(kappa*(theta-vt)-0.5*sigma**2)*dt+sigma/sqrt(vt)*sqrt(dt)*z2
        vt=math.exp(lnvt)
        if vt==0:
            break
        if sqrt(vt)==0:
            break
        lnSt=lnSt+(r-0.5*vt)*dt+sqrt(vt)*sqrt(dt)*z1
        i=i+1
    ST=math.exp(lnSt)
    CT=max(0,ST-K)
    sum_CT=sum_CT+CT
    sum_CT2=sum_CT2+CT*CT
    j=j+1
total_time = time() - start
print ('total time is %.6f seconds'% total_time)
# Out:
# total time is 1.513087 seconds

# %%
call_value=sum_CT/M*math.exp(-r*T)
SD=sqrt((sum_CT2-sum_CT*sum_CT/M)*math.exp(-2*r*T)/(M-1))
SE=SD/sqrt(M)
call_value
# Out:
# 0.6962502305473898

# %%
SD
# Out:
# 1.3108790281043023

# %%
SE
# Out:
# 0.04145363465757473

# %%
sqrt(sum_CT2/M)   #rmse
# Out:
# 1.5318223009290228

# %%
S0=100
K=100
r=0.0319
sigma=0.61
T=1.


d1=(np.log(S0/K)+(r+sigma**2/2)*T)/(sigma*np.sqrt(T))
d2=d1-sigma*np.sqrt(T)
C=S0*norm.cdf(d1)-K*exp(-r*T)*norm.cdf(d2)

C
# Out:
# 25.188283592791045

# %%
#3.1)
10000000*0.3*6.1    #number of  yuan
# Out:
# 18300000.0

# %%
10000000*0.4/80 #number of shares
# Out:
# 50000.0

# %%
10000000*0.3/90000   #tbills cost
# Out:
# 33.333333333333336

# %%
# Out:
# 5.599424363259058

# %%
#3
dt=0.001
M=1000
t=10/252
N=int(t/dt)
x0=80
y0=90000
z0=6.1


ty=[]

# %%
from time import time
start = time()
for j in range(M):
    xt=x0
    yt=y0
    zt=z0

    for i in range(N):
        e1=gauss(0.,1.)
        e2=gauss(0.,1.)
        e3=gauss(0.,1.)
        
        xt=xt+0.01*xt*dt+0.3*xt*sqrt(dt)*e1
        yt=yt+100*(90000+1000*t-yt)*dt+sqrt(yt)*sqrt(dt)*e2
        zt=zt+5*(6-zt)*dt+0.01*sqrt(zt)*sqrt(dt)*e3
        if yt<=0:
            break
        i=i+1
    print((xt-x0)/x0)
    ty.append(0.4*(xt-x0)/x0+0.3*(1-y0/yt)/10+0.3*(z0-zt)/z0)
    j=j+1
total_time = time() - start
print ('total time is %.6f seconds'% total_time)
# Out:
# -0.04461048017316287
# -0.061001152148378604
# -0.012723642567553383
# -0.03888724275496891
# 0.023511757425063885
# 0.00303642764479477
# -0.08878770988826404
# -0.03270195380667733
# 0.0029557612088577656
# 0.09629033718286131
# -0.018094193696010664
# 0.03283394861875699
# 0.035907739089905986
# -0.09824968161654776
# -0.06194136382066162
# 0.003914063978826476
# -0.016659472407786247
# 0.06710699308237959
# 0.07040866423327703
# -0.008271251069834484
# -0.01412197325644211
# 0.006861436172262892
# -0.03938175021766863
# 0.0021179299302056974
# 0.15076333174531625
# -0.026831136396052814
# 0.06815201258950321
# -0.04730089641475939
# -0.026528790904464295
# 0.05870824848100682
# -0.03692089968796584
# 0.015528807250913346
# -0.019210062262053285
# 0.09556967207188158
# 0.012729833882762876
# 0.034381685106105134
# -0.03631940762567289
# 0.018745944987849407
# -0.007781871314847954
# -0.015193884794704182
# 0.021460473721690576
# 0.029899837716076405
# 0.05469423323338436
# ...

# %%
ty2=sorted(ty)

# %%
i=M*0.01
30000
# Out:
# 30000

# %%
ty2[29999]   #VAR
# Out:
# -0.05180599030281686

# %%
ty3=ty2[:30000]

# %%
s = 0
for x in ty3:
    s += x
print(s/i)   #cvar
# Out:
# -0.05936068487963981
